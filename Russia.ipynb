# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;

################################################################################
## Python Version
################################################################################
import sys
from io import StringIO
from pandas import DataFrame, read_csv
import urllib
from timeUtils import clock, elapsed

from ioUtils import getFile, saveFile
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
def downloadURL(url):
    user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    headers={'User-Agent':user_agent,} 

    print("Now Downloading {0}".format(url))

    request=urllib.request.Request(url,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read() # The data u need
        
    return data, response.getcode()

# %% [markdown]
# # Russia

# %%
txt="""A
Emin Agalarov
Leonid Agutin
Irina Allegrova
Alsou
Darya Antonyuk
Artsvik
B
Nikolay Baskov
Kola Beldy
Zhenya Belousov
Dima Bilan
Polina Bogusevich
Mikhail Boyarsky
Tatiana Bulanova
C
Sergey Chumakov (singer)
D
Lada Dance
Danko (singer)
Marina Devyatova
Irina Dubtsova
E
Egine
Elvira T
F
Vasilya Fattakhova
Nikolai Fomenko
Jeanna Friske
G
Polina Gagarina
Oleg Gazmanov
Natalie Gioia
Glukoza
Alexey Glyzin
Aleksey Goman
Andrey Gubin
Lyudmila Gurchenko
I
Igor Ivanov (singer)
J
Jasmin (singer)
Julian (singer)
K
Yulianna Karaulova
Lena Katina
Sati Kazanova
Sevak Khanagyan
Elizaveta Khripounova
Dayana Kirillova
Philipp Kirkorov
Joseph Kobzon
Natasha Korolyova
Julia Kova
Alisa Kozhikina
Valeria Kozlova
Sergei Krylov (singer)
Irson Kudikova
Oleg Kukhta
L
Sergey Lazarev
Katya Lee
Katya Lel
Valery Leontiev
Lerika
Pyotr Leshchenko
Lika MC
Linda (singer)
Jenia Lubich
M
Muslim Magomayev (musician)
MakSim
Vladimir Markin
Valery Meladze
Lolita Milyavskaya
Boris Moiseev
N
Tomas N'evergreen
Natali (singer)
N.A.T.o. (singer)
Irene Nelson
Ksenia Novikova
Nyusha
O
Kristina Orbakaitė
Olga Orlova (singer)
P
Aleksandr Panayotov
Soso Pavliashvili
Elena Perova
Stas Piekha
Anna Pletnyova
Oksana Pochepa
Natalia Podolskaya
Vladimir Presnyakov Jr.
Alla Pugacheva
Mikhail Puntov
R
Vladislav Ramm
Masha Rasputina
Christian Ray
Timur Rodriguez
Ekaterina Ryabova (singer)
S
Makka Sagaipova
Viktor Saltykov
Irina Saltykova
Yuliya Samoylova (singer)
Nina Shatskaya
Batyrkhan Shukenov
Anna Shulgina
Klavdiya Shulzhenko
Shura (Russian singer)
Vladimir Shurochkin
Mikhail Smirnov (singer)
Vlad Sokolovsky
Vlad Stashevsky
Anastasia Stotskaya
Svoy
Valeriy Syutkin
T
Xava Tashaeva
Irina Toneva
Vlad Topalov
Alyona Torganova
Lena Tretyakova
Anita Tsoy
U
Liza Umarova
Leonid Utyosov
V
Valeriya
Anzhelika Varum
Varvara (singer)
Aida Vedishcheva
Marina Verenikina
Natalya Vetlitskaya
Julia Volkova
Aleksandra Vorobyova
Y
Lesya Yaroslavskaya
Z
Anastasia Zadorozhnaya
Zaza Napoli
Zemfira
Sergey Zhukov
Zivert
Sergey Zverev""".split("\n")

from string import ascii_uppercase
data = {"Russia": []}
country = "Russia"
for line in txt:
    artist = line
    artist = artist.split(" (born")[0]
    artist = artist.split(" (1")[0]
    artist = artist.split(" (b")[0]
    artist = artist.split(" (c")[0]
    artist = artist.split(" (p")[0]
    artist = artist.split(", ")[0]
    artist = artist.split(" – ")[0]    
    artist = artist.split(" - ")[0]
    artist = artist.replace("(band)", "").strip()
    artist = artist.replace("(singer)", "").strip()
    artist = artist.replace("(group)", "").strip()
    artist = artist.replace("(rapper)", "").strip()
    if artist in ascii_uppercase:
        continue
        
    data[country].append(artist)

from pandas import Series
russian_artists = DataFrame(Series(data["Russia"]))
russian_artists.columns = ["Artists"]
russian_artists.head()
# Out:
#            Artists
# 0    Emin Agalarov
# 1    Leonid Agutin
# 2  Irina Allegrova
# 3            Alsou
# 4   Darya Antonyuk

# %%
baseDir = "/Volumes/Piggy/Charts/data/russia/categories"
saveFile(idata=russian_artists, ifile="{0}/russia_artists.p".format(baseDir))
# Out:
#   --> This file is 2.2kB.

# %% [markdown]
# # Combination

# %%
rud = russiaData()

# %%
rud.parse()
# Out:
# Found 1 files.
# Saving data to /Volumes/Piggy/Charts/data/russia/results/russia.p
#   --> This file is 2.2kB.
# Saved data to /Volumes/Piggy/Charts/data/russia/results/russia.p
#   --> This file is 2.2kB.

# %%
# %load_ext autoreload
# %autoreload
from russia import russiaData
rud = russiaData(minYear=0, maxYear=2021)
#lad.setDBRenames(manDB)
#lad.setMultiDBRenames(multimanDB)
rud.setChartUsage(rank=[0])
rud.setFullChartData()
rud.setArtistAlbumData()
rud.saveArtistAlbumData()
rud.saveFullChartData()
_, _ = clock("Last Run")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using Charts For Rank 0
#     Categories: ['russia']
# 	Chart: russia
#   Using 1 Charts
# Using 1 Charts For Rank 0
# === ChartUsage ===
#   Using Charts (Rank=[0]): ['russia']
# Found 1 summary files
#   Using russia
# Renamed 0 single artists
# Saving 126 Artist Album Data to currentrussiaArtistAlbumData.p
# Saving data to currentrussiaArtistAlbumData.p
#   --> This file is 1.8kB.
# Saved data to currentrussiaArtistAlbumData.p
#   --> This file is 1.8kB.
# Saving 126 Full Artist Data
# Saving data to currentrussiaFullChartArtistAlbumData.p
#   --> This file is 2.7kB.
# Saved data to currentrussiaFullChartArtistAlbumData.p
#   --> This file is 2.7kB.
# Current Time is Thu Feb 25, 2021 19:52:27 for Last Run

# %%
getFile("currentlatinamericaArtistAlbumData.p")
# Out:
# {'Julio Iglesias': ['Lo Mejor de Tu Vida'],
#  'Santana': [],
#  'Roberto Carlos': [],
#  'Gloria Estefan': [],
#  'Shakira': [],
#  'Nelson Gonçalves': [],
#  'Enrique Iglesias': ['Enamorado Por Primera Vez', 'Dímelo', 'Solo En Ti'],
#  'Ricky Martin': ['Tal Vez'],
#  'Andrea Bocelli': [],
#  'Luis Miguel': [],
#  'Juan Gabriel': [],
#  'Jennifer Lopez': [],
#  'Camilo Sesto': [],
#  'Raphael': [],
#  'José Feliciano': [],
#  'Xuxa': [],
#  'Vicente Fernández': [],
#  'Thalia': [],
#  'Nelson Ned': [],
#  'Laura Pausini': [],
#  'Leo Dan': [],
#  'José José': ['Como Tú'],
#  'Eros Ramazzotti': [],
#  'Rocio Durcal': [],
#  'Selena': ['Tú Solo Tú'],
#  'J Balvin': ['Ginza'],
#  'Los Tigres del Norte': [],
#  'Juan Luis Guerra': [],
#  'José Luis Perales': [],
#  'Amália Rodrigues': [],
#  'Marco Antonio Solís': ['Qué Pena Me Das'],
#  'Maria Bethânia': [],
#  'Pedro Infante': [],
#  'Antonio Aguilar': [],
#  'Maná': [],
#  'Alejandro Sanz': [],
#  'Ricardo Montaner': [],
#  'Daddy Yankee': ['Rompe', 'Limbo'],
#  'Mecano': [],
#  'Miguel Bosé': [],
#  'Banda Calypso': [],
#  'Amado Batista': [],
#  'Luis Fonsi': ['No Me Doy Por Vencido'],
#  'Menudo': [],
#  'Alejandro Fernández': [],
#  'Ana Gabriel': ['Ay Amor', 'Es Demasiado Tarde', 'Evidencias'],
#  'Lucero': [],
#  "Lupita D'Alessio": [],
#  'Ricardo Arjona': [],
#  'Los Temerarios': [],
#  'Pimpinela': [],
#  'Los Chichos': [],
#  'Daniela Mercury': [],
#  'Zezé di Camargo & Luciano': [],
#  'Sandy & Junior': [],
#  'Maluma': [],
#  'Soda Stereo': [],
#  'Rocio Jurado': [],
#  'Daniela Romo': ['De Mí Enamórate', 'Todo, Todo, Todo'],
#  'Diomedes Díaz': [],
#  'Paulina Rubio': [],
#  'Los del Río': [],
#  'Ozuna': [],
#  'Chayanne': [],
#  'Juanes': ['Me Enamora', 'Nada Valgo Sin Tu Amor'],
#  'Jon Secada': [],
#  'Raúl di Blasio': [],
#  'José Luis Rodríguez': [],
#  'Palito Ortega': [],
#  'RBD': [],
#  'Gloria Trevi': [],
#  'Alejandra Guzmán': [],
#  'Jenni Rivera': [],
#  'Gipsy Kings': [],
#  'Fey': [],
#  'Julieta Venegas': [],
#  'Carlos Vives': [],
#  'Franco De Vita': [],
#  'Joan Sebastian': [],
#  'Sandro': [],
#  'Cristian Castro': ['Amor'],
#  'Manuel Mijares': [],
#  'Emmanuel': [],
#  'Pepe Aguilar': [],
#  'Valeria Lynch': [],
#  'Luis Fonsi and Daddy Yankee featuring Justin Bieber[a]': ['Despacito'],
#  'Enrique Iglesias featuring Descemer Bueno and Gente de Zona': ['Bailando'],
#  'Nicky Jam and Enrique Iglesias': ['El Perdón'],
#  'Shakira featuring Alejandro Sanz': ['La Tortura'],
#  'The Black Eyed Peas and J Balvin': ['Ritmo'],
#  'Son by Four': ['A Puro Dolor'],
#  'Flex': ['Te Quiero'],
#  'Nicky Jam': ['Hasta El Amanecer'],
#  'Enrique Iglesias featuring Juan Luis Guerra': ['Cuando Me Enamoro'],
#  'Marc Anthony': ['Vivir Mi Vida'],
#  'Yuri': ['Qué Te Pasa'],
#  'Bad Bunny featuring Drake': ['Mía'],
#  'Don Omar featuring Lucenzo': ['Danza Kuduro'],
#  'Bad Bunny and Jhay Cortez': ['Dakiti'],
#  'Wisin & Yandel featuring Chris Brown and T-Pain': ['Algo Me Gusta de Ti'],
#  'Prince Royce': ['Darte Un Beso'],
#  'Enrique Iglesias featuring Wisin': ['Duele El Corazón'],
#  'Casper Mágico, Nío García, Darell, Nicky Jam, Ozuna, and Bad Bunny': ['Te Boté'],
#  'Daddy Yankee and Katy Perry featuring Snow': ['Con Calma'],
#  'Pilar Montenegro': ['Quítame Ese Hombre'],
#  'Romeo Santos featuring Drake': ['Odio'],
#  'DJ Snake featuring Selena Gomez, Ozuna, and Cardi B': ['Taki Taki'],
#  'J Balvin and Willy William featuring Beyoncé': ['Mi Gente'],
#  'Anuel AA, Daddy Yankee, and Karol G featuring Ozuna and J Balvin': ['China'],
#  'Shakira featuring Maluma': ['Chantaje'],
#  'Rocío Durcal': ['Como Tu Mujer'],
#  'Vikki Carr and Ana Gabriel': ['Cosas del Amor'],
#  'Romeo Santos featuring Usher': ['Promise'],
#  'Michel Teló': ['Ai Se Eu Te Pego'],
#  'Gustavo Cerati': [],
#  'Celia Cruz': [],
#  'Carlos Gardel': [],
#  'Miguel Pinero': [],
#  'Carmen Miranda': [],
#  'Carlos Santana': []}
