# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;

################################################################################
## Python Version
################################################################################
import sys
from io import StringIO
from pandas import DataFrame, read_csv
import urllib
from time import sleep
from fsUtils import isFile
from ioUtils import getFile, saveFile
from webUtils import getHTML
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# /Users/tgadfort/opt/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
def downloadURL(url):
    user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    headers={'User-Agent':user_agent,} 

    print("Now Downloading {0}".format(url))

    request=urllib.request.Request(url,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read() # The data u need
        
    return data, response.getcode()

# %% [markdown]
# # InfoPlease

# %%
url = "https://www.infoplease.com/culture-entertainment/music/500-songs-shaped-rock"
savename = "infoplease/rock.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
    
url = "https://www.infoplease.com/culture-entertainment/music/must-have-recordings"
savename = "infoplease/musthavealbums.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.infoplease.com/culture-entertainment/music/must-have-recordings
#   --> This file is 30.2kB.

# %%
def getArtistData(bsdata):
    artistData = {}
    for ul in bsdata.findAll("ul"):
        lis = ul.findAll("li")
        for li in lis:
            b = li.find('b')
            if b is None:
                continue
            title = li.find('b').text
            title = title[1:-1]
            b.extract()
            artist = li.text.strip()
            if artist.endswith(","):
                artist = artist[:-1]
            #print(artist,'\t',title)
            if artistData.get(artist) is None:
                artistData[artist] = []
            artistData[artist].append(title)
            
    return artistData

bsdata = getHTML("infoplease/rock.p")
artistData = getArtistData(bsdata)
saveFile(idata=artistData, ifile="infoplease/artistData_rock.p", debug=True)



bsdata = getHTML("infoplease/musthavealbums.p")
artistData = getArtistData(bsdata)
saveFile(idata=artistData, ifile="infoplease/artistData_musthavealbums.p", debug=True)
# Out:
# Saving data to infoplease/artistData_rock.p
#   --> This file is 12.9kB.
# Saved data to infoplease/artistData_rock.p
#   --> This file is 12.9kB.
# Saving data to infoplease/artistData_musthavealbums.p
#   --> This file is 6.2kB.
# Saved data to infoplease/artistData_musthavealbums.p
#   --> This file is 6.2kB.

# %% [markdown]
# # MusicOutfitters

# %%
for year in range(1950,2021):
    url = "http://www.musicoutfitters.com/topsongs/{0}.htm".format(year)
    savename = "musicoutfitters/topsongs_{0}.p".format(year)    
    if not isFile(savename):
        data, code = downloadURL(url)
        saveFile(idata=data, ifile=savename)
        sleep(3)
    break
# Out:
# Now Downloading http://www.musicoutfitters.com/topsongs/1950.htm
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/http/client.py in connect(self)
#    1421             self.sock = self._context.wrap_socket(self.sock,
# -> 1422                                                   server_hostname=server_hostname)
#    1423
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     422             context=self,
# --> 423             session=session
#     424         )
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/ssl.py in do_handshake(self, block)
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1076)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-23-14979d3af268> in <module>
#       3     savename = "musicoutfitters/topsongs_{0}.p".format(year)
#       4     if not isFile(savename):
# ----> 5         data, code = downloadURL(url)
#       6         saveFile(idata=data, ifile=savename)
#       7         sleep(3)
#
# <ipython-input-2-2d82e75098e2> in downloadURL(url)
#       6
#       7     request=urllib.request.Request(url,None,headers) #The assembled request
# ----> 8     response = urllib.request.urlopen(request)
#       9     data = response.read() # The data u need
#      10
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# ~/opt/anaconda3/envs/py37/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
# -> 1321                 raise URLError(err)
#    1322             r = h.getresponse()
#    1323         except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1076)>

# %% [markdown]
# # Digital Dream Door

# %%
for year in range(40, 100):
    url="https://digitaldreamdoor.com/pages/bg_hits/bg_hits_{0}.html".format(year)
    savename="digitaldreamdoor/19{0}.p".format(year) 
    if not isFile(savename):
        data, code = downloadURL(url)
        saveFile(idata=data, ifile=savename)
        sleep(3)

for year in range(2000, 2020):
    url="https://digitaldreamdoor.com/pages/bg_hits/bg_hits_{0}.html".format(year)
    savename="digitaldreamdoor/{0}.p".format(year) 
    if not isFile(savename):
        data, code = downloadURL(url)
        saveFile(idata=data, ifile=savename)
        sleep(3)
        

for year in range(1960, 2020):
    if year == 1999:
        continue
    url="https://digitaldreamdoor.com/pages/albums_by_year/albums_{0}.html".format(year)
    savename="digitaldreamdoor/{0}_albums.p".format(year)
    if not isFile(savename):
        data, code = downloadURL(url)
        saveFile(idata=data, ifile=savename)
        sleep(3)
        
for decade in ["1920", "1930", "1940"]:
    url="https://digitaldreamdoor.com/pages/best_songs-{0}s.html".format(decade)
    savename="digitaldreamdoor/{0}s_bestsongs.p".format(year)
    if not isFile(savename):
        data, code = downloadURL(url)
        saveFile(idata=data, ifile=savename)
        sleep(3)
# Out:
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2000.html
#   --> This file is 8.2kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2001.html
#   --> This file is 7.9kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2002.html
#   --> This file is 8.1kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2003.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2004.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2005.html
#   --> This file is 8.1kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2006.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2007.html
#   --> This file is 8.2kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2008.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2009.html
#   --> This file is 7.8kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2010.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2011.html
#   --> This file is 7.8kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2012.html
#   --> This file is 7.8kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2013.html
#   --> This file is 7.9kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2014.html
#   --> This file is 7.8kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2015.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2016.html
#   --> This file is 7.9kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2017.html
#   --> This file is 7.8kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2018.html
#   --> This file is 8.0kB.
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2019.html
#   --> This file is 7.9kB.
# Now Downloading https://digitaldreamdoor.com/pages/best_songs-1920s.html
#   --> This file is 7.7kB.

# %%
url="https://digitaldreamdoor.com/pages/music0.html"
savename="digitaldreamdoor.p".format(year) 
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://digitaldreamdoor.com/pages/music0.html
#   --> This file is 15.2kB.

# %%
bsdata = getHTML("digitaldreamdoor.p")
divs = bsdata.findAll("div", {"class": "mus"})
for div in divs:
    refs = div.findAll("a")
    for ref in refs:
        print(ref.text,'\t',ref.attrs['href'])
        url = "https://digitaldreamdoor.com/pages/{0}".format(ref.attrs['href'])
        savename = "digitaldreamdoor/{0}.p".format(ref.attrs['href'].replace("/", "_"))
        if not isFile(savename):
            try:
                data, code = downloadURL(url)
            except:
                sleep(10)
            saveFile(idata=data, ifile=savename)
            sleep(3)
# Out:
# Greatest Rock Artists 	 best_artistsddd.html
# Greatest Rock Artists 2000s 	 best_artists00s.html
# Greatest Rock Artists 1990s 	 best_artists90.html
# Greatest Rock Artists 1980s 	 best_artists80pop.html
# Greatest Rock Artists 1970s 	 best_artists70s.html
# Greatest Rock Artists 1960s 	 best_artists60s.html
# Greatest Rock Artists 1950s 	 best_artists50s.html
# Greatest Rock Artists 1940s 	 best_artists40s.html
# Most Influential Rock 'n' Roll Artists 	 best_influential.html
# Greatest Frontmen Of Rock 	 best_frontmen.html
# Greatest 'Live' Rock Artists 	 best_liveband.html
# Greatest Rock 'n' Roll Artists - Female 	 best_artists-female.html
# Greatest Music Duos 	 best_duos.html
# Greatest Jam Bands 	 best_artists-jam.html
# Greatest Blues Rock Artists 	 best_artists-blues-rock.html
# Greatest Power Pop Artists 	 best_artists-Power-Pop.html
# Greatest Glam Rock Artists 	 best_artists-glam-rock.html
# Greatest Psychedelic Artists 	 best_artists_psychedelic.html
# Greatest Folk Rock Artists 	 best_artists-folk-rock.html
# Greatest Hard Rock Artists 	 best_artists-hard-rock.html
# Greatest Soft Rock Artists 	 best_artists-adu.html
# Greatest British Invasion Artists 	 best_artists-British-Invasion.html
# Top 10 Music Artists From Each State 	 best_state-artists.html
# Top 5 New Rock Artists of Each Year 2000-2009 	 best_artists-top-fives-2000-2009.html
# Top 5 New Rock Artists of Each Year 1980-1999 	 best_artists-top-fives-1980-1999.html
# Top 5 New Rock Artists of Each Year 1960-1979 	 best_artists-top-fives-1960-1979.html
# Top 5 New Rock Artists of Each Year 1946-1959 	 best_artists-top-fives-1946-1959.html
# Greatest Rock Music Ensembles 	 best_artists-ensembles.html
# Greatest Rock Guitarists 	 best_newguitar.html
# Greatest Rock Guitar Riffs 	 best_guitarriff.html
# Greatest Rock Guitar Solos 	 best_guitarsolo.html
# Greatest Live Rock Guitar Solos 	 best_guitar-solo-live.html
# Greatest Metal Guitarists 	 best_guitar-metal.html
# Greatest Acoustic Guitarists 	 best_jazz/best_acousticddd.html
.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums60s.html
#   --> This file is 10.0kB.
# Greatest Rock Albums of the 1950s 	 best_albums50s.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums50s.html
#   --> This file is 7.5kB.
# Top 10 Rock Albums of each Year 2010-2019 	 best_albums-top-tens-2010-2019.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-2010-2019.html
#   --> This file is 7.2kB.
# Top 10 Rock Albums of each Year 2000-2009 	 best_albums-top-tens-2000-2009.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-2000-2009.html
#   --> This file is 7.2kB.
# Top 10 Rock Albums of each Year 1990-1999 	 best_albums-top-tens-1990-1999.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-1990-1999.html
#   --> This file is 7.2kB.
# Top 10 Rock Albums of each Year 1980-1989 	 best_albums-top-tens-1980-1989.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-1980-1989.html
#   --> This file is 7.1kB.
# Top 10 Rock Albums of each Year 1970-1979 	 best_albums-top-tens-1970-1979.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-1970-1979.html
#   --> This file is 7.3kB.
# Top 10 Rock Albums of each Year 1960-1969 	 best_albums-top-tens-1960-1969.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-1960-1969.html
#   --> This file is 7.3kB.
# Top 10 Rock Albums of each Year 1956-1959 	 best_albums-top-tens-1956-1959.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-top-tens-1956-1959.html
#   --> This file is 5.6kB.
# Greatest 'Live' Rock Albums 	 best_livealb.html
# Now Downloading https://digitaldreamdoor.com/pages/best_livealb.html
#   --> This file is 8.8kB.
# Greatest Rock 'Guitar' Albums 	 best_rockguitalbddd.html
# Now Downloading https://digitaldreamdoor.com/pages/best_rockguitalbddd.html
#   --> This file is 8.9kB.
# Greatest Acoustic Guitar Albums 	 best_albums-acous.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-acous.html
#   --> This file is 7.4kB.
# Top 5 Albums by Popular Rock Artists 	 best_album-five-01.html
# Now Downloading https://digitaldreamdoor.com/pages/best_album-five-01.html
#   --> This file is 14.6kB.
# Greatest Psychedelic Albums 	 best_albumspsych.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albumspsych.html
#   --> This file is 8.0kB.
# Greatest Forgotten Albums 	 best_forgotalb.html
# Now Downloading https://digitaldreamdoor.com/pages/best_forgotalb.html
#   --> This file is 9.7kB.
# Greatest Drumming Albums 	 best_albums-drum.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-drum.html
#   --> This file is 7.4kB.
# Greatest Rock Debut Albums 	 best_albums-debut.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-debut.html
#   --> This file is 8.9kB.
# Greatest Double Albums 	 best_albums-double.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-double.html
#   --> This file is 7.7kB.
# Greatest Albums by Female Artists 	 best_albums-femart.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-femart.html
#   --> This file is 9.6kB.
# Greatest Posthumous Rock Albums 	 best_albums-posthumous-rock.html
# Now Downloading https://digitaldreamdoor.com/pages/best_albums-posthumous-rock.html
#   --> This file is 11.3kB.
# 1960 	 albums_by_year/albums_1960.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1960.html
#   --> This file is 7.6kB.
# 1961 	 albums_by_year/albums_1961.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1961.html
#   --> This file is 8.0kB.
# 1962 	 albums_by_year/albums_1962.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1962.html
#   --> This file is 8.1kB.
# 1963 	 albums_by_year/albums_1963.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1963.html
#   --> This file is 8.0kB.
# 1964 	 albums_by_year/albums_1964.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1964.html
#   --> This file is 8.2kB.
# 1965 	 albums_by_year/albums_1965.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1965.html
#   --> This file is 8.1kB.
# 1966 	 albums_by_year/albums_1966.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1966.html
#   --> This file is 7.9kB.
# 1967 	 albums_by_year/albums_1967.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1967.html
#   --> This file is 8.2kB.
# 1968 	 albums_by_year/albums_1968.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1968.html
#   --> This file is 8.0kB.
# 1969 	 albums_by_year/albums_1969.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1969.html
#   --> This file is 8.0kB.
# 1970 	 albums_by_year/albums_1970.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1970.html
#   --> This file is 8.2kB.
# 1971 	 albums_by_year/albums_1971.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1971.html
#   --> This file is 8.1kB.
# 1972 	 albums_by_year/albums_1972.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1972.html
#   --> This file is 8.1kB.
# 1973 	 albums_by_year/albums_1973.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1973.html
#   --> This file is 8.1kB.
# 1974 	 albums_by_year/albums_1974.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1974.html
#   --> This file is 8.2kB.
# 1975 	 albums_by_year/albums_1975.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1975.html
#   --> This file is 8.1kB.
# 1976 	 albums_by_year/albums_1976.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1976.html
#   --> This file is 7.9kB.
# 1977 	 albums_by_year/albums_1977.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1977.html
#   --> This file is 8.0kB.
# 1978 	 albums_by_year/albums_1978.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1978.html
#   --> This file is 8.0kB.
# 1979 	 albums_by_year/albums_1979.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1979.html
#   --> This file is 7.9kB.
# 1980 	 albums_by_year/albums_1980.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1980.html
#   --> This file is 8.0kB.
# 1981 	 albums_by_year/albums_1981.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1981.html
#   --> This file is 8.0kB.
# 1982 	 albums_by_year/albums_1982.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1982.html
#   --> This file is 8.0kB.
# 1983 	 albums_by_year/albums_1983.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1983.html
#   --> This file is 8.1kB.
# 1984 	 albums_by_year/albums_1984.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1984.html
#   --> This file is 8.0kB.
# 1985 	 albums_by_year/albums_1985.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1985.html
#   --> This file is 8.0kB.
# 1986 	 albums_by_year/albums_1986.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1986.html
#   --> This file is 8.0kB.
# 1987 	 albums_by_year/albums_1987.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1987.html
#   --> This file is 8.1kB.
# 1988 	 albums_by_year/albums_1988.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1988.html
#   --> This file is 8.1kB.
# 1989 	 albums_by_year/albums_1989.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1989.html
#   --> This file is 8.0kB.
# 1990 	 albums_by_year/albums_1990.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1990.html
#   --> This file is 7.9kB.
# 1991 	 albums_by_year/albums_1991.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1991.html
#   --> This file is 7.9kB.
# 1992 	 albums_by_year/albums_1992.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1992.html
#   --> This file is 7.9kB.
# 1993 	 albums_by_year/albums_1993.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1993.html
#   --> This file is 8.1kB.
# 1994 	 albums_by_year/albums_1994.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1994.html
#   --> This file is 7.9kB.
# 1995 	 albums_by_year/albums_1995.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1995.html
#   --> This file is 7.9kB.
# 1996 	 albums_by_year/albums_1996.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1996.html
#   --> This file is 8.0kB.
# 1997 	 albums_by_year/albums_1997.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1997.html
#   --> This file is 8.1kB.
# 1998 	 albums_by_year/albums_1998.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_1998.html
#   --> This file is 8.4kB.
# 2000 	 albums_by_year/albums_2000.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2000.html
#   --> This file is 8.2kB.
# 2001 	 albums_by_year/albums_2001.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2001.html
#   --> This file is 7.9kB.
# 2002 	 albums_by_year/albums_2002.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2002.html
#   --> This file is 8.1kB.
# 2003 	 albums_by_year/albums_2003.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2003.html
#   --> This file is 8.0kB.
# 2004 	 albums_by_year/albums_2004.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_2004.html
#   --> This file is 8.0kB.
# 2005 	 albums_by_year/albums_2005.html
# Now Downloading https://digitaldreamdoor.com/pages/albums_by_year/albums_
html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_88.html
#   --> This file is 9.2kB.
# 1989 	 bg_hits/bg_hits_89.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_89.html
#   --> This file is 9.1kB.
# 1990 	 bg_hits/bg_hits_90.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_90.html
#   --> This file is 9.1kB.
# 1991 	 bg_hits/bg_hits_91.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_91.html
#   --> This file is 8.9kB.
# 1992 	 bg_hits/bg_hits_92.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_92.html
#   --> This file is 8.8kB.
# 1993 	 bg_hits/bg_hits_93.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_93.html
#   --> This file is 8.9kB.
# 1994 	 bg_hits/bg_hits_94.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_94.html
#   --> This file is 8.9kB.
# 1995 	 bg_hits/bg_hits_95.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_95.html
#   --> This file is 9.1kB.
# 1996 	 bg_hits/bg_hits_96.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_96.html
#   --> This file is 9.2kB.
# 1997 	 bg_hits/bg_hits_97.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_97.html
#   --> This file is 9.2kB.
# 1998 	 bg_hits/bg_hits_98.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_98.html
#   --> This file is 9.2kB.
# 1999 	 bg_hits/bg_hits_99.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_99.html
#   --> This file is 9.0kB.
# 2000 	 bg_hits/bg_hits_2000.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2000.html
#   --> This file is 9.1kB.
# 2001 	 bg_hits/bg_hits_2001.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2001.html
#   --> This file is 9.1kB.
# 2002 	 bg_hits/bg_hits_2002.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2002.html
#   --> This file is 9.2kB.
# 2003 	 bg_hits/bg_hits_2003.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2003.html
#   --> This file is 9.1kB.
# 2004 	 bg_hits/bg_hits_2004.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2004.html
#   --> This file is 9.1kB.
# 2005 	 bg_hits/bg_hits_2005.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2005.html
#   --> This file is 9.2kB.
# 2006 	 bg_hits/bg_hits_2006.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2006.html
#   --> This file is 8.9kB.
# 2007 	 bg_hits/bg_hits_2007.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2007.html
#   --> This file is 9.1kB.
# 2008 	 bg_hits/bg_hits_2008.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2008.html
#   --> This file is 9.0kB.
# 2009 	 bg_hits/bg_hits_2009.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2009.html
#   --> This file is 9.0kB.
# 2010 	 bg_hits/bg_hits_2010.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2010.html
#   --> This file is 9.2kB.
# 2011 	 bg_hits/bg_hits_2011.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2011.html
#   --> This file is 9.2kB.
# 2012 	 bg_hits/bg_hits_2012.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2012.html
#   --> This file is 9.1kB.
# 2013 	 bg_hits/bg_hits_2013.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2013.html
#   --> This file is 9.0kB.
# 2014 	 bg_hits/bg_hits_2014.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2014.html
#   --> This file is 9.2kB.
# 2015 	 bg_hits/bg_hits_2015.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2015.html
#   --> This file is 9.5kB.
# 2016 	 bg_hits/bg_hits_2016.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2016.html
#   --> This file is 9.4kB.
# 2017 	 bg_hits/bg_hits_2017.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2017.html
#   --> This file is 9.2kB.
# 2018 	 bg_hits/bg_hits_2018.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2018.html
#   --> This file is 9.3kB.
# 2019 	 bg_hits/bg_hits_2019.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2019.html
#   --> This file is 9.4kB.
# 2020 	 bg_hits/bg_hits_2020.html
# Now Downloading https://digitaldreamdoor.com/pages/bg_hits/bg_hits_2020.html
#   --> This file is 9.1kB.
# Greatest R&B Artists 	 best_rb-greatest-RB-artists.html
# Now Downloading https://digitaldreamdoor.com/pages/best_rb-greatest-RB-artists.html
#   --> This file is 6.1kB.
# Greatest R&B/Soul Songs 	 best_rb-songs.html
# Now Downloading https://digitaldreamdoor.com/pages/best_rb-songs.html
#   --> This file is 9.2kB.
# Greatest R&B/Soul Ballads 	 best_rb-ballads.html
# Now Downloading https://digitaldreamdoor.com/pages/best_rb
html
# Now Downloading https://digitaldreamdoor.com/pages/best_artists-bio/Sly-Family-Stone.html
#   --> This file is 16.1kB.
# Soundgarden 	 best_artists-bio/soundgarden.html
# Now Downloading https://digitaldreamdoor.com/pages/best_artists-bio/soundgarden.html
#   --> This file is 12.7kB.
# Tool 	 best_artists-bio/tool.html
# Now Downloading https://digitaldreamdoor.com/pages/best_artists-bio/tool.html
#   --> This file is 11.2kB.
# The Who 	 best_artists-bio/who.html
# Now Downloading https://digitaldreamdoor.com/pages/best_artists-bio/who.html
#   --> This file is 12.1kB.
# 2020 Inductees 	 best_hall-of-fame-2020.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2020.html
#   --> This file is 9.8kB.
# 2019 Inductees 	 best_hall-of-fame-2019.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2019.html
#   --> This file is 9.7kB.
# 2018 Inductees 	 best_hall-of-fame-2018.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2018.html
#   --> This file is 10.1kB.
# 2017 Inductees 	 best_hall-of-fame-2017.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2017.html
#   --> This file is 13.9kB.
# 2016 Inductees 	 best_hall-of-fame-2016.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2016.html
#   --> This file is 13.2kB.
# 2015 Inductees 	 best_hall-of-fame-2015.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2015.html
#   --> This file is 14.6kB.
# 2014 Inductees 	 best_hall-of-fame-2014.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2014.html
#   --> This file is 15.7kB.
# 2013 Inductees 	 best_hall-of-fame-2013.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2013.html
#   --> This file is 15.1kB.
# 2012 Inductees 	 best_hall-of-fame-2012.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2012.html
#   --> This file is 22.4kB.
# 2011 Inductees 	 best_hall-of-fame-2011.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2011.html
#   --> This file is 14.2kB.
# 2010 Inductees 	 best_hall-of-fame-2010.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-2010.html
#   --> This file is 11.5kB.
# 2009 Inductees 	 best_halloffame_09.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_09.html
#   --> This file is 9.9kB.
# 2008 Inductees 	 best_halloffame_08.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_08.html
#   --> This file is 12.1kB.
# 2007 Inductees 	 best_halloffame_07.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_07.html
#   --> This file is 6.8kB.
# 2006 Inductees 	 best_halloffame_sc01.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_sc01.html
#   --> This file is 8.1kB.
# Inductees 1986-2020 	 best_halloffame.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame.html
#   --> This file is 9.7kB.
# 2021 Nominees 	 best_hall-of-fame-nom-2021.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2021.html
#   --> This file is 11.7kB.
# 2020 Nominees 	 best_hall-of-fame-nom-2020.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2020.html
#   --> This file is 13.3kB.
# 2019 Nominees 	 best_hall-of-fame-nom-2019.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2019.html
#   --> This file is 13.5kB.
# 2018 Nominees 	 best_hall-of-fame-nom-2018.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2018.html
#   --> This file is 15.9kB.
# 2017 Nominees 	 best_hall-of-fame-nom-2017.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2017.html
#   --> This file is 23.2kB.
# 2015 Nominees 	 best_hall-of-fame-nom-2015.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2015.html
#   --> This file is 19.2kB.
# 2014 Nominees 	 best_hall-of-fame-nom-2014.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2014.html
#   --> This file is 21.6kB.
# 2013 Nominees 	 best_hall-of-fame-nom-2013.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2013.html
#   --> This file is 20.5kB.
# 2012 Nominees 	 best_hall-of-fame-nom-2012.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2012.html
#   --> This file is 20.5kB.
# 2011 Nominees 	 best_hall-of-fame-nom-2011.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2011.html
#   --> This file is 17.8kB.
# 2010 Nominees 	 best_hall-of-fame-nom-2010.html
# Now Downloading https://digitaldreamdoor.com/pages/best_hall-of-fame-nom-2010.html
#   --> This file is 16.4kB.
# Rock & Roll Hall of Fame Candidates A-C 	 best_halloffame_x1.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x1.html
#   --> This file is 12.5kB.
# Rock & Roll Hall of Fame Candidates C-F 	 best_halloffame_x2.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x2.html
#   --> This file is 11.2kB.
# Rock & Roll Hall of Fame Candidates F-K 	 best_halloffame_x3.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x3.html
#   --> This file is 13.5kB.
# Rock & Roll Hall of Fame Candidates K-P 	 best_halloffame_x4.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x4.html
#   --> This file is 12.9kB.
# Rock & Roll Hall of Fame Candidates P-S 	 best_halloffame_x5.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x5.html
#   --> This file is 12.2kB.
# Rock & Roll Hall of Fame Candidates T-Z 	 best_halloffame_x6.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_x6.html
#   --> This file is 13.4kB.
# 50 Unlikely Candidates 	 best_halloffame_xlf.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_xlf.html
#   --> This file is 16.3kB.
# Sidemen Candidates 	 best_halloffame_side.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_side.html
#   --> This file is 16.0kB.
# Early Influences 	 best_halloffame_early.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_early.html
#   --> This file is 15.8kB.
# Outside Genre Possibilities 	 best_halloffame_out.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_out.html
#   --> This file is 7.9kB.
# Non-Performers 	 best_halloffame_non.html
# Now Downloading https://digitaldreamdoor.com/pages/best_halloffame_non.html
#   --> This file is 18.2kB.
# Rock 'n' Roll Timeline 	 best_timeline-r1.html
# Now Downloading https://digitaldreamdoor.com/pages/best_timeline-r1.html
#   --> This file is 17.9kB.
# Rap/Hip-Hop Timeline 	 best_rap-timeline1.html
# Now Downloading https://digitaldreamdoor.com/pages/best_rap-timeline1.html
#   --> This file is 15.1kB.
# Dance/Electronic Timeline 	 best_timeline-elec.html
# Now Downloading https://digitaldreamdoor.com/pages/best_timeline-elec.html
#   --> This file is 18.9kB.
# Woodstock '69 Lineup/Songlist 	 music0_woodstock.html
# Now Downloading https://digitaldreamdoor.com/pages/music0_woodstock.html
#   --> This file is 22.2kB.
# Music Stars Real Names 	 realname.html
# Now Downloading https://digitaldreamdoor.com/pages/realname.html
#   --> This file is 17.1kB.
# Music Stars Birthdays 	 musicbirthdays.html
# Now Downloading https://digitaldreamdoor.com/pages/musicbirthdays.html
#   --> This file is 16.4kB.
# Band Name Origins 	 music0_name.html
# Now Downloading https://digitaldreamdoor.com/pages/music0_name.html
#   --> This file is 17.6kB.
# Original Names of Bands 	 Original-Names-of-Bands.html
# Now Downloading https://digitaldreamdoor.com/pages/Original-Names-of-Bands.html
#   --> This file is 8.9kB.
# First Bands Archive 	 best_firstband.html
# Now Downloading https://digitaldreamdoor.com/pages/best_firstband.html
#   --> This file is 10.7kB.

# %%
from searchUtilstilstils import findExt
files = findExt("digitaldreamdoor", ".p")
files
# Out:
# ['digitaldreamdoor/chess_records.html.p',
#  'digitaldreamdoor/bg_hits_bg_hits_68.html.p',
#  'digitaldreamdoor/best_rb-song-90s.html.p',
#  'digitaldreamdoor/best_artists-indie.html.p',
#  'digitaldreamdoor/best_artists-bio_tool.html.p',
#  'digitaldreamdoor/best-classic-wks.html.p',
#  'digitaldreamdoor/best_hall-of-fame-nom-2014.html.p',
#  'digitaldreamdoor/bg_hits_bg_hits
#  'digitaldreamdoor/albums_by_year_albums_2015.html.p',
#  'digitaldreamdoor/bg_hits_bg_hits_49.html.p']

# %% [markdown]
# # PopRadioTop20

# %%
url="https://www.popradiotop20.com/Year/RR.htm"
savename = "popradiotop20.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.popradiotop20.com/Year/RR.htm
#   --> This file is 3.4kB.

# %%
bsdata = getHTML(savename)

# %%
for table in bsdata.findAll("table"):
    for tr in table.findAll("tr"):
        for td in tr.findAll("td"):
            ref = td.find("a")
            if ref is None:
                continue
            href = ref.attrs['href']
            url = "https://www.popradiotop20.com/Year/{0}".format(href)
            savename = "popradiotop20/{0}.p".format(href.replace(".htm", ""))
            if not isFile(savename):
                data, code = downloadURL(url)
                saveFile(idata=data, ifile=savename)
                sleep(3)
# Out:
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1976-Year.htm
#   --> This file is 2.7kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1976-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1976-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1977-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1977-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1977-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1978-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1978-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1978-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1979-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1979-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1979-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1980-Year.htm
#   --> This file is 2.8kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1980-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1980-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1981-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1981-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1981-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1982-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1982-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1982-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1982-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1983-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1983-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1983-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1983-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1984-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1984-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1984-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1984-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1985-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1985-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1985-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1985-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1986-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1986-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1986-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1986-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1987-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1987-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1987-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1987-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1988-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1988-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1988-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1988-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1989-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1989-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1989-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1989-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1990-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1990-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1990-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1990-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1991-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1991-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1991-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1991-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1992-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1992-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1992-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1992-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1993-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1993-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1993-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1993-Year.htm
#   --> This file is 2.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CHR-1994-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1994-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1994-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1994-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-1995-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1995-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1995-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1995-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-1996-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1996-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1996-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1996-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-1997-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1997-Year.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1997-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1997-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-1998-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1998-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1998-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1998-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-1999-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-1999-Year.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-1999-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-1999-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2000-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2000-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2000-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2000-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2001-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2001-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2001-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2001-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2002-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2002-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2002-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2002-Year.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2003-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2003-Year.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2003-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2003-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2004-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2004-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2004-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2004-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-POP-2005-Year.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-AC-2005-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-COU-2005-Year.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-URB-2005-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2006.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2006.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2006.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2006.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2007.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2007.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2007.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2007.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2008.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2008.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2008.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2008.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2009.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2009.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2009.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2009.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2011.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2011.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2011.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2011.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2012.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2012.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2012.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2012.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2013.htm
#   --> This file is 2.1kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2013.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2013.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-URB-2013.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-POP-2014.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AC-2014.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-COU-2014.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB
htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-JAZZ-2007.htm
#   --> This file is 3.3kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2008.htm
#   --> This file is 3.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2008.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2008.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-JAZZ-2008.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2009.htm
#   --> This file is 3.2kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2009.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2009.htm
#   --> This file is 3.4kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-JAZZ-2009.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2010.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2010.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-JAZZ-2010.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2011.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2011.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2011.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2012.htm
#   --> This file is 1.8kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2012.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2012.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2013.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2013.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2013.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2014.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2014.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2014.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2015.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2015.htm
#   --> This file is 1.8kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2015.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2016.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2016.htm
#   --> This file is 1.8kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2016.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2017.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2017.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2017.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AR-2018.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-UAC-2018.htm
#   --> This file is 1.8kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-AAA-2018.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CAC-2002-Year.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CAC-2003-Year.htm
#   --> This file is 1.2kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CAC-2004-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/RR-CAC-2005-Year.htm
#   --> This file is 3.1kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2006.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2007.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2008.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2009.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2010.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2011.htm
#   --> This file is 1.8kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2012.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2013.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2014.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2015.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2016.htm
#   --> This file is 2.0kB.
# Now Downloading https://www.popradiotop20.com/Year/MB-CAC-2017.htm
#   --> This file is 1.9kB.
# Now Downloading https://www.popradiotop20.com/Year/../index.htm
#   --> This file is 1.0kB.

# %%
from searchUtils import findExt
popradioData = {}
files = findExt("popradiotop20", ".p")
for ifile in files:
    bsdata = getHTML(ifile)
    retval = getPopRadioData(bsdata)
    chartName = retval["Chart"]
    year      = retval["Year"]
    songs     = retval["Songs"]
    if popradioData.get(chartName) is None:
        popradioData[chartName] = {}
    popradioData[chartName][year] = songs
    print("{0: <40}{1: <40}{2: <10}{3}".format(ifile,chartName,year,len(songs)))
# Out:
# popradiotop20/MB-CAC-2015.p             Mediabase Christian AC                  2015      50
# popradiotop20/RR-HAC-2004-Year.p        Radio & Records Hot AC                  2004      100
# popradiotop20/RR-POP-2003-Year.p        Radio & Records CHR/Pop                 2003      100
# popradiotop20/MB-ROCK-2011.p            Mediabase Mainstream Rock               2011      50
# popradiotop20/MB-RHY-2010.p             Mediabase Rhythmic                      2010      50
# popradiotop20/MB-JAZZ-2010.p            Mediabase Smooth AC                     2010      50
# popradiotop20/RR-CHR-1976-Year.p        Radio & Records Top-40                  1976      76
# popradiotop20/MB-AAA-2017.p             Mediabase Triple A                      2017      50
# popradiotop20/RR-URB-1996-Year.p        Radio & Records Urban                   1996      96
# popradiotop20/MB-URB-2009.p             Mediabase Urban                         2009      100
# popradiotop20/MB-HAC-2011.p             Mediabase Hot AC                        2011      50
# popradiotop20/MB-AR-2015.p              Mediabase Active Rock                   2015      50
# popradiotop20/MB-COU-2007.p             Mediabase Country                       2007      100
# popradiotop20/RR-URB-1988-Year.p        Radio & Records Urban                   1988      88
# popradiotop20/RR-ALT-2005-Year.p        Radio & Records Alternative             2005      100
# popradiotop20/RR-AC-2002-Year.p         Radio & Records AC                      2002      100
# popradiotop20/MB-UAC-2013.p             Mediabase Urban AC                      2013      50
# popradiotop20/RR-URB-1984-Year.p        Radio & Records Black/Urban             1984      84
# popradiotop20/RR-AC-1977-Year.p         Radio & Records Pop/Adult               1977      77
# popradiotop20/RR-CAC-2005-Year.p        Radio & Records Christian AC            2005      100
# popradiotop20/RR-RHY-2004-Year.p        Radio & Records CHR/Rhythmic            2004      100
# popradiotop20/MB-POP-2015.p             Mediabase Top 40                        2015      50
# popradiotop20/MB-ALT-2014.p             Mediabase Alternative                   2014      50
# popradiotop20/RR-POP-1997-Year.p        Radio & Records CHR/Pop                 1997      97
# popradiotop20/MB-URB-2007.p             Mediabase Urban                         2007      100
# popradiotop20/MB-UAC-2017.p             Mediabase Urban AC                      2017      50
# popradiotop20/MB-POP-2011.p             Mediabase Top 40                        2011      50
# popradiotop20/MB-ALT-2010.p             Mediabase Alternative                   2010      50
# popradiotop20/MB-COU-2009.p             Mediabase Country                       2009      100
# popradiotop20/MB-AAA-2013.p             Mediabase Triple A                      2013      50
# popradiotop20/MB-RHY-2014.p             Mediabase Rhythmic                      2014      50
# popradiotop20/RR-AAA-2005-Year.p        Radio & Records Triple A                2005      100
# popradiotop20/MB-AR-2011.p              Mediabase Active Rock                   2011      50
# popradiotop20/MB-HAC-2015.p             Mediabase Hot AC                        2015      50
# popradiotop20/RR-ROCK-1992-Year.p       Radio & Records AOR                     1992      92
# popradiotop20/MB-ROCK-2015.p            Mediabase Rock                          2015      50
# popradiotop20/RR-CHR-1989-Year.p        Radio & Records CHR                     1989      89
# popradiotop20/RR-COU-1980-Year.p        Radio & Records Country                 1980      80
# popradiotop20/RR-AC-1984-Year.p         Radio & Records Adult/Contemporary      1984      84
# popradiotop20/RR-URB-2002-Year.p        Radio & Records Urban                   2002      100
# popradiotop20/RR-AC-1988-Year.p         Radio & Records AC                      1988      88
# popradiotop20/MB-CAC-2011.p             Mediabase Christian AC                  2011      50
# popradiotop20/RR-COU-1992-Year.p        Radio & Records Country                 1992      92
# popradiotop20/RR-AC-1996-Year.p         Radio & Records AC                      1996      96
# popradiotop20/RR-CHR-1985-Year.p        Radio & Records Contemporary Hit Radio  1985      85
# popradiotop20/RR-POP-1999-Year.p        Radio & Records CHR/Pop                 1999      99
# popradiotop20/MB-URB-2017.p             Mediabase Urban                         2017      50
# popradiotop20/MB-UAC-2007.p             Mediabase Urban AC                      2007      100
# popradiotop20/MB-AAA-2009.p             Mediabase Triple A                      2009      100
# popradiotop20/RR-UAC-2005-Year.p        Radio & Records Urban AC                2005      100
# popradiotop20/RR-POP-1995-Year.p        Radio & Records CHR/Pop                 1995      95
# popradiotop20/MB-COU-2013.p             Mediabase Country                       2013      50
# popradiotop20/RR-AR-2005-Year.p         Radio & Records Active Rock             2005      100
# popradiotop20/RR-AC-1994-Year.p         Radio & Records AC                      1994      94
# popradiotop20/RR-COU-1990-Year.p        Radio & Records Country                 1990      90
# popradiotop20/RR-CHR-1987-Year.p        Radio & Records Contemporary Hit Radio  1987      87
# popradiotop20/MB-AC-2010.p              Mediabase AC                            2010      50
# popradiotop20/RR-AC-1986-Year.p         Radio & Records Adult Contemporary      1986      86
# popradiotop20/RR-COU-1982-Year.p        Radio & Records Country                 1982      82
# popradiotop20/RR-URB-2000-Year.p        Radio & Records Urban                   2000      100
# popradiotop20/RR-AC-1998-Year.p         Radio & Records AC                      1998      98
# popradiotop20/RR-ROCK-1990-Year.p       Radio & Records AOR                     1990      90
# popradiotop20/MB-AC-2014.p              Mediabase AC                            2014      50
# popradiotop20/RR-POP-2001-Year.p        Radio & Records CHR/Pop                 2001      100
# popradiotop20/RR-CHR-1978-Year.p        Radio & Records Top-40                  1978      78
# popradiotop20/RR-JAZZ-2004-Year.p       Radio & Records Smooth Jazz             2004      100
# popradiotop20/RR-URB-1998-Year.p        Radio & Records Urban                   1998      98
# popradiotop20/MB-AAA-2007.p             Mediabase Triple A                      2007      100
# popradiotop20/MB-UAC-2009.p             Mediabase Urban AC                      2009      50
# popradiotop20/RR-COU-2004-Year.p        Radio & Records Country                 2004      100
# popradiotop20/RR-AC-2000-Year.p         Radio & Records AC                      2000      100
# popradiotop20/MB-COU-2017.p             Mediabase Country                       2017      50
# popradiotop20/RR-URB-1986-Year.p        Radio & Records Black/Urban             1986      86
# popradiotop20/MB-URB-2013.p             Mediabase Urban                         2013      50
# popradiotop20/RR-ROCK-2004-Year.p       Radio & Records Rock                    2004      100
# popradiotop20/RR-AC-1979-Year.p         Radio & Records Pop/Adult               1979      79
# popradiotop20/RR-URB-1994-Year.p        Radio & Records Urban                   1994      94
# popradiotop20/RR-URB-2004-Year.p        Radio & Records Urban                   2004      100
# popradiotop20/RR-JAZZ-1998-Year.p       Radio & Records NAC/Smooth Jazz         1998      98
# popradiotop20/MB-AAA-2014.p             Mediabase Triple A                      2014      50
# popradiotop20/RR-CHR-1991-Year.p        Radio & Records CHR                     1991      91
# popradiotop20/RR-AC-1982-Year.p         Radio & Records Adult/Contemporary      1982      82
# popradiotop20/RR-COU-1986-Year.p        Radio & Records Country                 1986      86
# popradiotop20/MB-RHY-2013.p             Mediabase Rhythmic                      2013      50
# popradiotop20/RR-ALT-1997-Year.p        Radio & Records Alternative             1997      97
# popradiotop20/MB-AR-2016.p              Mediabase Active Rock                   2016      50
# popradiotop20/RR-COU-1998-Year.p        Radio & Records Country                 1998      98
# popradiotop20/RR-ROCK-1994-Year.p       Radio & Records Rock                    1994      94
# popradiotop20/MB-HAC-2012.p             Mediabase Hot AC                        2012      50
# popradiotop20/RR-CHR-1983-Year.p        Radio & Records Contemporary Hit Radio  1983      83
# popradiotop20/MB-UAC-2010.p             Mediabase Urban AC                      2010      50
# popradiotop20/RR-ROCK-1998-Year.p       Radio & Records Rock                    1998      98
# popradiotop20/RR-AC-1990-Year.p         Radio & Records AC                      1990      90
# popradiotop20/RR-COU-1994-Year.p        Radio & Records Country                 1994      94
# popradiotop20/MB-HAC-2018.p             Mediabase Hot AC                        2018      50
# popradiotop20/MB-ALT-2017.p             Mediabase Alternative                   2017      50
# popradiotop20/MB-POP-2016.p             Mediabase Top 40                        2016      50
# popradiotop20/RR-RHY-1996-Year.p        Radio & Records CHR/Rhythmic            1996      96
# popradiotop20/RR-ROCK-1986-Year.p       Radio & Records AOR                     1986      86
# popradiotop20/MB-AC-2007.p              Mediabase AC                            2007      100
# popradiotop20/RR-HAC-1996-Year.p        Radio & Records Hot AC                  1996      96
# popradiotop20/RR-UAC-2001-Year.p        Radio & Records Urban AC                2001      100
# popradiotop20/MB-CAC-2016.p             Mediabase Christian AC                  2016      50
# popradiotop20/RR-AR-2001-Year.p         Radio & Records Active Rock             2001      100
# popradiotop20/MB-ROCK-2012.p            Mediabase Mainstream Rock               2012      50
# popradiotop20/RR-AAA-2003-Year.p        Radio & Records Triple A                2003      100
# popradiotop20/MB-AC-2009.p              Mediabase AC                            2009      50
# popradiotop20/RR-ALT-2003-Year.p        Radio & Records Alternative             2003      100
# popradiotop20/RR-COU-1979-Year.p        Radio & Records Country                 1979      79
# popradiotop20/RR-ROCK-2000-Year.p       Radio & Records Rock                    2000      100
# popradiotop20/RR-URB-1990-Year.p        Radio & Records Urban                   1990      90
# popradiotop20/RR-JAZZ-2000-Year.p       Radio & Records NAC/Smooth Jazz         2000      100
# popradiotop20/MB-CAC-2012.p             Mediabase Christian AC                  2012      50
# popradiotop20/RR-CAC-2003-Year.p        Radio & Records Christian AC            2003      25
# popradiotop20/RR-RHY-2002-Year.p        Radio & Records CHR/Rhythmic            2002      100
# popradiotop20/RR-URB-1982-Year.p        Radio & Records Black Radio             1982      82
# popradiotop20/RR-COU-2000-Year.p        Radio & Records Country                 2000      100
# popradiotop20/RR-AC-2004-Year.p         Radio & Records AC                      2004      100
# popradiotop20/MB-UAC-2014.p             Mediabase Urban AC                      2014      50
# popradiotop20/RR-POP-2005-Year.p        Radio & Records CHR/Pop                 2005      100
# popradiotop20/MB-AR-2018.p              Mediabase Active Rock                   2018      50
# popradiotop20/RR-HAC-2002-Year.p        Radio & Records Hot AC                  2002      100
# popradiotop20/MB-ALT-2013.p             Mediabase Alternative                   2013      50
# popradiotop20/MB-POP-2012.p             Mediabase Top 40                        2012      50
# popradiotop20/RR-AAA-1997-Year.p        Radio & Records Adult Alternative       1997      97
# popradiotop20/MB-RHY-2017.p             Mediabase Rhythmic                      2017      50
# popradiotop20/RR-UAC-1999-Year.p        Radio & Records Urban AC                1999      99
# popradiotop20/MB-AAA-2010.p             Mediabase Triple A                      2010      50
# popradiotop20/MB-POP-2018.p             Mediabase Top 40                        2018      50
# popradiotop20/MB-HAC-2016.p             Mediabase Hot AC                        2016      50
# popradiotop20/RR-AR-1999-Year.p         Radio & Records Active Rock             1999      99
# popradiotop20/MB-AR-2012.p              Mediabase Active Rock                   2012      50
# popradiotop20/RR-COU-1977-Year.p        Radio & Records Country                 1977      77
# popradiotop20/MB-ROCK-2006.p            Mediabase Mainstream Rock               2006      100
# popradiotop20/MB-CAC-2008.p             Mediabase Christian AC                  2008      50
# popradiotop20/RR-COU-2002-Year.p        Radio & Records Country                 2002      100
# popradiotop20/RR-JAZZ-2002-Year.p       Radio & Records Smooth Jazz             2002      100
# popradiotop20/RR-RHY-2000-Year.p        Radio & Records CHR/Rhythmic            2000      100
# popradiotop20/RR-URB-1992-Year.p        Radio & Records Urban                   1992      92
# popradiotop20/MB-AC-2013.p              Mediabase AC                            2013      50
# popradiotop20/RR-ALT-2001-Year.p        Radio & Records Alternative             2001      100
# popradiotop20/RR-ROCK-2002-Year.p       Radio & Records Rock                    2002      100
# popradiotop20/MB-URB-2014.p             Mediabase Urban                         2014      50
# popradiotop20/MB-AR-2008.p              Mediabase Active Rock                   2008      100
# popradiotop20/RR-AAA-1999-Year.p        Radio & Records Adult Alternative       1999      99
# popradiotop20/MB-RHY-2007.p             Mediabase Rhythmic                      2007      100
# popradiotop20/MB-JAZZ-2007.p            Mediabase Smooth AC                     2007      100
# popradiotop20/RR-HAC-2000-Year.p        Radio & Records Hot AC                  2000      100
# popradiotop20/RR-UAC-1997-Year.p        Radio & Records Urban AC                1997      97
# popradiotop20/MB-ALT-2009.p             Mediabase Alternative                   2009      100
# popradiotop20/MB-POP-2008.p             Mediabase Top 40                        2008      100
# popradiotop20/MB-HAC-2006.p             Mediabase Hot AC                        2006      100
# popradiotop20/RR-AR-1997-Year.p         Radio & Records Active Rock             1997      97
# popradiotop20/MB-COU-2010.p             Mediabase Country                       2010      50
# popradiotop20/RR-JAZZ-1996-Year.p       Radio & Records NAC                     1996      96
# popradiotop20/RR-ROCK-1984-Year.p       Radio & Records AOR                     1984      84
# popradiotop20/RR-COU-1988-Year.p        Radio & Records Country                 1988      88
# popradiotop20/RR-CHR-1981-Year.p        Radio & Records Contemporary Hit Radio  1981      81
# popradiotop20/MB-COU-2014.p             Mediabase Country                       2014      50
# popradiotop20/RR-ALT-1999-Year.p        Radio & Records Alternative             1999      99
# popradiotop20/MB-AR-2006.p              Mediabase Active Rock                   2006      100
# popradiotop20/RR-COU-1996-Year.p        Radio & Records Country                 1996      96
# popradiotop20/RR-AC-1992-Year.p         Radio & Records AC                      1992      92
# popradiotop20/RR-ALT-1995-Year.p        Radio & Records Alternative             1995      95
# popradiotop20/MB-JAZZ-2009.p            Mediabase Smooth AC                     2009      50
# popradiotop20/MB-RHY-2009.p             Mediabase Rhythmic                      2009      100
# popradiotop20/RR-ROCK-1996-Year.p       Radio & Records Rock                    1996      96
# popradiotop20/MB-URB-2010.p             Mediabase Urban                         2010      50
# popradiotop20/MB-HAC-2008.p             Mediabase Hot AC                        2008      100
# popradiotop20/RR-CHR-1993-Year.p        Radio & Records CHR                     1993      93
# popradiotop20/MB-POP-2006.p             Mediabase Top 40                        2006      100
# popradiotop20/MB-ALT-2007.p             Mediabase Alternative                   2007      100
# popradiotop20/RR-COU-1984-Year.p        Radio & Records Country                 1984      84
# popradiotop20/RR-AC-1980-Year.p         Radio & Records Pop/Adult               1980      80
# popradiotop20/RR-RHY-1998-Year.p        Radio & Records CHR/Rhythmic            1998      98
# popradiotop20/RR-ROCK-1988-Year.p       Radio & Records AOR                     1988      88
# popradiotop20/RR-AAA-2001-Year.p        Radio & Records Triple A                2001      100
# popradiotop20/MB-AC-2017.p              Mediabase AC                            2017      50
# popradiotop20/RR-HAC-1998-Year.p        Radio & Records Hot AC                  1998      98
# popradiotop20/MB-ROCK-2008.p            Mediabase Mainstream Rock               2008      50
# popradiotop20/MB-CAC-2006.p             Mediabase Christian AC                  2006      50
# popradiotop20/RR-AR-2003-Year.p         Radio & Records Active Rock             2003      100
# popradiotop20/RR-UAC-2003-Year.p        Radio & Records Urban AC                2003      100
# popradiotop20/RR-URB-2003-Year.p        Radio & Records Urban                   2003      100
# popradiotop20/RR-AC-1985-Year.p         Radio & Records Adult/Contemporary      1985      85
# popradiotop20/RR-COU-1981-Year.p        Radio & Records Country                 1981      81
# popradiotop20/MB-POP-2017.p             Mediabase Top 40                        2017      50
# popradiotop20/MB-ALT-2016.p             Mediabase Alternative                   2016      50
# popradiotop20/MB-UAC-2011.p             Mediabase Urban AC                      2011      50
# popradiotop20/RR-CHR-1988-Year.p        Radio & Records CHR                     1988      88
# popradiotop20/MB-RHY-2018.p             Mediabase Rhythmic                      2018      50
# popradiotop20/RR-ROCK-1993-Year.p       Radio & Records AOR                     1993      93
# popradiotop20/RR-CHR-1984-Year.p        Radio & Records Contemporary Hit Radio  1984      84
# popradiotop20/MB-HAC-2013.p             Mediabase Hot AC                        2013      50
# popradiotop20/RR-AC-1997-Year.p         Radio & Records AC                      1997      97
# popradiotop20/RR-COU-1993-Year.p        Radio & Records Country                 1993      93
# popradiotop20/MB-AR-2017.p              Mediabase Active Rock                   2017      50
# popradiotop20/MB-RHY-2012.p             Mediabase Rhythmic                      2012      50
# popradiotop20/RR-AC-1989-Year.p         Radio & Records AC                      1989      89
# popradiotop20/MB-AAA-2015.p             Mediabase Triple A                      2015      50
# popradiotop20/MB-ROCK-2013.p            Mediabase Mainstream Rock               2013      50
# popradiotop20/RR-POP-1996-Year.p        Radio & Records CHR/Pop                 1996      96
# popradiotop20/RR-AAA-2004-Year.p        Radio & Records Triple A                2004      100
# popradiotop20/MB-CAC-2017.p             Mediabase Christian AC                  2017      50
# popradiotop20/MB-AC-2006.p              Mediabase AC                            2006      100
# popradiotop20/RR-URB-1989-Year.p        Radio & Records Urban                   1989      89
# popradiotop20/RR-ALT-2004-Year.p        Radio & Records Alternative             2004      100
# popradiotop20/RR-URB-1997-Year.p        Radio & Records Urban                   1997      97
# popradiotop20/RR-CHR-1977-Year.p        Radio & Records Top-40                  1977      77
# popradiotop20/MB-CAC-2013.p             Mediabase Christian AC                  2013      50
# popradiotop20/RR-RHY-2005-Year.p        Radio & Records CHR/Rhythmic            2005      100
# popradiotop20/RR-CAC-2004-Year.p        Radio & Records Christian AC            2004      100
# popradiotop20/RR-URB-1985-Year.p        Radio & Records Black/Urban             1985      85
# popradiotop20/RR-AC-1976-Year.p         Radio & Records Pop/Adult               1976      76
# popradiotop20/MB-AC-2008.p              Mediabase AC                            2008      50
# popradiotop20/RR-AC-2003-Year.p         Radio & Records AC                      2003      100
# popradiotop20/MB-AR-2013.p              Mediabase Active Rock                   2013      50
# popradiotop20/RR-POP-2002-Year.p        Radio & Records CHR/Pop                 2002      100
# popradiotop20/MB-ALT-2018.p             Mediabase Alternative                   2018      50
# popradiotop20/MB-HAC-2017.p             Mediabase Hot AC                        2017      50
# popradiotop20/MB-AAA-2011.p             Mediabase Triple A                      2011      50
# popradiotop20/RR-HAC-2005-Year.p        Radio & Records Hot AC                  2005      100
# popradiotop20/MB-RHY-2016.p             Mediabase Rhythmic                      2016      50
# popradiotop20/MB-POP-2013.p             Mediabase Top 40                        2013      50
# popradiotop20/MB-ALT-2012.p             Mediabase Alternative                   2012      50
# popradiotop20/MB-UAC-2015.p             Mediabase Urban AC                      2015      50
# popradiotop20/RR-URB-1987-Year.p        Radio & Records Urban Contemporary      1987      87
# popradiotop20/RR-AC-2001-Year.p         Radio & Records AC                      2001      100
# popradiotop20/RR-COU-2005-Year.p        Radio & Records Country                 2005      100
# popradiotop20/RR-JAZZ-2005-Year.p       Radio & Records Smooth Jazz             2005      100
# popradiotop20/RR-URB-1999-Year.p        Radio & Records Urban                   1999      99
# popradiotop20/MB-AC-2012.p              Mediabase AC                            2012      50
# popradiotop20/RR-CHR-1979-Year.p        Radio & Records Top-40                  1979      79
# popradiotop20/RR-URB-1995-Year.p        Radio & Records Urban                   1995      95
# popradiotop20/MB-CAC-2009.p             Mediabase Christian AC                  2009      50
# popradiotop20/MB-ROCK-2007.p            Mediabase Mainstream Rock               2007      100
# popradiotop20/RR-AC-1978-Year.p         Radio & Records Pop/Adult               1978      78
# popradiotop20/RR-ROCK-2005-Year.p       Radio & Records Rock                    2005      100
# popradiotop20/MB-AC-2018.p              Mediabase AC                            2018      50
# popradiotop20/MB-COU-2011.p             Mediabase Country                       2011      50
# popradiotop20/MB-POP-2009.p             Mediabase Top 40                        2009      100
# popradiotop20/MB-ALT-2008.p             Mediabase Alternative                   2008      100
# popradiotop20/MB-HAC-2007.p             Mediabase Hot AC                        2007      100
# popradiotop20/MB-JAZZ-2006.p            Mediabase Smooth Jazz                   2006      50
# popradiotop20/MB-RHY-2006.p             Mediabase Rhythmic                      2006      100
# popradiotop20/MB-AR-2009.p              Mediabase Active Rock                   2009      100
# popradiotop20/RR-POP-2000-Year.p        Radio & Records CHR/Pop                 2000      100
# popradiotop20/MB-URB-2015.p             Mediabase Urban                         2015      50
# popradiotop20/MB-HAC-2009.p             Mediabase Hot AC                        2009      100
# popradiotop20/RR-ROCK-1983-Year.p       Radio & Records AOR                     1983      83
# popradiotop20/MB-ALT-2006.p             Mediabase Alternative                   2006      100
# popradiotop20/MB-POP-2007.p             Mediabase Top 40                        2007      100
# popradiotop20/MB-URB-2011.p             Mediabase Urban                         2011      50
# popradiotop20/RR-CHR-1986-Year.p        Radio & Records Contemporary Hit Radio  1986      86
# popradiotop20/MB-RHY-2008.p             Mediabase Rhythmic                      2008      100
# popradiotop20/MB-JAZZ-2008.p            Mediabase Smooth AC                     2008      50
# popradiotop20/RR-COU-1991-Year.p        Radio & Records Country                 1991      91
# popradiotop20/RR-AC-1995-Year.p         Radio & Records AC                      1995      95
# popradiotop20/MB-COU-2015.p             Mediabase Country                       2015      50
# popradiotop20/RR-AC-1999-Year.p         Radio & Records AC                      1999      99
# popradiotop20/MB-AR-2007.p              Mediabase Active Rock                   2007      100
# popradiotop20/RR-ROCK-1991-Year.p       Radio & Records AOR                     1991      91
# popradiotop20/RR-URB-2001-Year.p        Radio & Records Urban                   2001      100
# popradiotop20/RR-CHR-1994-Year.p        Radio & Records CHR                     1994      94
# popradiotop20/RR-COU-1983-Year.p        Radio & Records Country                 1983      83
# popradiotop20/RR-AC-1987-Year.p         Radio & Records Adult Contemporary      1987      87
# popradiotop20/RR-POP-1998-Year.p        Radio & Records CHR/Pop                 1998      98
# popradiotop20/RR-AR-2004-Year.p         Radio & Records Active Rock             2004      100
# popradiotop20/MB-CAC-2007.p             Mediabase Christian AC                  2007      50
# popradiotop20/MB-ROCK-2009.p            Mediabase Mainstream Rock               2009      50
# popradiotop20/RR-UAC-2004-Year.p        Radio & Records Urban AC                2004      100
# popradiotop20/MB-AC-2016.p              Mediabase AC                            2016      50
# popradiotop20/RR-HAC-2003-Year.p        Radio & Records Hot AC                  2003      100
# popradiotop20/RR-POP-2004-Year.p        Radio & Records CHR/Pop                 2004      100
# popradiotop20/MB-ROCK-2010.p            Mediabase Mainstream Rock               2010      50
# popradiotop20/RR-AR-1998-Year.p         Radio & Records Active Rock             1998      98
# popradiotop20/RR-UAC-1998-Year.p        Radio & Records Urban AC                1998      98
# popradiotop20/RR-AAA-1996-Year.p        Radio & Records Adult Alternative       1996      96
# popradiotop20/MB-CAC-2014.p             Mediabase Christian AC                  2014      50
# popradiotop20/MB-ALT-2015.p             Mediabase Alternative                   2015      50
# popradiotop20/MB-POP-2014.p             Mediabase Top 40                        2014      50
# popradiotop20/RR-URB-1991-Year.p        Radio & Records Urban                   1991      91
# popradiotop20/RR-ROCK-2001-Year.p       Radio & Records Rock                    2001      100
# popradiotop20/RR-ALT-2002-Year.p        Radio & Records Alternative             2002      100
# popradiotop20/MB-UAC-2012.p             Mediabase Urban AC                      2012      50
# popradiotop20/RR-COU-1978-Year.p        Radio & Records Country                 1978      78
# popradiotop20/MB-AR-2014.p              Mediabase Active Rock                   2014      50
# popradiotop20/RR-AC-2005-Year.p         Radio & Records AC                      2005      100
# popradiotop20/RR-COU-2001-Year.p        Radio & Records Country                 2001      100
# popradiotop20/MB-COU-2006.p             Mediabase Country                       2006      100
# popradiotop20/MB-HAC-2010.p             Mediabase Hot AC                        2010      50
# popradiotop20/RR-URB-1983-Year.p        Radio & Records Black Radio             1983      83
# popradiotop20/MB-UAC-2018.p             Mediabase Urban AC                      2018      50
# popradiotop20/MB-AAA-2016.p             Mediabase Triple A                      2016      50
# popradiotop20/RR-RHY-2003-Year.p        Radio & Records CHR/Rhythmic            2003      100
# popradiotop20/MB-URB-2008.p             Mediabase Urban                         2008      100
# popradiotop20/RR-CAC-2002-Year.p        Radio & Records Christian AC            2002      50
# popradiotop20/MB-RHY-2011.p             Mediabase Rhythmic                      2011      50
# popradiotop20/RR-JAZZ-2001-Year.p       Radio & Records Smooth Jazz             2001      100
# popradiotop20/MB-HAC-2014.p             Mediabase Hot AC                        2014      50
# popradiotop20/MB-AR-2010.p              Mediabase Active Rock                   2010      50
# popradiotop20/RR-AR-2000-Year.p         Radio & Records Active Rock             2000      100
# popradiotop20/MB-RHY-2015.p             Mediabase Rhythmic                      2015      50
# popradiotop20/RR-HAC-1997-Year.p        Radio & Records Hot AC                  1997      97
# popradiotop20/RR-UAC-2000-Year.p        Radio & Records Urban AC                2000      100
# popradiotop20/MB-AAA-2012.p             Mediabase Triple A                      2012      50
# popradiotop20/MB-COU-2008.p             Mediabase Country                       2008      100
# popradiotop20/MB-ALT-2011.p             Mediabase Alternative                   2011      50
# popradiotop20/MB-POP-2010.p             Mediabase Top 40                        2010      50
# popradiotop20/RR-AAA-2002-Year.p        Radio & Records Triple A                2002      100
# popradiotop20/MB-URB-2006.p             Mediabase Urban                         2006      100
# popradiotop20/MB-AAA-2018.p             Mediabase Triple A                      2018      50
# popradiotop20/MB-UAC-2016.p             Mediabase Urban AC                      2016      50
# popradiotop20/RR-COU-1999-Year.p        Radio & Records Country                 1999      99
# popradiotop20/RR-ROCK-1995-Year.p       Radio & Records Rock                    1995      95
# popradiotop20/RR-ALT-1996-Year.p        Radio & Records Alternative             1996      96
# popradiotop20/MB-CAC-2010.p             Mediabase Christian AC                  2010      50
# popradiotop20/RR-COU-1987-Year.p        Radio & Records Country                 1987      87
# popradiotop20/RR-AC-1983-Year.p         Radio & Records Adult/Contemporary      1983      83
# popradiotop20/RR-URB-2005-Year.p        Radio & Records Urban                   2005      100
# popradiotop20/RR-JAZZ-1999-Year.p       Radio & Records NAC/Smooth Jazz         1999      99
# popradiotop20/RR-CHR-1990-Year.p        Radio & Records CHR                     1990      90
# popradiotop20/RR-RHY-1997-Year.p        Radio & Records CHR/Rhythmic            1997      97
# popradiotop20/RR-ROCK-1987-Year.p       Radio & Records AOR                     1987      87
# popradiotop20/RR-JAZZ-1995-Year.p       Radio & Records NAC                     1995      95
# popradiotop20/RR-ROCK-1999-Year.p       Radio & Records Rock                    1999      99
# popradiotop20/RR-COU-1995-Year.p        Radio & Records Country                 1995      95
# popradiotop20/RR-AC-1991-Year.p         Radio & Records AC                      1991      91
# popradiotop20/MB-ROCK-2014.p            Mediabase Rock                          2014      50
# popradiotop20/RR-CHR-1982-Year.p        Radio & Records Contemporary Hit Radio  1982      82
# popradiotop20/MB-COU-2012.p             Mediabase Country                       2012      50
# popradiotop20/RR-HAC-1999-Year.p        Radio & Records Hot AC                  1999      99
# popradiotop20/RR-AAA-2000-Year.p        Radio & Records Adult Alternative       2000      100
# popradiotop20/RR-UAC-2002-Year.p        Radio & Records Urban AC                2002      100
# popradiotop20/MB-COU-2018.p             Mediabase Country                       2018      50
# popradiotop20/RR-HAC-1995-Year.p        Radio & Records Hot AC                  1995      95
# popradiotop20/MB-URB-2016.p             Mediabase Urban                         2016      50
# popradiotop20/MB-UAC-2006.p             Mediabase Urban AC                      2006      100
# popradiotop20/MB-AAA-2008.p             Mediabase Triple A                      2008      100
# popradiotop20/RR-AR-2002-Year.p         Radio & Records Active Rock             2002      100
# popradiotop20/RR-AC-1993-Year.p         Radio & Records AC                      1993      93
# popradiotop20/RR-COU-1997-Year.p        Radio & Records Country                 1997      97
# popradiotop20/RR-CHR-1980-Year.p        Radio & Records Contemporary Hit Radio  1980      80
# popradiotop20/RR-ALT-1998-Year.p        Radio & Records Alternative             1998      98
# popradiotop20/RR-ROCK-1985-Year.p       Radio & Records AOR                     1985      85
# popradiotop20/RR-COU-1989-Year.p        Radio & Records Country                 1989      89
# popradiotop20/RR-RHY-1995-Year.p        Radio & Records CHR/Rhythmic            1995      95
# popradiotop20/RR-JAZZ-1997-Year.p       Radio & Records NAC/Smooth Jazz         1997      97
# popradiotop20/MB-AC-2011.p              Mediabase AC                            2011      50
# popradiotop20/RR-RHY-1999-Year.p        Radio & Records CHR/Rhythmic            1999      99
# popradiotop20/RR-AC-1981-Year.p         Radio & Records Adult/Contemporary      1981      81
# popradiotop20/RR-COU-1985-Year.p        Radio & Records Country                 1985      85
# popradiotop20/RR-ROCK-1989-Year.p       Radio & Records AOR                     1989      89
# popradiotop20/RR-CHR-1992-Year.p        Radio & Records CHR                     1992      92
# popradiotop20/RR-ROCK-1997-Year.p       Radio & Records Rock                    1997      97
# popradiotop20/RR-ALT-1994-Year.p        Radio & Records Alternative             1994      94
# popradiotop20/RR-AR-1996-Year.p         Radio & Records Active Rock             1996      96
# popradiotop20/MB-AC-2015.p              Mediabase AC                            2015      50
# popradiotop20/RR-HAC-2001-Year.p        Radio & Records Hot AC                  2001      100
# popradiotop20/RR-UAC-1996-Year.p        Radio & Records Urban AC                1996      96
# popradiotop20/RR-AAA-1998-Year.p        Radio & Records Adult Alternative       1998      98
# popradiotop20/RR-RHY-2001-Year.p        Radio & Records CHR/Rhythmic            2001      100
# popradiotop20/RR-JAZZ-2003-Year.p       Radio & Records Smooth Jazz             2003      100
# popradiotop20/RR-COU-2003-Year.p        Radio & Records Country                 2003      100
# popradiotop20/MB-URB-2012.p             Mediabase Urban                         2012      50
# popradiotop20/RR-COU-1976-Year.p        Radio & Records Country                 1976      76
# popradiotop20/RR-ROCK-2003-Year.p       Radio & Records Rock                    2003      100
# popradiotop20/MB-COU-2016.p             Mediabase Country                       2016      50
# popradiotop20/RR-ALT-2000-Year.p        Radio & Records Alternative             2000      100
# popradiotop20/MB-AAA-2006.p             Mediabase Triple A                      2006      100
# popradiotop20/MB-UAC-2008.p             Mediabase Urban AC                      2008      100
# popradiotop20/MB-URB-2018.p             Mediabase Urban                         2018      50
# popradiotop20/RR-URB-1993-Year.p        Radio & Records Urban                   1993      93

# %%
bsdata = getHTML("popradiotop20/MB-ALT-2017.p")
#bsdata
retval = getPopRadioData(bsdata, debug=True)
retval
# Out:
# <td align="left" bgcolor="#ffffff" bordercolor="#000000" bordercolordark="#000000" bordercolorlight="#000000" class="auto-style1" height="30" width="92%">
# <strong>Imagine Dragons</strong>  Believer</td>
# Imagine Dragons
# <td align="left" bgcolor="#ffffff" bordercolor="#000000" bordercolordark="#000000" bordercolorlight="#000000" class="auto-style1" height="30" width="92
# <td align="left" bgcolor="#ffffff" bordercolor="#000000" bordercolordark="#000000" bordercolorlight="#000000" class="auto-style1" height="30" width="92%">
# <strong>Mondo Cozmo</strong>  Shine</td>
# Mondo Cozmo
# <td align="left" bgcolor="#ffffff" bordercolor="#000000" bordercolordark="#000000" bordercolorlight="#000000" class="auto-style1" height="30" width="92%">
# <strong>Paramore</strong>  Hard Times</td>
# Paramore
# <td align="left" bgcolor="#ffffff" bordercolor="#000000" bordercolordark="#000000" bordercolorlight="#000000" class="auto-style1" height="30" width="92%">
# <strong>Bastille</strong>  Good Grief</td>
# Bastille
# {'Chart': 'Mediabase Alternative',
#  'Year': 2017,
#  'Songs': [{'Artists': ['Imagine Dragons'], 'Title': 'Believer'},
#   {'Artists': ['The Revivalists'], 'Title': 'Wish I Knew You'},
#   {'Artists': ['Portugal. The Man'], 'Title': 'Feel It Still'},
#   {'Artists': ['Judah & The Lion'], 'Title': 'Take It All Back'},
#   {'Artists': ["Rag'N'Bone Man"], 'Title': 'Human'},
#   {'Artists': ['Kings Of Leon'], 'Title': 'Waste A Moment'},
#   {'Artists': ['Green Day'], 'Title': 'Still Breathing'},
#   {'Artists': ['Twenty One Pilots'], 'Title': 'Heathens'},
#   {'Artists': ['Kaleo'], 'Title': 'Way Down We Go'},
#   {'Artists': ['Cage The Elephant'], 'Title': 'Trouble'},
#   {'Artists': ['Lumineers'], 'Title': 'Cleopatra'},
#   {'Artists': ['Cold War Kids'], 'Title': 'Love Is Mystical'},
#   {'Artists': ['Blink-182'], 'Title': "She's Out Of Her Mind"},
#   {'Artists': ['Sir Sly'], 'Title': 'High'},
#   {'Artists': ['Weezer'], 'Title': 'Feels Like Summer'},
#   {'Artists': ['Judah & The Lion'], 'Title': 'Suit & Jacket'},
#   {'Artists': ['Bastille'], 'Title': 'Blame'},
#   {'Artists': ['Andrew McMahon In Wilderness'], 'Title': 'Fire Escape'},
#   {'Artists': ['Killers'], 'Title': 'The Man'},
#   {'Artists': ['Dreamers'], 'Title': 'Sweet Disaster'},
#   {'Artists': ['Bleachers'], 'Title': "Don't Take The Money"},
#   {'Artists': ['Twenty One Pilots'], 'Title': 'Heavydirtysoul'},
#   {'Artists': ['Imagine Dragons'], 'Title': 'Thunder'},
#   {'Artists': ['The 1975'], 'Title': 'Somebody Else'},
#   {'Artists': ['Cage The Elephant'], 'Title': 'Cold Cold Cold'},
#   {'Artists': ['K.Flay'], 'Title': 'Blood In The Cut'},
#   {'Artists': ['Muse'], 'Title': 'Dig Down'},
#   {'Artists': ['Head And The Heart'], 'Title': 'All We Ever Knew'},
#   {'Artists': ['Kings Of Leon'], 'Title': 'Reverend'},
#   {'Artists': ['Catfish And The Bottlemen'], 'Title': '7'},
#   {'Artists': ['New Politics'], 'Title': 'One Of Us'},
#   {'Artists': ['Vance Joy'], 'Title': 'Lay It On Me'},
#   {'Artists': ['Red Hot Chili Peppers'], 'Title': 'Go Robot'},
#   {'Artists': ['Cage The Elephant'], 'Title': 'Whole Wide World'},
#   {'Artists': ['Lumineers'], 'Title': 'Angela'},
#   {'Artists': ['The Chainsmokers & Coldplay'],
#    'Title': 'Something Just Like This'},
#   {'Artists': ['Rise Against'], 'Title': 'The Violence'},
#   {'Artists': ['Missio'], 'Title': 'Middle Fingers'},
#   {'Artists': ['Thirty Seconds To Mars'], 'Title': 'Walk On Water'},
#   {'Artists': ['Queens Of The Stone Age'], 'Title': 'The Way You Used To Do'},
#   {'Artists': ['Coin'], 'Title': 'Talk Too Much'},
#   {'Artists': ['Empire Of The Sun'], 'Title': 'High And Low'},
#   {'Artists': ['Foo Fighters'], 'Title': 'Run'},
#   {'Artists': ['Grouplove'], 'Title': 'Welcome To Your Life'},
#   {'Artists': ['Highly Suspect'], 'Title': 'My Name Is Human'},
#   {'Artists': ['Lorde'], 'Title': 'Green Light'},
#   {'Artists': ['Bob Moses'], 'Title': 'Tearing Me Up'},
#   {'Artists': ['Mondo Cozmo'], 'Title': 'Shine'},
#   {'Artists': ['Paramore'], 'Title': 'Hard Times'},
#   {'Artists': ['Bastille'], 'Title': 'Good Grief'}]}

# %%
prt20 = popRadioData()
prt20.parse()
# Out:
# Found 373 files.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Triple_A.p
#   --> This file is 20.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Triple_A.p
#   --> This file is 20.3kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_AC.p
#   --> This file is 17.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_AC.p
#   --> This file is 17.3kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Alternative.p
#   --> This file is 19.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Alternative.p
#   --> This file is 19.3kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Active_Rock.p
#   --> This file is 18.6kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Active_Rock.p
#   --> This file is 18.6kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Christian_AC.p
#   --> This file is 13.1kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Christian_AC.p
#   --> This file is 13.1kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Country.p
#   --> This file is 19.7kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Country.p
#   --> This file is 19.7kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Hot_AC.p
#   --> This file is 19.9kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Hot_AC.p
#   --> This file is 19.9kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Smooth_Jazz.p
#   --> This file is 1.5kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Smooth_Jazz.p
#   --> This file is 1.5kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Smooth_AC.p
#   --> This file is 6.2kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Smooth_AC.p
#   --> This file is 6.2kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Top_40.p
#   --> This file is 20.8kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Top_40.p
#   --> This file is 20.8kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Rhythmic.p
#   --> This file is 20.8kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Rhythmic.p
#   --> This file is 20.8kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Mainstream_Rock.p
#   --> This file is 11.2kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Mainstream_Rock.p
#   --> This file is 11.2kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Rock.p
#   --> This file is 2.6kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Rock.p
#   --> This file is 2.6kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Urban_AC.p
#   --> This file is 17.9kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Urban_AC.p
#   --> This file is 17.9kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Urban.p
#   --> This file is 20.4kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Mediabase_Urban.p
#   --> This file is 20.4kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Alternative.p
#   --> This file is 12.2kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Alternative.p
#   --> This file is 12.2kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Triple_A.p
#   --> This file is 12.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Triple_A.p
#   --> This file is 12.3kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Pop_Adult.p
#   --> This file is 10.4kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Pop_Adult.p
#   --> This file is 10.4kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Contemporary.p
#   --> This file is 11.2kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Contemporary.p
#   --> This file is 11.2kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Contemporary.p
#   --> This file is 4.9kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Adult_Contemporary.p
#   --> This file is 4.9kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_AC.p
#   --> This file is 40.4kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_AC.p
#   --> This file is 40.4kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Alternative.p
#   --> This file is 26.6kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Alternative.p
#   --> This file is 26.6kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Active_Rock.p
#   --> This file is 21.6kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Active_Rock.p
#   --> This file is 21.6kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Christian_AC.p
#   --> This file is 6.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Christian_AC.p
#   --> This file is 6.3kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Top-40.p
#   --> This file is 8.4kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Top-40.p
#   --> This file is 8.4kB.
# Saving data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_Contemporary_Hit_Radio.p
#   --> This file is 17.3kB.
# Saved data to /Volumes/Piggy/Charts/data/popradiotop20/results/Radio___Records_
Steve Miller Band
Steve Winwood
Steven Tyler
Stevie Wonder
Sting
The Style Council
Styx
Sublime
Sum 41
Supertramp
Suzanne Vega
T
T-Bone Walker
T. Rex
Take That
Tammi Terrell
Tangerine Dream
Taylor Swift
Tears For Fears
Teena Marie
Temple Of The Dog
The Temptations
Tesla
Texas
Thelma Houston
Thelonious Monk
Thin Lizzy
Thomas Rhett
Three Dog Night
Tim McGraw
Toby Keith
Tom Jones
Tom Petty
Tom Waits
Toots & The Maytals
Tori Amos
Traffic
Traveling Wilburys
The Tubes
U
U2
UB40
Ultravox
Underworld
V
Van der Graaf Generator
Vangelis
The Velvet Underground
The Verve
Vince Gill
W
The Walker Brothers
Weezer
Wes Montgomery
Wet Wet Wet
will.i.am
Whitesnake
The Who
William Orbit
Willie Nelson
Wilson Pickett
Wishbone Ash
Wolfmother
Y
Yeah Yeah Yeahs
Yello
Yes
Z
Zucchero""".split("\n")

from string import ascii_uppercase
data = []
for line in txt:
    artist = line
    artist = artist.split(" (born")[0]
    artist = artist.split(" (1")[0]
    artist = artist.split(" (b")[0]
    artist = artist.split(" (c")[0]
    artist = artist.split(" (p")[0]
    artist = artist.split(", ")[0]
    artist = artist.split(" – ")[0]    
    artist = artist.split(" - ")[0]
    artist = artist.replace("(band)", "").strip()
    artist = artist.replace("(singer)", "").strip()
    artist = artist.replace("(group)", "").strip()
    artist = artist.replace("(rapper)", "").strip()
    if artist in ascii_uppercase:
        continue
        
    data.append(artist)

from pandas import Series
udiscovermusic = DataFrame(Series(data))
udiscovermusic.columns = ["Artists"]
udiscovermusic.head()
# Out:
#              Artists
# 0               10cc
# 1               2Pac
# 2            50 Cent
# 3  A Thousand Horses
# 4               ABBA

# %%
saveFile(idata=udiscovermusic, ifile="udiscovermusic/artists.p", debug=True)
# Out:
# Saving data to udiscovermusic/artists.p
#   --> This file is 7.0kB.
# Saved data to udiscovermusic/artists.p
#   --> This file is 7.0kB.

# %% [markdown]
# # MusixMatch

# %%
url="https://www.musixmatch.com/artist/La-Vida-Moderna"
savename = "musixmatch.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.musixmatch.com/artist/La-Vida-Moderna
#   --> This file is 25.4kB.

# %%
bsdata = getHTML("musixmatch.p")
bsdata
# Out:
# <!DOCTYPE html>
# <html class="artist-page-page" xmlns:og="http://ogp.me/ns#">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# musixmatch: http://ogp.me/ns/fb/musixmatch#">
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     window._mxm_ga_firstLoad = true; //flag page tracked on first load
#     ga('create', 'UA-16453829-10', 'auto');
#     ga('require', '');
#     ga('send', 'pageview');
#   </script>
# <script>(function () {/*
#
#   Copyright The Closure Library Authors.
#   SPDX-License-Identifier: Apache-2.0
#   */
#       'use strict'; var g = function (a) { var b = 0; return function () { return b < a.length ? { done: !1, value: a[b++] } : { done: !0 } } }, l = this || self, m = /^[\w+/_-]+[=]{0,2}$/, p = null, q = function () { }, r = function (a) {
#         var b = typeof a; if ("object" == b) if (a) {
#           if (a instanceof Array) return "array"; if (a instanceof Object) return b; var c = Object.prototype.toString.call(a); if ("[object Window]" == c) return "object"; if ("[object Array]" == c || "number" == typeof a.length && "undefined" != typeof a.splice && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("splice")) return "array";
#           if ("[object Function]" == c || "undefined" != typeof a.call && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("call")) return "function"
#         } else return "null"; else if ("function" == b && "undefined" == typeof a.call) return "object"; return b
#       }, u = function (a, b) { function c() { } c.prototype = b.prototype; a.prototype = new c; a.prototype.constructor = a }; var v = function (a, b) { Object.defineProperty(l, a, { configurable: !1, get: function () { return b }, set: q }) }; var y = function (a, b) { this.b = a === w && b || ""; this.a = x }, x = {}, w = {}; var aa = function (a, b) { a.src = b instanceof y && b.constructor === y && b.a === x ? b.b : "type_error:TrustedResourceUrl"; if (null === p) b: { b = l.document; if ((b = b.querySelector && b.querySelector("script[nonce]")) && (b = b.nonce || b.getAttribute("nonce")) && m.test(b)) { p = b; break b } p = "" } b = p; b && a.setAttribute("nonce", b) }; var z = function () { return Math.floor(2147483648 * Math.random()).toString(36) + Math.abs(Math.floor(2147483648 * Math.random()) ^ +new Date).toString(36) }; var A = function (a, b) { b = String(b); "application/xhtml+xml" === a.contentType && (b = b.toLowerCase()); return a.createElement(b) }, B = function (a) { this.a = a || l.document || document }; B.prototype.appendChild = function (a, b) { a.appendChild(b) }; var C = function (a, b, c, d, e, f) { try { var k = a.a, h = A(a.a, "SCRIPT"); h.async = !0; aa(h, b); k.head.appendChild(h); h.addEventListener("load", function () { e(); d && k.head.removeChild(h) }); h.addEventListener("error", function () { 0 < c ? C(a, b, c - 1, d, e, f) : (d && k.head.removeChild(h), f()) }) } catch (n) { f() } }; var ba = l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"), ca = l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="), da = l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"), ea = function (a, b, c) { this.b = a; this.f = new B(this.b); this.a = null; this.c = []; this.g = !1; this.i = b; this.h = c }, F = function (a) {
#         if (a.b.body && !a.g) {
#           var b =
#             function () { D(a); l.setTimeout(function () { return E(a, 3) }, 50) }; C(a.f, a.i, 2, !0, function () { l[a.h] || b() }, b); a.g = !0
#         }
#       }, D = function (a) {
#         for (var b = G(1, 5), c = 0; c < b; c++) { var d = H(a); a.b.body.appendChild(d); a.c.push(d) } b = H(a); b.style.bottom = "0"; b.style.left = "0"; b.style.position = "fixed"; b.style.width = G(100, 110).toString() + "%"; b.style.zIndex = G(2147483544, 2147483644).toString(); b.style["background-color"] = I(249, 259, 242, 252, 219, 229); b.style["box-shadow"] = "0 0 12px #888"; b.style.color = I(0, 10, 0, 10, 0, 10); b.style.display =
#           "flex"; b.style["justify-content"] = "center"; b.style["font-family"] = "Roboto, Arial"; c = H(a); c.style.width = G(80, 85).toString() + "%"; c.style.maxWidth = G(750, 775).toString() + "px"; c.style.margin = "24px"; c.style.display = "flex"; c.style["align-items"] = "flex-start"; c.style["justify-content"] = "center"; d = A(a.f.a, "IMG"); d.className = z(); d.src = ba; d.style.height = "24px"; d.style.width = "24px"; d.style["padding-right"] = "16px"; var e = H(a), f = H(a); f.style["font-weight"] = "bold"; f.textContent = ca; var k = H(a); k.textContent = da; J(a,
#             e, f); J(a, e, k); J(a, c, d); J(a, c, e); J(a, b, c); a.a = b; a.b.body.appendChild(a.a); b = G(1, 5); for (c = 0; c < b; c++)d = H(a), a.b.body.appendChild(d), a.c.push(d)
#       }, J = function (a, b, c) { for (var d = G(1, 5), e = 0; e < d; e++) { var f = H(a); b.appendChild(f) } b.appendChild(c); c = G(1, 5); for (d = 0; d < c; d++)e = H(a), b.appendChild(e) }, G = function (a, b) { return Math.floor(a + Math.random() * (b - a)) }, I = function (a, b, c, d, e, f) {
#         return "rgb(" + G(Math.max(a, 0), Math.min(b, 255)).toString() + "," + G(Math.max(c, 0), Math.min(d, 255)).toString() + "," + G(Math.max(e, 0), Math.min(f,
#           255)).toString() + ")"
#       }, H = function (a) { a = A(a.f.a, "DIV"); a.className = z(); return a }, E = function (a, b) { 0 >= b || null != a.a && 0 != a.a.offsetHeight && 0 != a.a.offsetWidth || (fa(a), D(a), l.setTimeout(function () { return E(a, b - 1) }, 50)) }, fa = function (a) { var b = a.c; var c = "undefined" != typeof Symbol && Symbol.iterator && b[Symbol.iterator]; b = c ? c.call(b) : { next: g(b) }; for (c = b.next(); !c.done; c = b.next())(c = c.value) && c.parentNode && c.parentNode.removeChild(c); a.c = []; (b = a.a) && b.parentNode && b.parentNode.removeChild(b); a.a = null }; var ia = function (a, b, c, d, e) { var f = ha(c), k = function (n) { n.appendChild(f); l.setTimeout(function () { f ? (0 !== f.offsetHeight && 0 !== f.offsetWidth ? b() : a(), f.parentNode && f.parentNode.removeChild(f)) : a() }, d) }, h = function (n) { document.body ? k(document.body) : 0 < n ? l.setTimeout(function () { h(n - 1) }, e) : b() }; h(3) }, ha = function (a) { var b = document.createElement("div"); b.className = a; b.style.width = "1px"; b.style.height = "1px"; b.style.position = "absolute"; b.style.left = "-10000px"; b.style.top = "-10000px"; b.style.zIndex = "-10000"; return b }; var K = {}, L = null; var M = function () { }, N = "function" == typeof Uint8Array, O = function (a, b) { a.b = null; b || (b = []); a.j = void 0; a.f = -1; a.a = b; a: { if (b = a.a.length) { --b; var c = a.a[b]; if (!(null === c || "object" != typeof c || Array.isArray(c) || N && c instanceof Uint8Array)) { a.g = b - a.f; a.c = c; break a } } a.g = Number.MAX_VALUE } a.i = {} }, P = [], Q = function (a, b) { if (b < a.g) { b += a.f; var c = a.a[b]; return c === P ? a.a[b] = [] : c } if (a.c) return c = a.c[b], c === P ? a.c[b] = [] : c }, R = function (a, b, c) { a.b || (a.b = {}); if (!a.b[c]) { var d = Q(a, c); d && (a.b[c] = new b(d)) } return a.b[c] };
#       M.prototype.h = N ? function () {
#         var a = Uint8Array.prototype.toJSON; Uint8Array.prototype.toJSON = function () {
#           var b; void 0 === b && (b = 0); if (!L) { L = {}; for (var c = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""), d = ["+/=", "+/", "-_=", "-_.", "-_"], e = 0; 5 > e; e++) { var f = c.concat(d[e].split("")); K[e] = f; for (var k = 0; k < f.length; k++) { var h = f[k]; void 0 === L[h] && (L[h] = k) } } } b = K[b]; c = []; for (d = 0; d < this.length; d += 3) {
#             var n = this[d], t = (e = d + 1 < this.length) ? this[d + 1] : 0; h = (f = d + 2 < this.length) ? this[d + 2] : 0; k = n >> 2; n = (n &
#               3) << 4 | t >> 4; t = (t & 15) << 2 | h >> 6; h &= 63; f || (h = 64, e || (t = 64)); c.push(b[k], b[n], b[t] || "", b[h] || "")
#           } return c.join("")
#         }; try { return JSON.stringify(this.a && this.a, S) } finally { Uint8Array.prototype.toJSON = a }
#       } : function () { return JSON.stringify(this.a && this.a, S) }; var S = function (a, b) { return "number" !== typeof b || !isNaN(b) && Infinity !== b && -Infinity !== b ? b : String(b) }; M.prototype.toString = function () { return this.a.toString() }; var T = function (a) { O(this, a) }; u(T, M); var U = function (a) { O(this, a) }; u(U, M); var ja = function (a, b) { this.c = new B(a); var c = R(b, T, 5); c = new y(w, Q(c, 4) || ""); this.b = new ea(a, c, Q(b, 4)); this.a = b }, ka = function (a, b, c, d) { b = new T(b ? JSON.parse(b) : null); b = new y(w, Q(b, 4) || ""); C(a.c, b, 3, !1, c, function () { ia(function () { F(a.b); d(!1) }, function () { d(!0) }, Q(a.a, 2), Q(a.a, 3), Q(a.a, 1)) }) }; var la = function (a, b) { V(a, "internal_api_load_with_sb", function (c, d, e) { ka(b, c, d, e) }); V(a, "internal_api_sb", function () { F(b.b) }) }, V = function (a, b, c) { a = l.btoa(a + b); v(a, c) }, W = function (a, b, c) { for (var d = [], e = 2; e < arguments.length; ++e)d[e - 2] = arguments[e]; e = l.btoa(a + b); e = l[e]; if ("function" == r(e)) e.apply(null, d); else throw Error("API not exported."); }; var X = function (a) { O(this, a) }; u(X, M); var Y = function (a) { this.h = window; this.a = a; this.b = Q(this.a, 1); this.f = R(this.a, T, 2); this.g = R(this.a, U, 3); this.c = !1 }; Y.prototype.start = function () { ma(); var a = new ja(this.h.document, this.g); la(this.b, a); na(this) };
#       var ma = function () { var a = function () { if (!l.frames.googlefcPresent) if (document.body) { var b = document.createElement("iframe"); b.style.display = "none"; b.style.width = "0px"; b.style.height = "0px"; b.style.border = "none"; b.style.zIndex = "-1000"; b.style.left = "-1000px"; b.style.top = "-1000px"; b.name = "googlefcPresent"; document.body.appendChild(b) } else l.setTimeout(a, 5) }; a() }, na = function (a) {
#         var b = Date.now(); W(a.b, "internal_api_load_with_sb", a.f.h(), function () {
#           var c; var d = a.b, e = l[l.btoa(d + "loader_js")]; if (e) {
#             e = l.atob(e);
#             e = parseInt(e, 10); d = l.btoa(d + "loader_js").split("."); var f = l; d[0] in f || "undefined" == typeof f.execScript || f.execScript("var " + d[0]); for (; d.length && (c = d.shift());)d.length ? f[c] && f[c] !== Object.prototype[c] ? f = f[c] : f = f[c] = {} : f[c] = null; c = Math.abs(b - e); c = 1728E5 > c ? 0 : c
#           } else c = -1; 0 != c && (W(a.b, "internal_api_sb"), Z(a, Q(a.a, 6)))
#         }, function (c) { Z(a, c ? Q(a.a, 4) : Q(a.a, 5)) })
#       }, Z = function (a, b) { a.c || (a.c = !0, a = new l.XMLHttpRequest, a.open("GET", b, !0), a.send()) }; (function (a, b) { l[a] = function (c) { for (var d = [], e = 0; e < arguments.length; ++e)d[e - 0] = arguments[e]; l[a] = q; b.apply(null, d) } })("__d3lUW8vwsKlB__", function (a) { "function" == typeof window.atob && (a = window.atob(a), a = new X(a ? JSON.parse(a) : null), (new Y(a)).start()) });
#     }).call(this);
#
#     window.__d3lUW8vwsKlB__("...");
#   </script>
# <script>
#     window.__prebidAdUnits = [];
#     (function() {
#       var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
#       pbs.async = true;
#       pbs.src = '//s.mxmcdn.net/site/js/prebid4.13.0.js';
#       var target = document.getElementsByTagName('head')[0];
#       target.insertBefore(pbs, target.firstChild);
#     })();
#   </script>
# <script>
#     var cssua=function(n,l,p){var q=/\s*([\-\w ]+)[\s\/\:]([\d_]+\b(?:[\-\._\/]\w+)*)/,r=/([\w\-\.]+[\s\/][v]?[\d_]+\b(?:[\-\._\/]\w+)*)/g,s=/\b(?:(blackberry\w*|bb10)|(rim tablet os))(?:\/(\d+\.\d+(?:\.\w+)*))?/,t=/\bsilk-accelerated=true\b/,u=/\bfluidapp\b/,v=/(\bwindows\b|\bmacintosh\b|\blinux\b|\bunix\b)/,w=/(\bandroid\b|\bipad\b|\bipod\b|\bwindows phone\b|\bwpdesktop\b|\bxblwp7\b|\bzunewp7\b|\bwindows ce\b|\bblackberry\w*|\bbb10\b|\brim tablet os\b|\bmeego|\bwebos\b|\bpalm|\bsymbian|\bj2me\b|\bdocomo\b|\bpda\b|\bchtml\b|\bmidp\b|\bcldc\b|\w*?mobile\w*?|\w*?phone\w*?)/,
#     x=/(\bxbox\b|\bplaystation\b|\bnintendo\s+\w+)/,k={parse:function(b,d){var a={};d&&(a.standalone=d);b=(""+b).toLowerCase();if(!b)return a;for(var c,e,g=b.split(/[()]/),f=0,k=g.length;f<k;f++)if(f%2){var m=g[f].split(";");c=0;for(e=m.length;c<e;c++)if(q.exec(m[c])){var h=RegExp.$1.split(" ").join("_"),l=RegExp.$2;if(!a[h]||parseFloat(a[h])<parseFloat(l))a[h]=l}}else if(m=g[f].match(r))for(c=0,e=m.length;c<e;c++)h=m[c].split(/[\/\s]+/),h.length&&"mozilla"!==h[0]&&(a[h[0].split(" ").join("_")]=h.slice(1).join("-"));
#     w.exec(b)?(a.mobile=RegExp.$1,s.exec(b)&&(delete a[a.mobile],a.blackberry=a.version||RegExp.$3||RegExp.$2||RegExp.$1,RegExp.$1?a.mobile="blackberry":"0.0.1"===a.version&&(a.blackberry="7.1.0.0"))):x.exec(b)?(a.game=RegExp.$1,c=a.game.split(" ").join("_"),a.version&&!a[c]&&(a[c]=a.version)):v.exec(b)&&(a.desktop=RegExp.$1);a.intel_mac_os_x?(a.mac_os_x=a.intel_mac_os_x.split("_").join("."),delete a.intel_mac_os_x):a.cpu_iphone_os?(a.ios=a.cpu_iphone_os.split("_").join("."),delete a.cpu_iphone_os):a.cpu_os?
#     (a.ios=a.cpu_os.split("_").join("."),delete a.cpu_os):"iphone"!==a.mobile||a.ios||(a.ios="1");a.opera&&a.version?(a.opera=a.version,delete a.blackberry):t.exec(b)?a.silk_accelerated=!0:u.exec(b)&&(a.fluidapp=a.version);a.edge&&(delete a.applewebkit,delete a.safari,delete a.chrome,delete a.android);if(a.applewebkit)a.webkit=a.applewebkit,delete a.applewebkit,a.opr&&(a.opera=a.opr,delete a.opr,delete a.chrome),a.safari&&(a.chrome||a.crios||a.fxios||a.opera||a.silk||a.fluidapp||a.phantomjs||a.mobile&&
#     !a.ios?(delete a.safari,a.vivaldi&&delete a.chrome):a.safari=a.version&&!a.rim_tablet_os?a.version:{419:"2.0.4",417:"2.0.3",416:"2.0.2",412:"2.0",312:"1.3",125:"1.2",85:"1.0"}[parseInt(a.safari,10)]||a.safari);else if(a.msie||a.trident)if(a.opera||(a.ie=a.msie||a.rv),delete a.msie,delete a.android,a.windows_phone_os)a.windows_phone=a.windows_phone_os,delete a.windows_phone_os;else{if("wpdesktop"===a.mobile||"xblwp7"===a.mobile||"zunewp7"===a.mobile)a.mobile="windows desktop",a.windows_phone=9>+a.ie?
#     "7.0":10>+a.ie?"7.5":"8.0",delete a.windows_nt}else if(a.gecko||a.firefox)a.gecko=a.rv;a.rv&&delete a.rv;a.version&&delete a.version;return a},format:function(b){var d="",a;for(a in b)if(a&&b.hasOwnProperty(a)){var c=a,e=b[a],c=c.split(".").join("-"),g=" ua-"+c;if("string"===typeof e){for(var e=e.split(" ").join("_").split(".").join("-"),f=e.indexOf("-");0<f;)g+=" ua-"+c+"-"+e.substring(0,f),f=e.indexOf("-",f+1);g+=" ua-"+c+"-"+e}d+=g}return d},encode:function(b){var d="",a;for(a in b)a&&b.hasOwnProperty(a)&&
#     (d&&(d+="\x26"),d+=encodeURIComponent(a)+"\x3d"+encodeURIComponent(b[a]));return d}};k.userAgent=k.ua=k.parse(l,p);l=k.format(k.ua)+" js";n.className=n.className?n.className.replace(/\bno-js\b/g,"")+l:l.substr(1);return k}(document.documentElement,navigator.userAgent,navigator.standalone);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a38809cc79","applicationID":"11518440","applicationTime":36.802177,"transactionName":"ZVdUZEdSXUVUVEAIX1wddUVGR1xbGlZGFVlBRhkYbm1vQwUHBgdtGRs=","queueTime":0,"ttGuid":"2d24868f5526fc","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"Uw8PVlVXGwIBUVBaAwUH",licenseKey:"a38809cc79",applicationID:"11518440"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(wind ...
# <link href="//s.mxmcdn.net/site/css/styles-39907f576175ff4a85ae.css" rel="stylesheet" type="text/css"/>
# <link href="//s.mxmcdn.net/site/css/styles-54104562bfd9047a28bf.css" rel="stylesheet" type="text/css"/>
# <script>__mxmStatusCode = 200;__mxmSession = {"userCountry":{"code":"US","name":"United States","continentCode":"NA"}};__mxmHeaders = {};</script>
# <meta content="5381b8eb344dfaa4" name="yandex-verification"/>
# <meta content="notranslate" name="google"/>
# <title>La Vida Moderna lyrics | Musixmatch</title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge; chrome=1" http-equiv="X-UA-Compatible"/><meta content="All La Vida Moderna lyrics sorted by popularity, with video and meanings." name="description"/><meta content="https://www.musixmatch.com" name="identifier"/><meta content="lyrics, video, meaning, writer, music video, top songs lyrics, synced lyrics, music player, artist, karaoke" name="keywords"/><meta content="_8faEqn-rAfu0zKe0faUhuSHMNf6SN9dudWkxouG_us" name="google-site-verification"/><meta content="m6xTItKX2q" name="baidu-site-verification"/><meta content="42d34374a1270f3e" name="yandex-verification"/><meta content="app-id=448278467, affiliate-data=http://clk.tradedoubler.com/click?p=24373&amp;amp;a=1805894, app-argument=mxm://artist/34038508" name="apple-itunes-app"/><link href="//s.mxmcdn.net" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//d2b1xqaw2ss8na.cloudfront.net" rel="dns-prefetch"/><link href="//platform.twitter.com" rel="dns-prefetch"/><link href="/opensearch.xml" rel="search" title="Musixmatch" type="application/opensearchdescription+xml"/><link href="https://www.musixmatch.com/artist/La-Vida-Moderna" rel="canonical"/><link href="//s.mxmcdn.net/site/images/favicon.png" rel="shortcut icon"/><link href="https://plus.google.com/+musiXmatch" rel="publisher"/><meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0" name="viewport"/><link href="https://www.musixmatch.com/artist/La-Vida-Moderna" hreflang="en" rel="alternate"/><link href="https://www.musixmatch.com/it/testi/La-Vida-Moderna" hreflang="it" rel="alternate"/><link href="https://www.musixmatch.com/fr/artist/La-Vida-Moderna" hreflang="fr" rel="alternate"/><link href="https://www.musixmatch.com/es/artist/La-Vida-Moderna" hreflang="es" rel="alternate"/><link href="https://www.musixmatch.com/ja/artist/La-Vida-Moderna" hreflang="ja" rel="alternate"/><link href="https://www.musixmatch.com/de/songtexte/La-Vida-Moderna" hreflang="de" rel="alternate"/><link href="https://www.musixmatch.com/pt/artist/La-Vida-Moderna" hreflang="pt" rel="alternate"/><link href="https://www.musixmatch.com/pt-br/artist/La-Vida-Moderna" hreflang="pt-br" rel="alternate"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="//s.mxmcdn.net/site/images/win_tile_144.png" name="msapplication-TileImage"/><meta content="#ff6600" name="msapplication-TileColor"/><link href="//s.mxmcdn.net/site/images/mxm_icn_72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//s.mxmcdn.net/site/images/mxm_icn_114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//s.mxmcdn.net/site/images/mxm_icn_57.png" rel="apple-touch-icon"/><meta content="131314396964274" property="fb:app_id"/><meta content="688442030" property="fb:admins"/><meta content="4f6d74a840fa7f3f5fe34b553ebbb4dc" name="p:domain_verify"/><link href="https://chrome.google.com/webstore/detail/gfenjblodoldnbiddmggcbkcapiolbig" rel="chrome-webstore-item"/><link href="android-app://com.musixmatch.android.lyrify/mxm/artist/34038508?origin=appindexing" rel="alternate"/><link href="ios-app://448278467/mxm/artist/34038508" rel="alternate"/><meta content="All La Vida Moderna lyrics sorted by popularity, with video and meanings." property="og:description"/><meta content="34038508" property="og:artist_id"/><meta content="La Vida Moderna lyrics | Musixmatch" property="og:title"/><meta content="musiXmatch" property="og:site_name"/><meta content="https://www.musixmatch.com/artist/La-Vida-Moderna" property="og:url"/><meta content="musixmatch:lyrics" property="og:type"/><meta content="//s.mxmcdn.net/site/images/avatar-placeholder.png" property="og:image"/><meta content="131314396964274" property="fb:app_id"/><meta content="en" http-equiv="content-language"/>
# <script>
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     pbjs.bidderSettings = {
#         rubicon: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85 * 0.84;
#             }
#         },
#         appnexus: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         },
#         ix: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         }
#     };
# </script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function () {
#         googletag.pubads().disableInitialLoad();
#     });
#
#     var priceGranularity = {
#         buckets: [{
#             min: 0,
#             max: 31.49,
#             increment: 0.01
#         }]
#     };
#
#     function sendAdserverRequest() {
#         if (pbjs.adserverRequestSent) return;
#         pbjs.adserverRequestSent = true;
#         googletag.cmd.push(function () {
#             pbjs.que.push(function () {
#                 pbjs.setTargetingForGPTAsync();
#                 googletag.pubads().refresh();
#             });
#         });
#     }
# </script>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function () {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#             '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#     function getParameterByName(name, url) {
#         if (!url) url = window.location.href;
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)"),
#             results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#     }
#
#     googletag.cmd.push(function () {
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().disableInitialLoad();
#         googletag.pubads().collapseEmptyDivs();
#         var campaign = getParameterByName('utm_campaign');
#         if (campaign) {
#             googletag.pubads().setTargeting('utm_campaign', campaign);
#         }
#         googletag.enableServices();
#     });
#
#     // Make sure that the properties exist on the window.
#     window.googlefc = window.googlefc || {};
#     window.googlefc.ccpa = window.googlefc.ccpa || {}
#     window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#     // Queue the callback on the callbackQueue.
#     googlefc.callbackQueue.push({
#         'CONSENT_DATA_READY':
#             () => __tcfapi('getTCData', 0, (data, success) => {
#                 var FAILSAFE_TIMEOUT = 3000;
#
#                 pbjs.que.push(function () {
#                     pbjs.enableAnalytics([{
#                         provider: 'ga'
#                     }]);
#                     pbjs.setConfig({
#                         bidderSequence: 'random',
#                         enableSendAllBids: true,
#                         priceGranularity: priceGranularity,
#                         consentManagement: {
#                             gdpr: {
#                                 cmpApi: 'iab',
#                                 defaultGdprScope: true
#                             }
#                         }
#                     })
#                     pbjs.addAdUnits(__prebidAdUnits);
#                     pbjs.requestBids({
#                         bidsBackHandler: sendAdserverRequest
#                     });
#                 });
#
#                 setTimeout(function () {
#                     sendAdserverRequest();
#                 }, FAILSAFE_TIMEOUT);
#             })
#     });
# </script>
# </head>
# <body class="" spellcheck="false">
# <div id="fb-root"></div>
# <div id="site"><div class="" data-reactroot="" id="artist-page"><div class="navbar" id="header" role="banner"><nav class="top-bar desktop-bar" data-topbar="true"><section class="top-bar-section"><ul class="title-area"><li class="name"><h1><a href="/" id="logo"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg" width="40"/></a></h1></li></ul><ul class="search-nav" role="search"><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div></form></li></ul><div class="top-bar-right"><ul class="site-nav" role="navigation"><li><a href="/explore">Top lyrics</a></li><li><a href="/community">Community</a></li><li><a href="/contribute">Contribute</a></li><li><a href="https://about.musixmatch.com/business/overview">Business</a></li></ul><ul class="user-nav"><li><ul class="user-nav-items loggedOut"><li id="sign-in"><a data-external-link="true" href="/sign-in">Sign in</a></li><li id="sign-up"><a data-external-link="true" href="/sign-up">Sign up</a></li></ul></li></ul></div></section></nav><nav class="top-bar mobile-top-bar"><ul class="title-area"><li class="offcanvas-toggler"><a href="#"><i class="icon icon-list"></i></a></li><li class="name"><h1><a href="/"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg"/></a></h1></li><li class="toggle-search-bar"><a href="#"><span><i class="icon icon-search"></i></span></a></li><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div><button class="button button-link search-bar-cancel"><i class="icon icon-cross"></i></button></form></li></ul></nav><noscript></noscript></div><div id="content" role="main"><div class="artist-page main-wrapper" itemtype="http://schema.org/MusicGroup"><meta content="/artist/La-Vida-Moderna" itemprop="url"/><div class="profile-header artist-header"><div class="main-wrapper"><div class="noCoverPlaceholder"></div><div class="bg"></div><div class="profile-info"><div class="profile-head-link"><div class="profile-image"><img alt="La Vida Moderna - lyrics" class="profile-avatar large" itemprop="image" src="//s.mxmcdn.net/site/images/avatar-placeholder.png"/></div><div class="profile-data"><meta content="La Vida Moderna" itemprop="name"/><meta content="Discover and play La Vida Moderna songs with lyrics" itemprop="description"/><span class="lyricsLabel">lyrics</span><h1 class="" itemprop="name" title="La Vida Moderna">La Vida Moderna</h1><ul class="genres"></ul></div><a class="verify-link" href="https://artists.musixmatch.com">Are you this artist? Verify your lyrics now!</a></div><button class="button-primary contribute-button">+ <!-- -->Add lyrics</button><ul class="profile-head-info"></ul><span></span></div></div></div><div class="profile-content"><div><div class="section-header"><ul class="tabs"><li class="selected" id="overview"><a href="/artist/La-Vida-Moderna">Overview</a></li><li class="" id="community"><a href="/artist/La-Vida-Moderna/community">Contributors</a></li><li class="" id="albums"><a href="/artist/La-Vida-Moderna/albums">Albums</a></li></ul></div><div class="tab-content"><div class="main-wrapper"><div class="main"><div class="row"><div class="main-panel"><div class="_2-NbqRCcpnx1S7eZLj0p72" id="cf_async_100001909_34038508"></div><div class="box box-style-plain" id="top-songs"><div class="box-header"><h3 class="box-title"> <!-- -->Lyrics for top songs by La Vida Moderna</h3><div class="actions"></div></div><div class="box-content"><div><div><ul class="tracks list"><li class="showPosition showCoverart"><span class="position">01</span><div class="track-card media-card has-picture"><div class="media-card-picture"><img alt="Ipno D ...
#   googletag.cmd.push(function() {
#     window['__ad_div_gpt_ad_336x280_musixmatch_artist_sidebar_top'] = googletag.defineSlot("/154438701/336x280_musixmatch_artist_sidebar_top", [336, 280],
#     "div_gpt_ad_336x280_musixmatch_artist_sidebar_top").addService(googletag.pubads());
#     googletag.display("div_gpt_ad_336x280_musixmatch_artist_sidebar_top");
#     googletag.pubads().refresh([window.__ad_div_gpt_ad_336x280_musixmatch_artist_sidebar_top]);
#   });
# </script></div></div></div></div><div class="box box-style-plain" id="albums"><div class="box-header"><h3 class="box-title"> <!-- -->Albums</h3><div class="actions"><a class="see-all-action" href="/artist/La-Vida-Moderna/albums">All albums</a></div></div><div class="box-content"><ul class="albums list"><li><div class="album-card media-card has-picture"><div class="media-card-picture"><img alt="Ipno De Moderdonia (feat. feat. Pirata &amp; Lobo) by La Vida Moderna â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums5/9/8/3/6/9/7/37796389.jpg 320w, https://s.mxmcdn.net/images-storage/albums5/9/8/3/6/9/7/37796389_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums5/9/8/3/6/9/7/37796389_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums5/9/8/3/6/9/7/37796389_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a href="/album/La-Vida-Moderna/Ipno-De-Moderdonia-feat-feat-Pirata-Lobo">Ipno De Moderdonia (feat. feat. Pirata &amp; Lobo)</a></h2><h3 class="media-card-subtitle">2017</h3></div></div><meta content="Ipno De Moderdonia (feat. feat. Pirata &amp; Lobo)" itemprop="name"/><meta content="https://s.mxmcdn.net/images-storage/albums5/9/8/3/6/9/7/37796389_500_500.jpg" itemprop="image"/></div></li></ul></div></div></div></div></div></div></div></div></div></div></div><span></span><div id="footer"><div class="main-wrapper"><div class="footer-container"><div class="mxm-footer__sitemap"><div class="mxm-footer__sitemap-logo"><div class="mui-logo"><a class="mui-logo__link" href="/"><img alt="Musixmatch logo" class="mui-logo__img" src="//s.mxmcdn.net/site/images/logo.svg" width="176"/></a></div><a href="https://aws.amazon.com/it/eventi/?sc_channel=TA&amp;sc_campaign=musixmatch_IT&amp;sc_publisher=musixmatch&amp;sc_medium=website&amp;sc_content=IT_landingpage&amp;sc_country=IT" style="display:block;margin-top:20px;margin-bottom:50px"><img alt="Powered by Amazon Web Services" height="46" src="//s.mxmcdn.net/site/images/amazon-logo-black.png" srcset="//s.mxmcdn.net/site/images/amazon-logo-black@2x.png 2x" width="120"/></a><div class="mxm-footer__language"><button class="small button dropdown" id="language-menu">English</button></div></div></div><div class="mxm-footer__sitemap-links"><h4>Company</h4><ul><li><a data-external-link="true" href="https://about.musixmatch.com" target="_blank">About us</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/careers" target="_blank">Careers</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/press" target="_blank">Press</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/contact" target="_blank">Contact</a></li><li><a data-external-link="true" href="https://blog.musixmatch.com" target="_blank">Blog</a></li></ul></div><div class="mxm-footer__sitemap-links"><h4>Products</h4><ul><li><a data-external-link="true" href="https://about.musixmatch.com/business/overview" target="_blank">Business Solutions</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/apps" target="_blank">Apps</a></li><li><a data-external-link="true" href="https://developer.musixmatch.com" target="_blank">Developers</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/publishers/musixmatch-for-publishers" target="_blank">Musixmatch for Publishers</a></li></ul></div><div class="mxm-footer__sitemap-links"><h4>Community</h4><ul><li><a data-external-link="true" href="https://about.musixmatch.com/community/overview" target="_blank">Overview</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/community/guidelines" target="_blank">Guidelines</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/artists/verified-artist" target="_blank">Verified Artists</a></li><li><a data-external-link="true" href="https://about.musixmatch.com/community/become-a-curator" target="_blank">Become a Curator</a></li><li> ...
#  ðŸŒŽ Enjoyed everywhere</p></div></div></div><span></span></div></div>
# <script>var __mxmProps = {"artistVanity":"La-Vida-Moderna","async":true,"tab":"overview","pageName":"artist-page","page":1,"artist":{"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"vanityId":"La-Vida-Moderna","tracks_page":1,"albums_page":1,"albums":{"0":{"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"attributes":{"album_id":26623603,"album_mbid":"","album_name":"Ipno De Moderdonia (feat. feat. Pirata & Lobo)","album_rating":9,"album_track_count":1,"album_release_date":"2017-07-01","album_release_type":"Single","artist_id":34038508,"artist_name":"La Vida Moderna","primary_genres":{"music_genre_list":[]},"secondary_genres":{"music_genre_list":[]},"album_pline":"2017 La Vida Moderna","album_copyright":"2017 La Vida Moderna","album_label":"","album_vanity_id":"La-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo","album_edit_url":"https:\u002F\u002Fwww.musixmatch.com\u002Falbum\u002FLa-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo?utm_source=application&utm_campaign=api&utm_medium=musixmatch-community%3A1409608317702","restricted":0,"updated_time":"2017-08-03T20:06:32Z","album_coverart_100x100":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389.jpg","album_coverart_350x350":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_350_350.jpg","album_coverart_500x500":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_500_500.jpg","album_coverart_800x800":""},"id":26623603,"title":"Ipno De Moderdonia (feat. feat. Pirata & Lobo)","artistName":"La Vida Moderna","artistId":34038508,"copyright":"2017 La Vida Moderna","year":"2017","releaseDate":"2017-07-01","vanityId":"La-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo","artistVanity":"La-Vida-Moderna","albumVanity":"Ipno-De-Moderdonia-feat-feat-Pirata-Lobo","coverart":{"small":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389.jpg","medium":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_350_350.jpg","normal":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_500_500.jpg","large":"\u002F\u002Fs.mxmcdn.net\u002Fimages\u002Falbums\u002Fnocover-800x800.png"},"restricted":false},"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
# ...
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"attributes":{"album_id":26623603,"album_mbid":"","album_name":"Ipno De Moderdonia (feat. feat. Pirata & Lobo)","album_rating":9,"album_track_count":1,"album_release_date":"2017-07-01","album_release_type":"Single","artist_id":34038508,"artist_name":"La Vida Moderna","primary_genres":{"music_genre_list":[]},"secondary_genres":{"music_genre_list":[]},"album_pline":"2017 La Vida Moderna","album_copyright":"2017 La Vida Moderna","album_label":"","album_vanity_id":"La-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo","album_edit_url":"https:\u002F\u002Fwww.musixmatch.com\u002Falbum\u002FLa-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo?utm_source=application&utm_campaign=api&utm_medium=musixmatch-community%3A1409608317702","restricted":0,"updated_time":"2017-08-03T20:06:32Z","album_coverart_100x100":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389.jpg","album_coverart_350x350":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_350_350.jpg","album_coverart_500x500":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_500_500.jpg","album_coverart_800x800":""},"id":26623603,"title":"Ipno De Moderdonia (feat. feat. Pirata & Lobo)","artistName":"La Vida Moderna","artistId":34038508,"copyright":"2017 La Vida Moderna","year":"2017","releaseDate":"2017-07-01","vanityId":"La-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo","artistVanity":"La-Vida-Moderna","albumVanity":"Ipno-De-Moderdonia-feat-feat-Pirata-Lobo","coverart":{"small":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389.jpg","medium":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_350_350.jpg","normal":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_500_500.jpg","large":"\u002F\u002Fs.mxmcdn.net\u002Fimages\u002Falbums\u002Fnocover-800x800.png"},"restricted":false},"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"_api":{"method":"artist.albums.get","params":{"page_size":5,"page":1,"s_release_date":"desc","g_album_name":1,"artist_id":34038508,"f_album_release_type":"single,album,ep"}},"attributes":[{"album":{"album_id":26623603,"album_mbid":"","album_name":"Ipno De Moderdonia (feat. feat. Pirata & Lobo)","album_rating":9,"album_track_count":1,"album_release_date":"2017-07-01","album_release_type":"Single","artist_id":34038508,"artist_name":"La Vida Moderna","primary_genres":{"music_genre_list":[]},"secondary_genres":{"music_genre_list":[]},"album_pline":"2017 La Vida Moderna","album_copyright":"2017 La Vida Moderna","album_label":"","album_vanity_id":"La-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo","album_edit_url":"https:\u002F\u002Fwww.musixmatch.com\u002Falbum\u002FLa-Vida-Moderna\u002FIpno-De-Moderdonia-feat-feat-Pirata-Lobo?utm_source=application&utm_campaign=api&utm_medium=musixmatch-community%3A1409608317702","restricted":0,"updated_time":"2017-08-03T20:06:32Z","album_coverart_100x100":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389.jpg","album_coverart_350x350":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_350_350.jpg","album_coverart_500x500":"https:\u002F\u002Fs.mxmcdn.net\u002Fimages-storage\u002Falbums5\u002F9\u002F8\u002F3\u002F6\u002F9\u002F7\u002F37796389_500_500.jpg","album_coverart_800x800":""}}],"length":1},"writers":{"_api":{"method":"artist.writers.get","params":{"artist_id":34038508}},"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"attributes":[],"info":{"status_code":200,"available":0,"execute_time":0.0053720474243164,"total_items":0}},"contributors":{"_api":{"params":{"page":1,"page_size":16,"chart_name":"artist_top","artist_id":34038508},"method":"crowd.chart.users.get"},"state":function () {
#         return state;
#       },"done":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"fail":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"progress":function () {
#           if (state === PENDING) {
#             holder.push.apply(holder, flatten(arguments));
#           }
#           if (shouldExecuteImmediately()) {
#             execute(arguments, closingArguments[holderState]);
#           }
#           return candidate;
#         },"always":function () {
#         var _ref;
#         return (_ref = candidate.done.apply(candidate, arguments)).fail.apply(_ref, arguments);
#       },"pipe":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"then":function (doneFilter, failFilter, progressFilter) {
#         var filter, master;
#         master = new Deferred();
#         filter = function(source, funnel, callback) {
#           if (!callback) {
#             return candidate[source](master[funnel]);
#           }
#           return candidate[source](function() {
#             var args, value;
#             args = 1 <= arguments.length ? __slice.call(arguments, 0) : [];
#             value = callback.apply(null, args);
#             if (isPromise(value)) {
#               return value.done(master.resolve).fail(master.reject).progress(master.notify);
#             } else {
#               return master[funnel](value);
#             }
#           });
#         };
#         filter('done', 'resolve', doneFilter);
#         filter('fail', 'reject', failFilter);
#         filter('progress', 'notify', progressFilter);
#         return master;
#       },"promise":function () {
#           return candidate;
#         },"attributes":[],"info":{"available":0,"hint":"no content","status_code":200,"execute_time":0.0061969757080078,"total_items":0,"page_size":16}}}</script>
# <script async="" src="//s.mxmcdn.net/site/js/common-43bca79ed615488d9890.js"></script>
# <script>window.___gcfg = {parsetags: 'explicit'};</script>
# </body>
# </html>

# %%
from fsUtils import isFile
url="https://www.musixmatch.com/search/Dave%20Matthews%20Band"
savename = "musixmatch_search.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.musixmatch.com/search/Dave%20Matthews%20Band
#   --> This file is 42.2kB.

# %%
from webUtils import getHTML
bsdata = getHTML(savename)
bsdata
# Out:
# <!DOCTYPE html>
# <html class="search-results-page" xmlns:og="http://ogp.me/ns#">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# musixmatch: http://ogp.me/ns/fb/musixmatch#">
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     window._mxm_ga_firstLoad = true; //flag page tracked on first load
#     ga('create', 'UA-16453829-10', 'auto');
#     ga('require', '');
#     ga('send', 'pageview');
#   </script>
# <script>(function () {/*
#
#   Copyright The Closure Library Authors.
#   SPDX-License-Identifier: Apache-2.0
#   */
#       'use strict'; var g = function (a) { var b = 0; return function () { return b < a.length ? { done: !1, value: a[b++] } : { done: !0 } } }, l = this || self, m = /^[\w+/_-]+[=]{0,2}$/, p = null, q = function () { }, r = function (a) {
#         var b = typeof a; if ("object" == b) if (a) {
#           if (a instanceof Array) return "array"; if (a instanceof Object) return b; var c = Object.prototype.toString.call(a); if ("[object Window]" == c) return "object"; if ("[object Array]" == c || "number" == typeof a.length && "undefined" != typeof a.splice && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("splice")) return "array";
#           if ("[object Function]" == c || "undefined" != typeof a.call && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("call")) return "function"
#         } else return "null"; else if ("function" == b && "undefined" == typeof a.call) return "object"; return b
#       }, u = function (a, b) { function c() { } c.prototype = b.prototype; a.prototype = new c; a.prototype.constructor = a }; var v = function (a, b) { Object.defineProperty(l, a, { configurable: !1, get: function () { return b }, set: q }) }; var y = function (a, b) { this.b = a === w && b || ""; this.a = x }, x = {}, w = {}; var aa = function (a, b) { a.src = b instanceof y && b.constructor === y && b.a === x ? b.b : "type_error:TrustedResourceUrl"; if (null === p) b: { b = l.document; if ((b = b.querySelector && b.querySelector("script[nonce]")) && (b = b.nonce || b.getAttribute("nonce")) && m.test(b)) { p = b; break b } p = "" } b = p; b && a.setAttribute("nonce", b) }; var z = function () { return Math.floor(2147483648 * Math.random()).toString(36) + Math.abs(Math.floor(2147483648 * Math.random()) ^ +new Date).toString(36) }; var A = function (a, b) { b = String(b); "application/xhtml+xml" === a.contentType && (b = b.toLowerCase()); return a.createElement(b) }, B = function (a) { this.a = a || l.document || document }; B.prototype.appendChild = function (a, b) { a.appendChild(b) }; var C = function (a, b, c, d, e, f) { try { var k = a.a, h = A(a.a, "SCRIPT"); h.async = !0; aa(h, b); k.head.appendChild(h); h.addEventListener("load", function () { e(); d && k.head.removeChild(h) }); h.addEventListener("error", function () { 0 < c ? C(a, b, c - 1, d, e, f) : (d && k.head.removeChild(h), f()) }) } catch (n) { f() } }; var ba = l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"), ca = l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="), da = l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"), ea = function (a, b, c) { this.b = a; this.f = new B(this.b); this.a = null; this.c = []; this.g = !1; this.i = b; this.h = c }, F = function (a) {
#         if (a.b.body && !a.g) {
#           var b =
#             function () { D(a); l.setTimeout(function () { return E(a, 3) }, 50) }; C(a.f, a.i, 2, !0, function () { l[a.h] || b() }, b); a.g = !0
#         }
#       }, D = function (a) {
#         for (var b = G(1, 5), c = 0; c < b; c++) { var d = H(a); a.b.body.appendChild(d); a.c.push(d) } b = H(a); b.style.bottom = "0"; b.style.left = "0"; b.style.position = "fixed"; b.style.width = G(100, 110).toString() + "%"; b.style.zIndex = G(2147483544, 2147483644).toString(); b.style["background-color"] = I(249, 259, 242, 252, 219, 229); b.style["box-shadow"] = "0 0 12px #888"; b.style.color = I(0, 10, 0, 10, 0, 10); b.style.display =
#           "flex"; b.style["justify-content"] = "center"; b.style["font-family"] = "Roboto, Arial"; c = H(a); c.style.width = G(80, 85).toString() + "%"; c.style.maxWidth = G(750, 775).toString() + "px"; c.style.margin = "24px"; c.style.display = "flex"; c.style["align-items"] = "flex-start"; c.style["justify-content"] = "center"; d = A(a.f.a, "IMG"); d.className = z(); d.src = ba; d.style.height = "24px"; d.style.width = "24px"; d.style["padding-right"] = "16px"; var e = H(a), f = H(a); f.style["font-weight"] = "bold"; f.textContent = ca; var k = H(a); k.textContent = da; J(a,
#             e, f); J(a, e, k); J(a, c, d); J(a, c, e); J(a, b, c); a.a = b; a.b.body.appendChild(a.a); b = G(1, 5); for (c = 0; c < b; c++)d = H(a), a.b.body.appendChild(d), a.c.push(d)
#       }, J = function (a, b, c) { for (var d = G(1, 5), e = 0; e < d; e++) { var f = H(a); b.appendChild(f) } b.appendChild(c); c = G(1, 5); for (d = 0; d < c; d++)e = H(a), b.appendChild(e) }, G = function (a, b) { return Math.floor(a + Math.random() * (b - a)) }, I = function (a, b, c, d, e, f) {
#         return "rgb(" + G(Math.max(a, 0), Math.min(b, 255)).toString() + "," + G(Math.max(c, 0), Math.min(d, 255)).toString() + "," + G(Math.max(e, 0), Math.min(f,
#           255)).toString() + ")"
#       }, H = function (a) { a = A(a.f.a, "DIV"); a.className = z(); return a }, E = function (a, b) { 0 >= b || null != a.a && 0 != a.a.offsetHeight && 0 != a.a.offsetWidth || (fa(a), D(a), l.setTimeout(function () { return E(a, b - 1) }, 50)) }, fa = function (a) { var b = a.c; var c = "undefined" != typeof Symbol && Symbol.iterator && b[Symbol.iterator]; b = c ? c.call(b) : { next: g(b) }; for (c = b.next(); !c.done; c = b.next())(c = c.value) && c.parentNode && c.parentNode.removeChild(c); a.c = []; (b = a.a) && b.parentNode && b.parentNode.removeChild(b); a.a = null }; var ia = function (a, b, c, d, e) { var f = ha(c), k = function (n) { n.appendChild(f); l.setTimeout(function () { f ? (0 !== f.offsetHeight && 0 !== f.offsetWidth ? b() : a(), f.parentNode && f.parentNode.removeChild(f)) : a() }, d) }, h = function (n) { document.body ? k(document.body) : 0 < n ? l.setTimeout(function () { h(n - 1) }, e) : b() }; h(3) }, ha = function (a) { var b = document.createElement("div"); b.className = a; b.style.width = "1px"; b.style.height = "1px"; b.style.position = "absolute"; b.style.left = "-10000px"; b.style.top = "-10000px"; b.style.zIndex = "-10000"; return b }; var K = {}, L = null; var M = function () { }, N = "function" == typeof Uint8Array, O = function (a, b) { a.b = null; b || (b = []); a.j = void 0; a.f = -1; a.a = b; a: { if (b = a.a.length) { --b; var c = a.a[b]; if (!(null === c || "object" != typeof c || Array.isArray(c) || N && c instanceof Uint8Array)) { a.g = b - a.f; a.c = c; break a } } a.g = Number.MAX_VALUE } a.i = {} }, P = [], Q = function (a, b) { if (b < a.g) { b += a.f; var c = a.a[b]; return c === P ? a.a[b] = [] : c } if (a.c) return c = a.c[b], c === P ? a.c[b] = [] : c }, R = function (a, b, c) { a.b || (a.b = {}); if (!a.b[c]) { var d = Q(a, c); d && (a.b[c] = new b(d)) } return a.b[c] };
#       M.prototype.h = N ? function () {
#         var a = Uint8Array.prototype.toJSON; Uint8Array.prototype.toJSON = function () {
#           var b; void 0 === b && (b = 0); if (!L) { L = {}; for (var c = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""), d = ["+/=", "+/", "-_=", "-_.", "-_"], e = 0; 5 > e; e++) { var f = c.concat(d[e].split("")); K[e] = f; for (var k = 0; k < f.length; k++) { var h = f[k]; void 0 === L[h] && (L[h] = k) } } } b = K[b]; c = []; for (d = 0; d < this.length; d += 3) {
#             var n = this[d], t = (e = d + 1 < this.length) ? this[d + 1] : 0; h = (f = d + 2 < this.length) ? this[d + 2] : 0; k = n >> 2; n = (n &
#               3) << 4 | t >> 4; t = (t & 15) << 2 | h >> 6; h &= 63; f || (h = 64, e || (t = 64)); c.push(b[k], b[n], b[t] || "", b[h] || "")
#           } return c.join("")
#         }; try { return JSON.stringify(this.a && this.a, S) } finally { Uint8Array.prototype.toJSON = a }
#       } : function () { return JSON.stringify(this.a && this.a, S) }; var S = function (a, b) { return "number" !== typeof b || !isNaN(b) && Infinity !== b && -Infinity !== b ? b : String(b) }; M.prototype.toString = function () { return this.a.toString() }; var T = function (a) { O(this, a) }; u(T, M); var U = function (a) { O(this, a) }; u(U, M); var ja = function (a, b) { this.c = new B(a); var c = R(b, T, 5); c = new y(w, Q(c, 4) || ""); this.b = new ea(a, c, Q(b, 4)); this.a = b }, ka = function (a, b, c, d) { b = new T(b ? JSON.parse(b) : null); b = new y(w, Q(b, 4) || ""); C(a.c, b, 3, !1, c, function () { ia(function () { F(a.b); d(!1) }, function () { d(!0) }, Q(a.a, 2), Q(a.a, 3), Q(a.a, 1)) }) }; var la = function (a, b) { V(a, "internal_api_load_with_sb", function (c, d, e) { ka(b, c, d, e) }); V(a, "internal_api_sb", function () { F(b.b) }) }, V = function (a, b, c) { a = l.btoa(a + b); v(a, c) }, W = function (a, b, c) { for (var d = [], e = 2; e < arguments.length; ++e)d[e - 2] = arguments[e]; e = l.btoa(a + b); e = l[e]; if ("function" == r(e)) e.apply(null, d); else throw Error("API not exported."); }; var X = function (a) { O(this, a) }; u(X, M); var Y = function (a) { this.h = window; this.a = a; this.b = Q(this.a, 1); this.f = R(this.a, T, 2); this.g = R(this.a, U, 3); this.c = !1 }; Y.prototype.start = function () { ma(); var a = new ja(this.h.document, this.g); la(this.b, a); na(this) };
#       var ma = function () { var a = function () { if (!l.frames.googlefcPresent) if (document.body) { var b = document.createElement("iframe"); b.style.display = "none"; b.style.width = "0px"; b.style.height = "0px"; b.style.border = "none"; b.style.zIndex = "-1000"; b.style.left = "-1000px"; b.style.top = "-1000px"; b.name = "googlefcPresent"; document.body.appendChild(b) } else l.setTimeout(a, 5) }; a() }, na = function (a) {
#         var b = Date.now(); W(a.b, "internal_api_load_with_sb", a.f.h(), function () {
#           var c; var d = a.b, e = l[l.btoa(d + "loader_js")]; if (e) {
#             e = l.atob(e);
#             e = parseInt(e, 10); d = l.btoa(d + "loader_js").split("."); var f = l; d[0] in f || "undefined" == typeof f.execScript || f.execScript("var " + d[0]); for (; d.length && (c = d.shift());)d.length ? f[c] && f[c] !== Object.prototype[c] ? f = f[c] : f = f[c] = {} : f[c] = null; c = Math.abs(b - e); c = 1728E5 > c ? 0 : c
#           } else c = -1; 0 != c && (W(a.b, "internal_api_sb"), Z(a, Q(a.a, 6)))
#         }, function (c) { Z(a, c ? Q(a.a, 4) : Q(a.a, 5)) })
#       }, Z = function (a, b) { a.c || (a.c = !0, a = new l.XMLHttpRequest, a.open("GET", b, !0), a.send()) }; (function (a, b) { l[a] = function (c) { for (var d = [], e = 0; e < arguments.length; ++e)d[e - 0] = arguments[e]; l[a] = q; b.apply(null, d) } })("__d3lUW8vwsKlB__", function (a) { "function" == typeof window.atob && (a = window.atob(a), a = new X(a ? JSON.parse(a) : null), (new Y(a)).start()) });
#     }).call(this);
#
#     window.__d3lUW8vwsKlB__("...");
#   </script>
# <script>
#     window.__prebidAdUnits = [];
#     (function() {
#       var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
#       pbs.async = true;
#       pbs.src = '//s.mxmcdn.net/site/js/prebid4.13.0.js';
#       var target = document.getElementsByTagName('head')[0];
#       target.insertBefore(pbs, target.firstChild);
#     })();
#   </script>
# <script>
#     var cssua=function(n,l,p){var q=/\s*([\-\w ]+)[\s\/\:]([\d_]+\b(?:[\-\._\/]\w+)*)/,r=/([\w\-\.]+[\s\/][v]?[\d_]+\b(?:[\-\._\/]\w+)*)/g,s=/\b(?:(blackberry\w*|bb10)|(rim tablet os))(?:\/(\d+\.\d+(?:\.\w+)*))?/,t=/\bsilk-accelerated=true\b/,u=/\bfluidapp\b/,v=/(\bwindows\b|\bmacintosh\b|\blinux\b|\bunix\b)/,w=/(\bandroid\b|\bipad\b|\bipod\b|\bwindows phone\b|\bwpdesktop\b|\bxblwp7\b|\bzunewp7\b|\bwindows ce\b|\bblackberry\w*|\bbb10\b|\brim tablet os\b|\bmeego|\bwebos\b|\bpalm|\bsymbian|\bj2me\b|\bdocomo\b|\bpda\b|\bchtml\b|\bmidp\b|\bcldc\b|\w*?mobile\w*?|\w*?phone\w*?)/,
#     x=/(\bxbox\b|\bplaystation\b|\bnintendo\s+\w+)/,k={parse:function(b,d){var a={};d&&(a.standalone=d);b=(""+b).toLowerCase();if(!b)return a;for(var c,e,g=b.split(/[()]/),f=0,k=g.length;f<k;f++)if(f%2){var m=g[f].split(";");c=0;for(e=m.length;c<e;c++)if(q.exec(m[c])){var h=RegExp.$1.split(" ").join("_"),l=RegExp.$2;if(!a[h]||parseFloat(a[h])<parseFloat(l))a[h]=l}}else if(m=g[f].match(r))for(c=0,e=m.length;c<e;c++)h=m[c].split(/[\/\s]+/),h.length&&"mozilla"!==h[0]&&(a[h[0].split(" ").join("_")]=h.slice(1).join("-"));
#     w.exec(b)?(a.mobile=RegExp.$1,s.exec(b)&&(delete a[a.mobile],a.blackberry=a.version||RegExp.$3||RegExp.$2||RegExp.$1,RegExp.$1?a.mobile="blackberry":"0.0.1"===a.version&&(a.blackberry="7.1.0.0"))):x.exec(b)?(a.game=RegExp.$1,c=a.game.split(" ").join("_"),a.version&&!a[c]&&(a[c]=a.version)):v.exec(b)&&(a.desktop=RegExp.$1);a.intel_mac_os_x?(a.mac_os_x=a.intel_mac_os_x.split("_").join("."),delete a.intel_mac_os_x):a.cpu_iphone_os?(a.ios=a.cpu_iphone_os.split("_").join("."),delete a.cpu_iphone_os):a.cpu_os?
#     (a.ios=a.cpu_os.split("_").join("."),delete a.cpu_os):"iphone"!==a.mobile||a.ios||(a.ios="1");a.opera&&a.version?(a.opera=a.version,delete a.blackberry):t.exec(b)?a.silk_accelerated=!0:u.exec(b)&&(a.fluidapp=a.version);a.edge&&(delete a.applewebkit,delete a.safari,delete a.chrome,delete a.android);if(a.applewebkit)a.webkit=a.applewebkit,delete a.applewebkit,a.opr&&(a.opera=a.opr,delete a.opr,delete a.chrome),a.safari&&(a.chrome||a.crios||a.fxios||a.opera||a.silk||a.fluidapp||a.phantomjs||a.mobile&&
#     !a.ios?(delete a.safari,a.vivaldi&&delete a.chrome):a.safari=a.version&&!a.rim_tablet_os?a.version:{419:"2.0.4",417:"2.0.3",416:"2.0.2",412:"2.0",312:"1.3",125:"1.2",85:"1.0"}[parseInt(a.safari,10)]||a.safari);else if(a.msie||a.trident)if(a.opera||(a.ie=a.msie||a.rv),delete a.msie,delete a.android,a.windows_phone_os)a.windows_phone=a.windows_phone_os,delete a.windows_phone_os;else{if("wpdesktop"===a.mobile||"xblwp7"===a.mobile||"zunewp7"===a.mobile)a.mobile="windows desktop",a.windows_phone=9>+a.ie?
#     "7.0":10>+a.ie?"7.5":"8.0",delete a.windows_nt}else if(a.gecko||a.firefox)a.gecko=a.rv;a.rv&&delete a.rv;a.version&&delete a.version;return a},format:function(b){var d="",a;for(a in b)if(a&&b.hasOwnProperty(a)){var c=a,e=b[a],c=c.split(".").join("-"),g=" ua-"+c;if("string"===typeof e){for(var e=e.split(" ").join("_").split(".").join("-"),f=e.indexOf("-");0<f;)g+=" ua-"+c+"-"+e.substring(0,f),f=e.indexOf("-",f+1);g+=" ua-"+c+"-"+e}d+=g}return d},encode:function(b){var d="",a;for(a in b)a&&b.hasOwnProperty(a)&&
#     (d&&(d+="\x26"),d+=encodeURIComponent(a)+"\x3d"+encodeURIComponent(b[a]));return d}};k.userAgent=k.ua=k.parse(l,p);l=k.format(k.ua)+" js";n.className=n.className?n.className.replace(/\bno-js\b/g,"")+l:l.substr(1);return k}(document.documentElement,navigator.userAgent,navigator.standalone);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a38809cc79","applicationID":"11518440","applicationTime":10.057223,"transactionName":"ZVdUZEdSXUVUVEAIX1wddUVGR1xbGkRRAEJRWhkYbm1vQwUHBgdtGRs=","queueTime":0,"ttGuid":"43ef62eae90838","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"Uw8PVlVXGwIBUVBaAwUH",licenseKey:"a38809cc79",applicationID:"11518440"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(wind ...
# <link href="//s.mxmcdn.net/site/css/styles-39907f576175ff4a85ae.css" rel="stylesheet" type="text/css"/>
# <link href="//s.mxmcdn.net/site/css/styles-54104562bfd9047a28bf.css" rel="stylesheet" type="text/css"/>
# <script>__mxmStatusCode = 200;__mxmSession = {"userCountry":{"code":"US","name":"United States","continentCode":"NA"}};__mxmHeaders = {};</script>
# <meta content="5381b8eb344dfaa4" name="yandex-verification"/>
# <meta content="notranslate" name="google"/>
# <title>Search results for Dave Matthews Band</title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge; chrome=1" http-equiv="X-UA-Compatible"/><meta content="Search any lyrics by title, artist or text on Musixmatch, the world's largest lyrics catalog" name="description"/><meta content="https://www.musixmatch.com" name="identifier"/><meta content="lyrics, video, meaning, writer, music video, top songs lyrics, synced lyrics, music player, artist, karaoke" name="keywords"/><meta content="_8faEqn-rAfu0zKe0faUhuSHMNf6SN9dudWkxouG_us" name="google-site-verification"/><meta content="m6xTItKX2q" name="baidu-site-verification"/><meta content="42d34374a1270f3e" name="yandex-verification"/><meta content="app-id=448278467, affiliate-data=http://clk.tradedoubler.com/click?p=24373&amp;amp;a=1805894, app-argument=mxm://search/Dave%20Matthews%20Band" name="apple-itunes-app"/><link href="//s.mxmcdn.net" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//d2b1xqaw2ss8na.cloudfront.net" rel="dns-prefetch"/><link href="//platform.twitter.com" rel="dns-prefetch"/><link href="/opensearch.xml" rel="search" title="Musixmatch" type="application/opensearchdescription+xml"/><link rel="canonical"/><link href="//s.mxmcdn.net/site/images/favicon.png" rel="shortcut icon"/><link href="https://plus.google.com/+musiXmatch" rel="publisher"/><meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0" name="viewport"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="//s.mxmcdn.net/site/images/win_tile_144.png" name="msapplication-TileImage"/><meta content="#ff6600" name="msapplication-TileColor"/><link href="//s.mxmcdn.net/site/images/mxm_icn_72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//s.mxmcdn.net/site/images/mxm_icn_114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//s.mxmcdn.net/site/images/mxm_icn_57.png" rel="apple-touch-icon"/><meta content="131314396964274" property="fb:app_id"/><meta content="688442030" property="fb:admins"/><meta content="4f6d74a840fa7f3f5fe34b553ebbb4dc" name="p:domain_verify"/><link href="https://chrome.google.com/webstore/detail/gfenjblodoldnbiddmggcbkcapiolbig" rel="chrome-webstore-item"/><meta content="en" http-equiv="content-language"/>
# <script>
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     pbjs.bidderSettings = {
#         rubicon: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85 * 0.84;
#             }
#         },
#         appnexus: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         },
#         ix: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         }
#     };
# </script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function () {
#         googletag.pubads().disableInitialLoad();
#     });
#
#     var priceGranularity = {
#         buckets: [{
#             min: 0,
#             max: 31.49,
#             increment: 0.01
#         }]
#     };
#
#     function sendAdserverRequest() {
#         if (pbjs.adserverRequestSent) return;
#         pbjs.adserverRequestSent = true;
#         googletag.cmd.push(function () {
#             pbjs.que.push(function () {
#                 pbjs.setTargetingForGPTAsync();
#                 googletag.pubads().refresh();
#             });
#         });
#     }
# </script>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function () {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#             '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#     function getParameterByName(name, url) {
#         if (!url) url = window.location.href;
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)"),
#             results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#     }
#
#     googletag.cmd.push(function () {
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().disableInitialLoad();
#         googletag.pubads().collapseEmptyDivs();
#         var campaign = getParameterByName('utm_campaign');
#         if (campaign) {
#             googletag.pubads().setTargeting('utm_campaign', campaign);
#         }
#         googletag.enableServices();
#     });
#
#     // Make sure that the properties exist on the window.
#     window.googlefc = window.googlefc || {};
#     window.googlefc.ccpa = window.googlefc.ccpa || {}
#     window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#     // Queue the callback on the callbackQueue.
#     googlefc.callbackQueue.push({
#         'CONSENT_DATA_READY':
#             () => __tcfapi('getTCData', 0, (data, success) => {
#                 var FAILSAFE_TIMEOUT = 3000;
#
#                 pbjs.que.push(function () {
#                     pbjs.enableAnalytics([{
#                         provider: 'ga'
#                     }]);
#                     pbjs.setConfig({
#                         bidderSequence: 'random',
#                         enableSendAllBids: true,
#                         priceGranularity: priceGranularity,
#                         consentManagement: {
#                             gdpr: {
#                                 cmpApi: 'iab',
#                                 defaultGdprScope: true
#                             }
#                         }
#                     })
#                     pbjs.addAdUnits(__prebidAdUnits);
#                     pbjs.requestBids({
#                         bidsBackHandler: sendAdserverRequest
#                     });
#                 });
#
#                 setTimeout(function () {
#                     sendAdserverRequest();
#                 }, FAILSAFE_TIMEOUT);
#             })
#     });
# </script>
# </head>
# <body class="" spellcheck="false">
# <div id="fb-root"></div>
# <div id="site"><div class="" data-reactroot="" id="search-results"><div class="navbar" id="header" role="banner"><nav class="top-bar desktop-bar" data-topbar="true"><section class="top-bar-section"><ul class="title-area"><li class="name"><h1><a href="/" id="logo"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg" width="40"/></a></h1></li></ul><ul class="search-nav" role="search"><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div></form></li></ul><div class="top-bar-right"><ul class="site-nav" role="navigation"><li><a href="/explore">Top lyrics</a></li><li><a href="/community">Community</a></li><li><a href="/contribute">Contribute</a></li><li><a href="https://about.musixmatch.com/business/overview">Business</a></li></ul><ul class="user-nav"><li><ul class="user-nav-items loggedOut"><li id="sign-in"><a data-external-link="true" href="/sign-in">Sign in</a></li><li id="sign-up"><a data-external-link="true" href="/sign-up">Sign up</a></li></ul></li></ul></div></section></nav><nav class="top-bar mobile-top-bar"><ul class="title-area"><li class="offcanvas-toggler"><a href="#"><i class="icon icon-list"></i></a></li><li class="name"><h1><a href="/"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg"/></a></h1></li><li class="toggle-search-bar"><a href="#"><span><i class="icon icon-search"></i></span></a></li><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div><button class="button button-link search-bar-cancel"><i class="icon icon-cross"></i></button></form></li></ul></nav><noscript></noscript></div><div id="content" role="main"><div class="search-results"><div class="main-wrapper"><h1><span>Search results for <span><span class="search_query">Dave Matthews Band</span></span></span></h1><div><div class="section-header"><ul class="tabs"><li class="selected" id="all-results"><a href="/search/Dave%20Matthews%20Band">All results</a></li><li class="" id="tracks"><a href="/search/Dave%20Matthews%20Band/tracks">Tracks</a></li><li class="" id="artists"><a href="/search/Dave%20Matthews%20Band/artists">Artists</a></li><li class="" id="lyrics"><a href="/search/Dave%20Matthews%20Band/lyrics">Lyrics</a></li></ul></div><div class="tab-content"><div id="search-all-results"><div class="main-panel"><div class="box box-style-plain"><div class="box-header"><h3 class="box-title"> <!-- -->Best Result</h3><div class="actions"></div></div><div class="box-content"><ul class="artists list"><li><div class="artist-card media-card has-picture"><div class="media-card-picture"><img alt="Dave Matthews Band" src="https://static.musixmatch.com/images-storage/mxmimages/2/2/8/4/3/34822_14.jpg"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="cover" href="/artist/Dave-Matthews-Band">Dave Matthews Band</a></h2></div></div></div></li></ul></div></div><div class="box box-style-plain"><div class="box-header"><h3 class="box-title"> <!-- -->Tracks</h3><div class="actions"><a class="see-all-action" href="/search/Dave Matthews Band/tracks">See all</a></div></div><div class="box-content"><div><ul class="tracks list"><li class="showArtist showCoverart"><div class="track-card media-card has-picture"><div class="media-card-picture"><img alt="#36 by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446.jpg 320w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/271 ...
#  ðŸŒŽ Enjoyed everywhere</p></div></div></div><span></span></div></div>
# <script></script></body></html>

# %%
div = bsdata.find("div", {"id": "search-results"})
if div is not None:
    artists = div.find("div", {"class": "search-results"})
    print(artists)
# Out:
# <div class="search-results"><div class="main-wrapper"><h1><span>Search results for <span><span class="search_query">Dave Matthews Band</span></span></span></h1><div><div class="section-header"><ul class="tabs"><li class="selected" id="all-results"><a href="/search/Dave%20Matthews%20Band">All results</a></li><li class="" id="tracks"><a href="/search/Dave%20Matthews%20Band/tracks">Tracks</a></li><li class="" id="artists"><a href="/search/Dave%20Matthews%20Band/artists">Artists</a></li><li class="" id="lyrics"><a href="/search/Dave%20Matthews%20Band/lyrics">Lyrics</a></li></ul></div><div class="tab-content"><div id="search-all-results"><div class="main-panel"><div class="box box-style-plain"><div class="box-header"><h3 class="box-title"> <!-- -->Best Result</h3><div class="actions"></div></div><div class="box-content"><ul class="artists list"><li><div class="artist-card media-card has-picture"><div class="media-card-picture"><img alt="Dave Matthews Band" src="https://static.musixmatch.com/images-storage/mxmimages/2/2/8/4/3/34822_14.jpg"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="cover" href="/artist/Dave-Matthews-Band">Dave Matthews Band</a></h2></div></div></div></li></ul></div></div><div class="box box-style-plain"><div class="box-header"><h3 class="box-title"> <!-- -->Tracks</h3><div class="actions"><a class="see-all-action" href="/search/Dave Matthews Band/tracks">See all</a></div></div><div class="box-content"><div><ul class="tracks list"><li class="showArtist showCoverart"><div class="track-card media-card has-picture"><div class="media-card-picture"><img alt="#36 by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446.jpg 320w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums/6/4/4/8/6/1/27168446_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="title" href="/lyrics/Dave-Matthews-Band/36"><span>#36</span></a></h2><h3 class="media-card-subtitle"><span class="artist-field"><span><a class="artist" href="/artist/Dave-Matthews-Band">Dave Matthews Band</a></span></span></h3></div></div><meta content="/lyrics/Dave-Matthews-Band/36" itemprop="url"/><meta content="/lyrics/Dave-Matthews-Band/36/play" itemprop="audio"/><meta content="PT12M55S" itemprop="duration"/><meta content="Live At Red Rocks 8.15.95" itemprop="inalbum"/></div></li><li class="showArtist showCoverart"><div class="track-card media-card has-picture"><div class="media-card-picture"><img alt="#40 by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums/0/0/8/6/8/4/11486800.jpg 320w, https://s.mxmcdn.net/images-storage/albums/0/0/8/6/8/4/11486800_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums/0/0/8/6/8/4/11486800_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums/0/0/8/6/8/4/11486800_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="title" href="/lyrics/Dave-Matthews-Band/40"><span>#40</span></a></h2><h3 class="media-card-subtitle"><span class="artist-field"><span><a class="artist" href="/artist/Dave-Matthews-Band">Dave Matthews Band</a></span></span></h3></div></div><meta content="/lyrics/Dave-Matthews-Band/40" itemprop="url"/><meta content="/lyrics/Dave-Matthews-Band/40/play" itemprop="audio"/><meta content="PT1M50S" itemprop="duration"/><meta content="Listener Supported" itemprop="inalbum"/></div></li><li class="showArtist showCoverart"><div class="track-card media-card has-picture"><div class="media-card-picture"><img alt="Two Step - 06/07/08 Busch Stadium St. Louis by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums/4/2/2/5/1/1/32115224.jpg 320w, https://s.mxmcdn.n ...

# %%
from fsUtils import isFile
url="https://www.musixmatch.com/search/Dave%20Matthews%20Band/artists"
savename = "musixmatch_searchartist.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.musixmatch.com/search/Dave%20Matthews%20Band/artists
#   --> This file is 28.6kB.

# %%
bsdata = getHTML(savename)

# %%
bsdata
# Out:
# <!DOCTYPE html>
# <html class="search-results-page" xmlns:og="http://ogp.me/ns#">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# musixmatch: http://ogp.me/ns/fb/musixmatch#">
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     window._mxm_ga_firstLoad = true; //flag page tracked on first load
#     ga('create', 'UA-16453829-10', 'auto');
#     ga('require', '');
#     ga('send', 'pageview');
#   </script>
# <script>(function () {/*
#
#   Copyright The Closure Library Authors.
#   SPDX-License-Identifier: Apache-2.0
#   */
#       'use strict'; var g = function (a) { var b = 0; return function () { return b < a.length ? { done: !1, value: a[b++] } : { done: !0 } } }, l = this || self, m = /^[\w+/_-]+[=]{0,2}$/, p = null, q = function () { }, r = function (a) {
#         var b = typeof a; if ("object" == b) if (a) {
#           if (a instanceof Array) return "array"; if (a instanceof Object) return b; var c = Object.prototype.toString.call(a); if ("[object Window]" == c) return "object"; if ("[object Array]" == c || "number" == typeof a.length && "undefined" != typeof a.splice && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("splice")) return "array";
#           if ("[object Function]" == c || "undefined" != typeof a.call && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("call")) return "function"
#         } else return "null"; else if ("function" == b && "undefined" == typeof a.call) return "object"; return b
#       }, u = function (a, b) { function c() { } c.prototype = b.prototype; a.prototype = new c; a.prototype.constructor = a }; var v = function (a, b) { Object.defineProperty(l, a, { configurable: !1, get: function () { return b }, set: q }) }; var y = function (a, b) { this.b = a === w && b || ""; this.a = x }, x = {}, w = {}; var aa = function (a, b) { a.src = b instanceof y && b.constructor === y && b.a === x ? b.b : "type_error:TrustedResourceUrl"; if (null === p) b: { b = l.document; if ((b = b.querySelector && b.querySelector("script[nonce]")) && (b = b.nonce || b.getAttribute("nonce")) && m.test(b)) { p = b; break b } p = "" } b = p; b && a.setAttribute("nonce", b) }; var z = function () { return Math.floor(2147483648 * Math.random()).toString(36) + Math.abs(Math.floor(2147483648 * Math.random()) ^ +new Date).toString(36) }; var A = function (a, b) { b = String(b); "application/xhtml+xml" === a.contentType && (b = b.toLowerCase()); return a.createElement(b) }, B = function (a) { this.a = a || l.document || document }; B.prototype.appendChild = function (a, b) { a.appendChild(b) }; var C = function (a, b, c, d, e, f) { try { var k = a.a, h = A(a.a, "SCRIPT"); h.async = !0; aa(h, b); k.head.appendChild(h); h.addEventListener("load", function () { e(); d && k.head.removeChild(h) }); h.addEventListener("error", function () { 0 < c ? C(a, b, c - 1, d, e, f) : (d && k.head.removeChild(h), f()) }) } catch (n) { f() } }; var ba = l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"), ca = l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="), da = l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"), ea = function (a, b, c) { this.b = a; this.f = new B(this.b); this.a = null; this.c = []; this.g = !1; this.i = b; this.h = c }, F = function (a) {
#         if (a.b.body && !a.g) {
#           var b =
#             function () { D(a); l.setTimeout(function () { return E(a, 3) }, 50) }; C(a.f, a.i, 2, !0, function () { l[a.h] || b() }, b); a.g = !0
#         }
#       }, D = function (a) {
#         for (var b = G(1, 5), c = 0; c < b; c++) { var d = H(a); a.b.body.appendChild(d); a.c.push(d) } b = H(a); b.style.bottom = "0"; b.style.left = "0"; b.style.position = "fixed"; b.style.width = G(100, 110).toString() + "%"; b.style.zIndex = G(2147483544, 2147483644).toString(); b.style["background-color"] = I(249, 259, 242, 252, 219, 229); b.style["box-shadow"] = "0 0 12px #888"; b.style.color = I(0, 10, 0, 10, 0, 10); b.style.display =
#           "flex"; b.style["justify-content"] = "center"; b.style["font-family"] = "Roboto, Arial"; c = H(a); c.style.width = G(80, 85).toString() + "%"; c.style.maxWidth = G(750, 775).toString() + "px"; c.style.margin = "24px"; c.style.display = "flex"; c.style["align-items"] = "flex-start"; c.style["justify-content"] = "center"; d = A(a.f.a, "IMG"); d.className = z(); d.src = ba; d.style.height = "24px"; d.style.width = "24px"; d.style["padding-right"] = "16px"; var e = H(a), f = H(a); f.style["font-weight"] = "bold"; f.textContent = ca; var k = H(a); k.textContent = da; J(a,
#             e, f); J(a, e, k); J(a, c, d); J(a, c, e); J(a, b, c); a.a = b; a.b.body.appendChild(a.a); b = G(1, 5); for (c = 0; c < b; c++)d = H(a), a.b.body.appendChild(d), a.c.push(d)
#       }, J = function (a, b, c) { for (var d = G(1, 5), e = 0; e < d; e++) { var f = H(a); b.appendChild(f) } b.appendChild(c); c = G(1, 5); for (d = 0; d < c; d++)e = H(a), b.appendChild(e) }, G = function (a, b) { return Math.floor(a + Math.random() * (b - a)) }, I = function (a, b, c, d, e, f) {
#         return "rgb(" + G(Math.max(a, 0), Math.min(b, 255)).toString() + "," + G(Math.max(c, 0), Math.min(d, 255)).toString() + "," + G(Math.max(e, 0), Math.min(f,
#           255)).toString() + ")"
#       }, H = function (a) { a = A(a.f.a, "DIV"); a.className = z(); return a }, E = function (a, b) { 0 >= b || null != a.a && 0 != a.a.offsetHeight && 0 != a.a.offsetWidth || (fa(a), D(a), l.setTimeout(function () { return E(a, b - 1) }, 50)) }, fa = function (a) { var b = a.c; var c = "undefined" != typeof Symbol && Symbol.iterator && b[Symbol.iterator]; b = c ? c.call(b) : { next: g(b) }; for (c = b.next(); !c.done; c = b.next())(c = c.value) && c.parentNode && c.parentNode.removeChild(c); a.c = []; (b = a.a) && b.parentNode && b.parentNode.removeChild(b); a.a = null }; var ia = function (a, b, c, d, e) { var f = ha(c), k = function (n) { n.appendChild(f); l.setTimeout(function () { f ? (0 !== f.offsetHeight && 0 !== f.offsetWidth ? b() : a(), f.parentNode && f.parentNode.removeChild(f)) : a() }, d) }, h = function (n) { document.body ? k(document.body) : 0 < n ? l.setTimeout(function () { h(n - 1) }, e) : b() }; h(3) }, ha = function (a) { var b = document.createElement("div"); b.className = a; b.style.width = "1px"; b.style.height = "1px"; b.style.position = "absolute"; b.style.left = "-10000px"; b.style.top = "-10000px"; b.style.zIndex = "-10000"; return b }; var K = {}, L = null; var M = function () { }, N = "function" == typeof Uint8Array, O = function (a, b) { a.b = null; b || (b = []); a.j = void 0; a.f = -1; a.a = b; a: { if (b = a.a.length) { --b; var c = a.a[b]; if (!(null === c || "object" != typeof c || Array.isArray(c) || N && c instanceof Uint8Array)) { a.g = b - a.f; a.c = c; break a } } a.g = Number.MAX_VALUE } a.i = {} }, P = [], Q = function (a, b) { if (b < a.g) { b += a.f; var c = a.a[b]; return c === P ? a.a[b] = [] : c } if (a.c) return c = a.c[b], c === P ? a.c[b] = [] : c }, R = function (a, b, c) { a.b || (a.b = {}); if (!a.b[c]) { var d = Q(a, c); d && (a.b[c] = new b(d)) } return a.b[c] };
#       M.prototype.h = N ? function () {
#         var a = Uint8Array.prototype.toJSON; Uint8Array.prototype.toJSON = function () {
#           var b; void 0 === b && (b = 0); if (!L) { L = {}; for (var c = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""), d = ["+/=", "+/", "-_=", "-_.", "-_"], e = 0; 5 > e; e++) { var f = c.concat(d[e].split("")); K[e] = f; for (var k = 0; k < f.length; k++) { var h = f[k]; void 0 === L[h] && (L[h] = k) } } } b = K[b]; c = []; for (d = 0; d < this.length; d += 3) {
#             var n = this[d], t = (e = d + 1 < this.length) ? this[d + 1] : 0; h = (f = d + 2 < this.length) ? this[d + 2] : 0; k = n >> 2; n = (n &
#               3) << 4 | t >> 4; t = (t & 15) << 2 | h >> 6; h &= 63; f || (h = 64, e || (t = 64)); c.push(b[k], b[n], b[t] || "", b[h] || "")
#           } return c.join("")
#         }; try { return JSON.stringify(this.a && this.a, S) } finally { Uint8Array.prototype.toJSON = a }
#       } : function () { return JSON.stringify(this.a && this.a, S) }; var S = function (a, b) { return "number" !== typeof b || !isNaN(b) && Infinity !== b && -Infinity !== b ? b : String(b) }; M.prototype.toString = function () { return this.a.toString() }; var T = function (a) { O(this, a) }; u(T, M); var U = function (a) { O(this, a) }; u(U, M); var ja = function (a, b) { this.c = new B(a); var c = R(b, T, 5); c = new y(w, Q(c, 4) || ""); this.b = new ea(a, c, Q(b, 4)); this.a = b }, ka = function (a, b, c, d) { b = new T(b ? JSON.parse(b) : null); b = new y(w, Q(b, 4) || ""); C(a.c, b, 3, !1, c, function () { ia(function () { F(a.b); d(!1) }, function () { d(!0) }, Q(a.a, 2), Q(a.a, 3), Q(a.a, 1)) }) }; var la = function (a, b) { V(a, "internal_api_load_with_sb", function (c, d, e) { ka(b, c, d, e) }); V(a, "internal_api_sb", function () { F(b.b) }) }, V = function (a, b, c) { a = l.btoa(a + b); v(a, c) }, W = function (a, b, c) { for (var d = [], e = 2; e < arguments.length; ++e)d[e - 2] = arguments[e]; e = l.btoa(a + b); e = l[e]; if ("function" == r(e)) e.apply(null, d); else throw Error("API not exported."); }; var X = function (a) { O(this, a) }; u(X, M); var Y = function (a) { this.h = window; this.a = a; this.b = Q(this.a, 1); this.f = R(this.a, T, 2); this.g = R(this.a, U, 3); this.c = !1 }; Y.prototype.start = function () { ma(); var a = new ja(this.h.document, this.g); la(this.b, a); na(this) };
#       var ma = function () { var a = function () { if (!l.frames.googlefcPresent) if (document.body) { var b = document.createElement("iframe"); b.style.display = "none"; b.style.width = "0px"; b.style.height = "0px"; b.style.border = "none"; b.style.zIndex = "-1000"; b.style.left = "-1000px"; b.style.top = "-1000px"; b.name = "googlefcPresent"; document.body.appendChild(b) } else l.setTimeout(a, 5) }; a() }, na = function (a) {
#         var b = Date.now(); W(a.b, "internal_api_load_with_sb", a.f.h(), function () {
#           var c; var d = a.b, e = l[l.btoa(d + "loader_js")]; if (e) {
#             e = l.atob(e);
#             e = parseInt(e, 10); d = l.btoa(d + "loader_js").split("."); var f = l; d[0] in f || "undefined" == typeof f.execScript || f.execScript("var " + d[0]); for (; d.length && (c = d.shift());)d.length ? f[c] && f[c] !== Object.prototype[c] ? f = f[c] : f = f[c] = {} : f[c] = null; c = Math.abs(b - e); c = 1728E5 > c ? 0 : c
#           } else c = -1; 0 != c && (W(a.b, "internal_api_sb"), Z(a, Q(a.a, 6)))
#         }, function (c) { Z(a, c ? Q(a.a, 4) : Q(a.a, 5)) })
#       }, Z = function (a, b) { a.c || (a.c = !0, a = new l.XMLHttpRequest, a.open("GET", b, !0), a.send()) }; (function (a, b) { l[a] = function (c) { for (var d = [], e = 0; e < arguments.length; ++e)d[e - 0] = arguments[e]; l[a] = q; b.apply(null, d) } })("__d3lUW8vwsKlB__", function (a) { "function" == typeof window.atob && (a = window.atob(a), a = new X(a ? JSON.parse(a) : null), (new Y(a)).start()) });
#     }).call(this);
#
#     window.__d3lUW8vwsKlB__("...");
#   </script>
# <script>
#     window.__prebidAdUnits = [];
#     (function() {
#       var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
#       pbs.async = true;
#       pbs.src = '//s.mxmcdn.net/site/js/prebid4.13.0.js';
#       var target = document.getElementsByTagName('head')[0];
#       target.insertBefore(pbs, target.firstChild);
#     })();
#   </script>
# <script>
#     var cssua=function(n,l,p){var q=/\s*([\-\w ]+)[\s\/\:]([\d_]+\b(?:[\-\._\/]\w+)*)/,r=/([\w\-\.]+[\s\/][v]?[\d_]+\b(?:[\-\._\/]\w+)*)/g,s=/\b(?:(blackberry\w*|bb10)|(rim tablet os))(?:\/(\d+\.\d+(?:\.\w+)*))?/,t=/\bsilk-accelerated=true\b/,u=/\bfluidapp\b/,v=/(\bwindows\b|\bmacintosh\b|\blinux\b|\bunix\b)/,w=/(\bandroid\b|\bipad\b|\bipod\b|\bwindows phone\b|\bwpdesktop\b|\bxblwp7\b|\bzunewp7\b|\bwindows ce\b|\bblackberry\w*|\bbb10\b|\brim tablet os\b|\bmeego|\bwebos\b|\bpalm|\bsymbian|\bj2me\b|\bdocomo\b|\bpda\b|\bchtml\b|\bmidp\b|\bcldc\b|\w*?mobile\w*?|\w*?phone\w*?)/,
#     x=/(\bxbox\b|\bplaystation\b|\bnintendo\s+\w+)/,k={parse:function(b,d){var a={};d&&(a.standalone=d);b=(""+b).toLowerCase();if(!b)return a;for(var c,e,g=b.split(/[()]/),f=0,k=g.length;f<k;f++)if(f%2){var m=g[f].split(";");c=0;for(e=m.length;c<e;c++)if(q.exec(m[c])){var h=RegExp.$1.split(" ").join("_"),l=RegExp.$2;if(!a[h]||parseFloat(a[h])<parseFloat(l))a[h]=l}}else if(m=g[f].match(r))for(c=0,e=m.length;c<e;c++)h=m[c].split(/[\/\s]+/),h.length&&"mozilla"!==h[0]&&(a[h[0].split(" ").join("_")]=h.slice(1).join("-"));
#     w.exec(b)?(a.mobile=RegExp.$1,s.exec(b)&&(delete a[a.mobile],a.blackberry=a.version||RegExp.$3||RegExp.$2||RegExp.$1,RegExp.$1?a.mobile="blackberry":"0.0.1"===a.version&&(a.blackberry="7.1.0.0"))):x.exec(b)?(a.game=RegExp.$1,c=a.game.split(" ").join("_"),a.version&&!a[c]&&(a[c]=a.version)):v.exec(b)&&(a.desktop=RegExp.$1);a.intel_mac_os_x?(a.mac_os_x=a.intel_mac_os_x.split("_").join("."),delete a.intel_mac_os_x):a.cpu_iphone_os?(a.ios=a.cpu_iphone_os.split("_").join("."),delete a.cpu_iphone_os):a.cpu_os?
#     (a.ios=a.cpu_os.split("_").join("."),delete a.cpu_os):"iphone"!==a.mobile||a.ios||(a.ios="1");a.opera&&a.version?(a.opera=a.version,delete a.blackberry):t.exec(b)?a.silk_accelerated=!0:u.exec(b)&&(a.fluidapp=a.version);a.edge&&(delete a.applewebkit,delete a.safari,delete a.chrome,delete a.android);if(a.applewebkit)a.webkit=a.applewebkit,delete a.applewebkit,a.opr&&(a.opera=a.opr,delete a.opr,delete a.chrome),a.safari&&(a.chrome||a.crios||a.fxios||a.opera||a.silk||a.fluidapp||a.phantomjs||a.mobile&&
#     !a.ios?(delete a.safari,a.vivaldi&&delete a.chrome):a.safari=a.version&&!a.rim_tablet_os?a.version:{419:"2.0.4",417:"2.0.3",416:"2.0.2",412:"2.0",312:"1.3",125:"1.2",85:"1.0"}[parseInt(a.safari,10)]||a.safari);else if(a.msie||a.trident)if(a.opera||(a.ie=a.msie||a.rv),delete a.msie,delete a.android,a.windows_phone_os)a.windows_phone=a.windows_phone_os,delete a.windows_phone_os;else{if("wpdesktop"===a.mobile||"xblwp7"===a.mobile||"zunewp7"===a.mobile)a.mobile="windows desktop",a.windows_phone=9>+a.ie?
#     "7.0":10>+a.ie?"7.5":"8.0",delete a.windows_nt}else if(a.gecko||a.firefox)a.gecko=a.rv;a.rv&&delete a.rv;a.version&&delete a.version;return a},format:function(b){var d="",a;for(a in b)if(a&&b.hasOwnProperty(a)){var c=a,e=b[a],c=c.split(".").join("-"),g=" ua-"+c;if("string"===typeof e){for(var e=e.split(" ").join("_").split(".").join("-"),f=e.indexOf("-");0<f;)g+=" ua-"+c+"-"+e.substring(0,f),f=e.indexOf("-",f+1);g+=" ua-"+c+"-"+e}d+=g}return d},encode:function(b){var d="",a;for(a in b)a&&b.hasOwnProperty(a)&&
#     (d&&(d+="\x26"),d+=encodeURIComponent(a)+"\x3d"+encodeURIComponent(b[a]));return d}};k.userAgent=k.ua=k.parse(l,p);l=k.format(k.ua)+" js";n.className=n.className?n.className.replace(/\bno-js\b/g,"")+l:l.substr(1);return k}(document.documentElement,navigator.userAgent,navigator.standalone);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a38809cc79","applicationID":"11518440","applicationTime":18.355952,"transactionName":"ZVdUZEdSXUVUVEAIX1wddUVGR1xbGkRRAEJRWhkYbm1vQwUHBgdtGRsZUUdHWkVBRA==","queueTime":0,"ttGuid":"99823ea3f82f40","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"Uw8PVlVXGwIBUVBaAwUH",licenseKey:"a38809cc79",applicationID:"11518440"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(docu ...
# <link href="//s.mxmcdn.net/site/css/styles-39907f576175ff4a85ae.css" rel="stylesheet" type="text/css"/>
# <link href="//s.mxmcdn.net/site/css/styles-54104562bfd9047a28bf.css" rel="stylesheet" type="text/css"/>
# <script>__mxmStatusCode = 200;__mxmSession = {"userCountry":{"code":"US","name":"United States","continentCode":"NA"}};__mxmHeaders = {};</script>
# <meta content="5381b8eb344dfaa4" name="yandex-verification"/>
# <meta content="notranslate" name="google"/>
# <title>Search results for Dave Matthews Band</title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge; chrome=1" http-equiv="X-UA-Compatible"/><meta content="Search any lyrics by title, artist or text on Musixmatch, the world's largest lyrics catalog" name="description"/><meta content="https://www.musixmatch.com" name="identifier"/><meta content="lyrics, video, meaning, writer, music video, top songs lyrics, synced lyrics, music player, artist, karaoke" name="keywords"/><meta content="_8faEqn-rAfu0zKe0faUhuSHMNf6SN9dudWkxouG_us" name="google-site-verification"/><meta content="m6xTItKX2q" name="baidu-site-verification"/><meta content="42d34374a1270f3e" name="yandex-verification"/><meta content="app-id=448278467, affiliate-data=http://clk.tradedoubler.com/click?p=24373&amp;amp;a=1805894, app-argument=mxm://search/Dave%20Matthews%20Band" name="apple-itunes-app"/><link href="//s.mxmcdn.net" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//d2b1xqaw2ss8na.cloudfront.net" rel="dns-prefetch"/><link href="//platform.twitter.com" rel="dns-prefetch"/><link href="/opensearch.xml" rel="search" title="Musixmatch" type="application/opensearchdescription+xml"/><link rel="canonical"/><link href="//s.mxmcdn.net/site/images/favicon.png" rel="shortcut icon"/><link href="https://plus.google.com/+musiXmatch" rel="publisher"/><meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0" name="viewport"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="//s.mxmcdn.net/site/images/win_tile_144.png" name="msapplication-TileImage"/><meta content="#ff6600" name="msapplication-TileColor"/><link href="//s.mxmcdn.net/site/images/mxm_icn_72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//s.mxmcdn.net/site/images/mxm_icn_114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//s.mxmcdn.net/site/images/mxm_icn_57.png" rel="apple-touch-icon"/><meta content="131314396964274" property="fb:app_id"/><meta content="688442030" property="fb:admins"/><meta content="4f6d74a840fa7f3f5fe34b553ebbb4dc" name="p:domain_verify"/><link href="https://chrome.google.com/webstore/detail/gfenjblodoldnbiddmggcbkcapiolbig" rel="chrome-webstore-item"/><meta content="en" http-equiv="content-language"/>
# <script>
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     pbjs.bidderSettings = {
#         rubicon: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85 * 0.84;
#             }
#         },
#         appnexus: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         },
#         ix: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         }
#     };
# </script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function () {
#         googletag.pubads().disableInitialLoad();
#     });
#
#     var priceGranularity = {
#         buckets: [{
#             min: 0,
#             max: 31.49,
#             increment: 0.01
#         }]
#     };
#
#     function sendAdserverRequest() {
#         if (pbjs.adserverRequestSent) return;
#         pbjs.adserverRequestSent = true;
#         googletag.cmd.push(function () {
#             pbjs.que.push(function () {
#                 pbjs.setTargetingForGPTAsync();
#                 googletag.pubads().refresh();
#             });
#         });
#     }
# </script>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function () {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#             '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#     function getParameterByName(name, url) {
#         if (!url) url = window.location.href;
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)"),
#             results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#     }
#
#     googletag.cmd.push(function () {
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().disableInitialLoad();
#         googletag.pubads().collapseEmptyDivs();
#         var campaign = getParameterByName('utm_campaign');
#         if (campaign) {
#             googletag.pubads().setTargeting('utm_campaign', campaign);
#         }
#         googletag.enableServices();
#     });
#
#     // Make sure that the properties exist on the window.
#     window.googlefc = window.googlefc || {};
#     window.googlefc.ccpa = window.googlefc.ccpa || {}
#     window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#     // Queue the callback on the callbackQueue.
#     googlefc.callbackQueue.push({
#         'CONSENT_DATA_READY':
#             () => __tcfapi('getTCData', 0, (data, success) => {
#                 var FAILSAFE_TIMEOUT = 3000;
#
#                 pbjs.que.push(function () {
#                     pbjs.enableAnalytics([{
#                         provider: 'ga'
#                     }]);
#                     pbjs.setConfig({
#                         bidderSequence: 'random',
#                         enableSendAllBids: true,
#                         priceGranularity: priceGranularity,
#                         consentManagement: {
#                             gdpr: {
#                                 cmpApi: 'iab',
#                                 defaultGdprScope: true
#                             }
#                         }
#                     })
#                     pbjs.addAdUnits(__prebidAdUnits);
#                     pbjs.requestBids({
#                         bidsBackHandler: sendAdserverRequest
#                     });
#                 });
#
#                 setTimeout(function () {
#                     sendAdserverRequest();
#                 }, FAILSAFE_TIMEOUT);
#             })
#     });
# </script>
# </head>
# <body class="" spellcheck="false">
# <div id="fb-root"></div>
# <div id="site"><div class="" data-reactroot="" id="search-results"><div class="navbar" id="header" role="banner"><nav class="top-bar desktop-bar" data-topbar="true"><section class="top-bar-section"><ul class="title-area"><li class="name"><h1><a href="/" id="logo"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg" width="40"/></a></h1></li></ul><ul class="search-nav" role="search"><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div></form></li></ul><div class="top-bar-right"><ul class="site-nav" role="navigation"><li><a href="/explore">Top lyrics</a></li><li><a href="/community">Community</a></li><li><a href="/contribute">Contribute</a></li><li><a href="https://about.musixmatch.com/business/overview">Business</a></li></ul><ul class="user-nav"><li><ul class="user-nav-items loggedOut"><li id="sign-in"><a data-external-link="true" href="/sign-in">Sign in</a></li><li id="sign-up"><a data-external-link="true" href="/sign-up">Sign up</a></li></ul></li></ul></div></section></nav><nav class="top-bar mobile-top-bar"><ul class="title-area"><li class="offcanvas-toggler"><a href="#"><i class="icon icon-list"></i></a></li><li class="name"><h1><a href="/"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg"/></a></h1></li><li class="toggle-search-bar"><a href="#"><span><i class="icon icon-search"></i></span></a></li><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div><button class="button button-link search-bar-cancel"><i class="icon icon-cross"></i></button></form></li></ul></nav><noscript></noscript></div><div id="content" role="main"><div class="search-results"><div class="main-wrapper"><h1><span>Search results for <span><span class="search_query">Dave Matthews Band</span></span></span></h1><div><div class="section-header"><ul class="tabs"><li class="" id="all-results"><a href="/search/Dave%20Matthews%20Band">All results</a></li><li class="" id="tracks"><a href="/search/Dave%20Matthews%20Band/tracks">Tracks</a></li><li class="selected" id="artists"><a href="/search/Dave%20Matthews%20Band/artists">Artists</a></li><li class="" id="lyrics"><a href="/search/Dave%20Matthews%20Band/lyrics">Lyrics</a></li></ul></div><div class="tab-content"><div id="search-artists"><div class="box box-style-plain"><div class="box-header"><h3 class="box-title"> <!-- -->Artists</h3><div class="actions"></div></div><div class="box-content"><div><ul class="artists grid"><li><div class="artist-card media-card has-picture"><div class="media-card-picture"><img alt="Dave Matthews Band" src="https://static.musixmatch.com/images-storage/mxmimages/2/2/8/4/3/34822_14.jpg"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="cover" href="/artist/Dave-Matthews-Band">Dave Matthews Band</a></h2></div></div></div></li><li><div class="artist-card media-card has-picture"><div class="media-card-picture"><img alt="Robert Randolph &amp; The Family Band featuring Dave Matthews, Leroi Moore &amp; Rashawn Ross" src="https://static.musixmatch.com/images-storage/mxmimages/6/7/7/5/1/3/315776_14.jpg"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a class="cover" href="/artist/Robert-Randolph-The-Family-Band-featuring-Dave-Matthews-Leroi-Moore-Rashawn-Ross">Robert Randolph &amp; The Family Band featuring Dave Matthews, Leroi Moore &amp; Rashawn Ross</a></h2></div></div></div></li><li><div class="artist-card media-card has-picture"><div class="media-card-picture"><img alt="Jurrasic 5 featuring Dave Matthews Band &amp; Dave Matthews Band" src="//s.m ...
#  ðŸŒŽ Enjoyed everywhere</p></div></div></div><span></span></div></div>
# <script></script></body></html>

# %%
div = bsdata.find("div", {"id": "search-results"})
if div is not None:
    artists = div.find("div", {"class": "search-results"})
    for ul in artists.findAll("ul"):
        for li in ul.findAll("li"):
            h2 = li.find("h2")
            if h2 is None:
                continue
            ref = h2.find('a')
            if ref is None:
                continue
            href = ref.attrs['href']
            name = ref.text
            print("{0: <100}{1}".format(name,href))
# Out:
# Dave Matthews Band                                                                                  /artist/Dave-Matthews-Band
# Robert Randolph & The Family Band featuring Dave Matthews, Leroi Moore & Rashawn Ross               /artist/Robert-Randolph-The-Family-Band-featuring-Dave-Matthews-Leroi-Moore-Rashawn-Ross
# Jurrasic 5 featuring Dave Matthews Band & Dave Matthews Band                                        /artist/Jurrasic-5-featuring-Dave-Matthews-Band-Dave-Matthews-Band
# Dave Matthews' Big Band                                                                             /artist/Dave-Matthews-Big-Band
# Ivete Sangalo & Dave Matthews Band                                                                  /artist/Ivete-Sangalo-Dave-Matthews-Band
# Jurrasic 5 featuring Dave Matthews Band                                                             /artist/Jurrasic-5-featuring-Dave-Matthews-Band
# The Dave Matthews Cover Band                                                                        /artist/The-Dave-Matthews-Cover-Band
# Jurrasic 5 featuring Dave Matthews Band featuring Dave Matthews Band                                /artist/Jurrasic-5-featuring-Dave-Matthews-Band-featuring-Dave-Matthews-Band
# Dave Matthews, Stefan Lessard & Boyd Tinsley feat. The University of Virginia Marching Band         /artist/Dave-Matthews-Stefan-Lessard-Boyd-Tinsley-feat-The-University-of-Virginia-Marching-Band
# Dave Matthews Band & Jurassic 5                                                                     /artist/Dave-Matthews-Band-Jurassic-5

# %%
url="https://www.musixmatch.com/artist/Dave-Matthews-Band"
savename = "musixmatch_dmb.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.musixmatch.com/artist/Dave-Matthews-Band
#   --> This file is 56.2kB.

# %%
bsdata = getHTML(savename)

# %%
bsdata
# Out:
# <!DOCTYPE html>
# <html class="artist-page-page" xmlns:og="http://ogp.me/ns#">
# <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# musixmatch: http://ogp.me/ns/fb/musixmatch#">
# <script>
#     (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#     (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#     m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#     })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#     window._mxm_ga_firstLoad = true; //flag page tracked on first load
#     ga('create', 'UA-16453829-10', 'auto');
#     ga('require', '');
#     ga('send', 'pageview');
#   </script>
# <script>(function () {/*
#
#   Copyright The Closure Library Authors.
#   SPDX-License-Identifier: Apache-2.0
#   */
#       'use strict'; var g = function (a) { var b = 0; return function () { return b < a.length ? { done: !1, value: a[b++] } : { done: !0 } } }, l = this || self, m = /^[\w+/_-]+[=]{0,2}$/, p = null, q = function () { }, r = function (a) {
#         var b = typeof a; if ("object" == b) if (a) {
#           if (a instanceof Array) return "array"; if (a instanceof Object) return b; var c = Object.prototype.toString.call(a); if ("[object Window]" == c) return "object"; if ("[object Array]" == c || "number" == typeof a.length && "undefined" != typeof a.splice && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("splice")) return "array";
#           if ("[object Function]" == c || "undefined" != typeof a.call && "undefined" != typeof a.propertyIsEnumerable && !a.propertyIsEnumerable("call")) return "function"
#         } else return "null"; else if ("function" == b && "undefined" == typeof a.call) return "object"; return b
#       }, u = function (a, b) { function c() { } c.prototype = b.prototype; a.prototype = new c; a.prototype.constructor = a }; var v = function (a, b) { Object.defineProperty(l, a, { configurable: !1, get: function () { return b }, set: q }) }; var y = function (a, b) { this.b = a === w && b || ""; this.a = x }, x = {}, w = {}; var aa = function (a, b) { a.src = b instanceof y && b.constructor === y && b.a === x ? b.b : "type_error:TrustedResourceUrl"; if (null === p) b: { b = l.document; if ((b = b.querySelector && b.querySelector("script[nonce]")) && (b = b.nonce || b.getAttribute("nonce")) && m.test(b)) { p = b; break b } p = "" } b = p; b && a.setAttribute("nonce", b) }; var z = function () { return Math.floor(2147483648 * Math.random()).toString(36) + Math.abs(Math.floor(2147483648 * Math.random()) ^ +new Date).toString(36) }; var A = function (a, b) { b = String(b); "application/xhtml+xml" === a.contentType && (b = b.toLowerCase()); return a.createElement(b) }, B = function (a) { this.a = a || l.document || document }; B.prototype.appendChild = function (a, b) { a.appendChild(b) }; var C = function (a, b, c, d, e, f) { try { var k = a.a, h = A(a.a, "SCRIPT"); h.async = !0; aa(h, b); k.head.appendChild(h); h.addEventListener("load", function () { e(); d && k.head.removeChild(h) }); h.addEventListener("error", function () { 0 < c ? C(a, b, c - 1, d, e, f) : (d && k.head.removeChild(h), f()) }) } catch (n) { f() } }; var ba = l.atob("aHR0cHM6Ly93d3cuZ3N0YXRpYy5jb20vaW1hZ2VzL2ljb25zL21hdGVyaWFsL3N5c3RlbS8xeC93YXJuaW5nX2FtYmVyXzI0ZHAucG5n"), ca = l.atob("WW91IGFyZSBzZWVpbmcgdGhpcyBtZXNzYWdlIGJlY2F1c2UgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlIGlzIGludGVyZmVyaW5nIHdpdGggdGhpcyBwYWdlLg=="), da = l.atob("RGlzYWJsZSBhbnkgYWQgb3Igc2NyaXB0IGJsb2NraW5nIHNvZnR3YXJlLCB0aGVuIHJlbG9hZCB0aGlzIHBhZ2Uu"), ea = function (a, b, c) { this.b = a; this.f = new B(this.b); this.a = null; this.c = []; this.g = !1; this.i = b; this.h = c }, F = function (a) {
#         if (a.b.body && !a.g) {
#           var b =
#             function () { D(a); l.setTimeout(function () { return E(a, 3) }, 50) }; C(a.f, a.i, 2, !0, function () { l[a.h] || b() }, b); a.g = !0
#         }
#       }, D = function (a) {
#         for (var b = G(1, 5), c = 0; c < b; c++) { var d = H(a); a.b.body.appendChild(d); a.c.push(d) } b = H(a); b.style.bottom = "0"; b.style.left = "0"; b.style.position = "fixed"; b.style.width = G(100, 110).toString() + "%"; b.style.zIndex = G(2147483544, 2147483644).toString(); b.style["background-color"] = I(249, 259, 242, 252, 219, 229); b.style["box-shadow"] = "0 0 12px #888"; b.style.color = I(0, 10, 0, 10, 0, 10); b.style.display =
#           "flex"; b.style["justify-content"] = "center"; b.style["font-family"] = "Roboto, Arial"; c = H(a); c.style.width = G(80, 85).toString() + "%"; c.style.maxWidth = G(750, 775).toString() + "px"; c.style.margin = "24px"; c.style.display = "flex"; c.style["align-items"] = "flex-start"; c.style["justify-content"] = "center"; d = A(a.f.a, "IMG"); d.className = z(); d.src = ba; d.style.height = "24px"; d.style.width = "24px"; d.style["padding-right"] = "16px"; var e = H(a), f = H(a); f.style["font-weight"] = "bold"; f.textContent = ca; var k = H(a); k.textContent = da; J(a,
#             e, f); J(a, e, k); J(a, c, d); J(a, c, e); J(a, b, c); a.a = b; a.b.body.appendChild(a.a); b = G(1, 5); for (c = 0; c < b; c++)d = H(a), a.b.body.appendChild(d), a.c.push(d)
#       }, J = function (a, b, c) { for (var d = G(1, 5), e = 0; e < d; e++) { var f = H(a); b.appendChild(f) } b.appendChild(c); c = G(1, 5); for (d = 0; d < c; d++)e = H(a), b.appendChild(e) }, G = function (a, b) { return Math.floor(a + Math.random() * (b - a)) }, I = function (a, b, c, d, e, f) {
#         return "rgb(" + G(Math.max(a, 0), Math.min(b, 255)).toString() + "," + G(Math.max(c, 0), Math.min(d, 255)).toString() + "," + G(Math.max(e, 0), Math.min(f,
#           255)).toString() + ")"
#       }, H = function (a) { a = A(a.f.a, "DIV"); a.className = z(); return a }, E = function (a, b) { 0 >= b || null != a.a && 0 != a.a.offsetHeight && 0 != a.a.offsetWidth || (fa(a), D(a), l.setTimeout(function () { return E(a, b - 1) }, 50)) }, fa = function (a) { var b = a.c; var c = "undefined" != typeof Symbol && Symbol.iterator && b[Symbol.iterator]; b = c ? c.call(b) : { next: g(b) }; for (c = b.next(); !c.done; c = b.next())(c = c.value) && c.parentNode && c.parentNode.removeChild(c); a.c = []; (b = a.a) && b.parentNode && b.parentNode.removeChild(b); a.a = null }; var ia = function (a, b, c, d, e) { var f = ha(c), k = function (n) { n.appendChild(f); l.setTimeout(function () { f ? (0 !== f.offsetHeight && 0 !== f.offsetWidth ? b() : a(), f.parentNode && f.parentNode.removeChild(f)) : a() }, d) }, h = function (n) { document.body ? k(document.body) : 0 < n ? l.setTimeout(function () { h(n - 1) }, e) : b() }; h(3) }, ha = function (a) { var b = document.createElement("div"); b.className = a; b.style.width = "1px"; b.style.height = "1px"; b.style.position = "absolute"; b.style.left = "-10000px"; b.style.top = "-10000px"; b.style.zIndex = "-10000"; return b }; var K = {}, L = null; var M = function () { }, N = "function" == typeof Uint8Array, O = function (a, b) { a.b = null; b || (b = []); a.j = void 0; a.f = -1; a.a = b; a: { if (b = a.a.length) { --b; var c = a.a[b]; if (!(null === c || "object" != typeof c || Array.isArray(c) || N && c instanceof Uint8Array)) { a.g = b - a.f; a.c = c; break a } } a.g = Number.MAX_VALUE } a.i = {} }, P = [], Q = function (a, b) { if (b < a.g) { b += a.f; var c = a.a[b]; return c === P ? a.a[b] = [] : c } if (a.c) return c = a.c[b], c === P ? a.c[b] = [] : c }, R = function (a, b, c) { a.b || (a.b = {}); if (!a.b[c]) { var d = Q(a, c); d && (a.b[c] = new b(d)) } return a.b[c] };
#       M.prototype.h = N ? function () {
#         var a = Uint8Array.prototype.toJSON; Uint8Array.prototype.toJSON = function () {
#           var b; void 0 === b && (b = 0); if (!L) { L = {}; for (var c = "ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz0123456789".split(""), d = ["+/=", "+/", "-_=", "-_.", "-_"], e = 0; 5 > e; e++) { var f = c.concat(d[e].split("")); K[e] = f; for (var k = 0; k < f.length; k++) { var h = f[k]; void 0 === L[h] && (L[h] = k) } } } b = K[b]; c = []; for (d = 0; d < this.length; d += 3) {
#             var n = this[d], t = (e = d + 1 < this.length) ? this[d + 1] : 0; h = (f = d + 2 < this.length) ? this[d + 2] : 0; k = n >> 2; n = (n &
#               3) << 4 | t >> 4; t = (t & 15) << 2 | h >> 6; h &= 63; f || (h = 64, e || (t = 64)); c.push(b[k], b[n], b[t] || "", b[h] || "")
#           } return c.join("")
#         }; try { return JSON.stringify(this.a && this.a, S) } finally { Uint8Array.prototype.toJSON = a }
#       } : function () { return JSON.stringify(this.a && this.a, S) }; var S = function (a, b) { return "number" !== typeof b || !isNaN(b) && Infinity !== b && -Infinity !== b ? b : String(b) }; M.prototype.toString = function () { return this.a.toString() }; var T = function (a) { O(this, a) }; u(T, M); var U = function (a) { O(this, a) }; u(U, M); var ja = function (a, b) { this.c = new B(a); var c = R(b, T, 5); c = new y(w, Q(c, 4) || ""); this.b = new ea(a, c, Q(b, 4)); this.a = b }, ka = function (a, b, c, d) { b = new T(b ? JSON.parse(b) : null); b = new y(w, Q(b, 4) || ""); C(a.c, b, 3, !1, c, function () { ia(function () { F(a.b); d(!1) }, function () { d(!0) }, Q(a.a, 2), Q(a.a, 3), Q(a.a, 1)) }) }; var la = function (a, b) { V(a, "internal_api_load_with_sb", function (c, d, e) { ka(b, c, d, e) }); V(a, "internal_api_sb", function () { F(b.b) }) }, V = function (a, b, c) { a = l.btoa(a + b); v(a, c) }, W = function (a, b, c) { for (var d = [], e = 2; e < arguments.length; ++e)d[e - 2] = arguments[e]; e = l.btoa(a + b); e = l[e]; if ("function" == r(e)) e.apply(null, d); else throw Error("API not exported."); }; var X = function (a) { O(this, a) }; u(X, M); var Y = function (a) { this.h = window; this.a = a; this.b = Q(this.a, 1); this.f = R(this.a, T, 2); this.g = R(this.a, U, 3); this.c = !1 }; Y.prototype.start = function () { ma(); var a = new ja(this.h.document, this.g); la(this.b, a); na(this) };
#       var ma = function () { var a = function () { if (!l.frames.googlefcPresent) if (document.body) { var b = document.createElement("iframe"); b.style.display = "none"; b.style.width = "0px"; b.style.height = "0px"; b.style.border = "none"; b.style.zIndex = "-1000"; b.style.left = "-1000px"; b.style.top = "-1000px"; b.name = "googlefcPresent"; document.body.appendChild(b) } else l.setTimeout(a, 5) }; a() }, na = function (a) {
#         var b = Date.now(); W(a.b, "internal_api_load_with_sb", a.f.h(), function () {
#           var c; var d = a.b, e = l[l.btoa(d + "loader_js")]; if (e) {
#             e = l.atob(e);
#             e = parseInt(e, 10); d = l.btoa(d + "loader_js").split("."); var f = l; d[0] in f || "undefined" == typeof f.execScript || f.execScript("var " + d[0]); for (; d.length && (c = d.shift());)d.length ? f[c] && f[c] !== Object.prototype[c] ? f = f[c] : f = f[c] = {} : f[c] = null; c = Math.abs(b - e); c = 1728E5 > c ? 0 : c
#           } else c = -1; 0 != c && (W(a.b, "internal_api_sb"), Z(a, Q(a.a, 6)))
#         }, function (c) { Z(a, c ? Q(a.a, 4) : Q(a.a, 5)) })
#       }, Z = function (a, b) { a.c || (a.c = !0, a = new l.XMLHttpRequest, a.open("GET", b, !0), a.send()) }; (function (a, b) { l[a] = function (c) { for (var d = [], e = 0; e < arguments.length; ++e)d[e - 0] = arguments[e]; l[a] = q; b.apply(null, d) } })("__d3lUW8vwsKlB__", function (a) { "function" == typeof window.atob && (a = window.atob(a), a = new X(a ? JSON.parse(a) : null), (new Y(a)).start()) });
#     }).call(this);
#
#     window.__d3lUW8vwsKlB__("...");
#   </script>
# <script>
#     window.__prebidAdUnits = [];
#     (function() {
#       var d = document, pbs = d.createElement('script'), pro = d.location.protocol;
#       pbs.async = true;
#       pbs.src = '//s.mxmcdn.net/site/js/prebid4.13.0.js';
#       var target = document.getElementsByTagName('head')[0];
#       target.insertBefore(pbs, target.firstChild);
#     })();
#   </script>
# <script>
#     var cssua=function(n,l,p){var q=/\s*([\-\w ]+)[\s\/\:]([\d_]+\b(?:[\-\._\/]\w+)*)/,r=/([\w\-\.]+[\s\/][v]?[\d_]+\b(?:[\-\._\/]\w+)*)/g,s=/\b(?:(blackberry\w*|bb10)|(rim tablet os))(?:\/(\d+\.\d+(?:\.\w+)*))?/,t=/\bsilk-accelerated=true\b/,u=/\bfluidapp\b/,v=/(\bwindows\b|\bmacintosh\b|\blinux\b|\bunix\b)/,w=/(\bandroid\b|\bipad\b|\bipod\b|\bwindows phone\b|\bwpdesktop\b|\bxblwp7\b|\bzunewp7\b|\bwindows ce\b|\bblackberry\w*|\bbb10\b|\brim tablet os\b|\bmeego|\bwebos\b|\bpalm|\bsymbian|\bj2me\b|\bdocomo\b|\bpda\b|\bchtml\b|\bmidp\b|\bcldc\b|\w*?mobile\w*?|\w*?phone\w*?)/,
#     x=/(\bxbox\b|\bplaystation\b|\bnintendo\s+\w+)/,k={parse:function(b,d){var a={};d&&(a.standalone=d);b=(""+b).toLowerCase();if(!b)return a;for(var c,e,g=b.split(/[()]/),f=0,k=g.length;f<k;f++)if(f%2){var m=g[f].split(";");c=0;for(e=m.length;c<e;c++)if(q.exec(m[c])){var h=RegExp.$1.split(" ").join("_"),l=RegExp.$2;if(!a[h]||parseFloat(a[h])<parseFloat(l))a[h]=l}}else if(m=g[f].match(r))for(c=0,e=m.length;c<e;c++)h=m[c].split(/[\/\s]+/),h.length&&"mozilla"!==h[0]&&(a[h[0].split(" ").join("_")]=h.slice(1).join("-"));
#     w.exec(b)?(a.mobile=RegExp.$1,s.exec(b)&&(delete a[a.mobile],a.blackberry=a.version||RegExp.$3||RegExp.$2||RegExp.$1,RegExp.$1?a.mobile="blackberry":"0.0.1"===a.version&&(a.blackberry="7.1.0.0"))):x.exec(b)?(a.game=RegExp.$1,c=a.game.split(" ").join("_"),a.version&&!a[c]&&(a[c]=a.version)):v.exec(b)&&(a.desktop=RegExp.$1);a.intel_mac_os_x?(a.mac_os_x=a.intel_mac_os_x.split("_").join("."),delete a.intel_mac_os_x):a.cpu_iphone_os?(a.ios=a.cpu_iphone_os.split("_").join("."),delete a.cpu_iphone_os):a.cpu_os?
#     (a.ios=a.cpu_os.split("_").join("."),delete a.cpu_os):"iphone"!==a.mobile||a.ios||(a.ios="1");a.opera&&a.version?(a.opera=a.version,delete a.blackberry):t.exec(b)?a.silk_accelerated=!0:u.exec(b)&&(a.fluidapp=a.version);a.edge&&(delete a.applewebkit,delete a.safari,delete a.chrome,delete a.android);if(a.applewebkit)a.webkit=a.applewebkit,delete a.applewebkit,a.opr&&(a.opera=a.opr,delete a.opr,delete a.chrome),a.safari&&(a.chrome||a.crios||a.fxios||a.opera||a.silk||a.fluidapp||a.phantomjs||a.mobile&&
#     !a.ios?(delete a.safari,a.vivaldi&&delete a.chrome):a.safari=a.version&&!a.rim_tablet_os?a.version:{419:"2.0.4",417:"2.0.3",416:"2.0.2",412:"2.0",312:"1.3",125:"1.2",85:"1.0"}[parseInt(a.safari,10)]||a.safari);else if(a.msie||a.trident)if(a.opera||(a.ie=a.msie||a.rv),delete a.msie,delete a.android,a.windows_phone_os)a.windows_phone=a.windows_phone_os,delete a.windows_phone_os;else{if("wpdesktop"===a.mobile||"xblwp7"===a.mobile||"zunewp7"===a.mobile)a.mobile="windows desktop",a.windows_phone=9>+a.ie?
#     "7.0":10>+a.ie?"7.5":"8.0",delete a.windows_nt}else if(a.gecko||a.firefox)a.gecko=a.rv;a.rv&&delete a.rv;a.version&&delete a.version;return a},format:function(b){var d="",a;for(a in b)if(a&&b.hasOwnProperty(a)){var c=a,e=b[a],c=c.split(".").join("-"),g=" ua-"+c;if("string"===typeof e){for(var e=e.split(" ").join("_").split(".").join("-"),f=e.indexOf("-");0<f;)g+=" ua-"+c+"-"+e.substring(0,f),f=e.indexOf("-",f+1);g+=" ua-"+c+"-"+e}d+=g}return d},encode:function(b){var d="",a;for(a in b)a&&b.hasOwnProperty(a)&&
#     (d&&(d+="\x26"),d+=encodeURIComponent(a)+"\x3d"+encodeURIComponent(b[a]));return d}};k.userAgent=k.ua=k.parse(l,p);l=k.format(k.ua)+" js";n.className=n.className?n.className.replace(/\bno-js\b/g,"")+l:l.substr(1);return k}(document.documentElement,navigator.userAgent,navigator.standalone);
#   </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam-cell.nr-data.net","errorBeacon":"bam-cell.nr-data.net","licenseKey":"a38809cc79","applicationID":"11518440","applicationTime":46.228462,"transactionName":"ZVdUZEdSXUVUVEAIX1wddUVGR1xbGlZGFVlBRhkYbm1vQwUHBgdtGRs=","queueTime":0,"ttGuid":"1ddfa04955c454","agentToken":null}; (window.NREUM||(NREUM={})).loader_config={xpid:"Uw8PVlVXGwIBUVBaAwUH",licenseKey:"a38809cc79",applicationID:"11518440"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{c.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(23),c={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(c.console=!0,i.indexOf("dev")!==-1&&(c.dev=!0),i.indexOf("nr_dev")!==-1&&(c.nrDev=!0))}catch(s){}c.nrDev&&o.on("internal-error",function(t){r(t.stack)}),c.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),c.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(c,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,c){try{p?p-=1:i(c||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,s.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:s.now();o("err",[t,n])}var o=t("handle"),a=t(24),c=t("ee"),s=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError",p=0;s.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(9),t(8),"addEventListener"in window&&t(5),s.xhrWrappable&&t(10),d=!0)}c.on("fn-start",function(t,e,n){d&&(p+=1)}),c.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),c.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),c.on("internal-error",function(t){o("ierr",[t,s.now(),!0])})},{}],3:[function(t,e,n){t("loader").features.ins=!0},{}],4:[function(t,e,n){function r(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var i=t("ee"),o=t("handle"),a=t(9),c=t(8),s="learResourceTimings",f="addEventListener",u="resourcetimingbufferfull",d="bstResource",l="resource",p="-start",h="-end",m="fn"+p,w="fn"+h,v="bstTimer",g="pushState",y=t("loader");y.features.stn=!0,t(7),"addEventListener"in window&&t(5);var x=NREUM.o.EV;i.on(m,function(t,e){var n=t[0];n instanceof x&&(this.bstStart=y.now())}),i.on(w,function(t,e){var n=t[0];n instanceof x&&o("bst",[n,e,this.bstStart,y.now()])}),a.on(m,function(t,e,n){this.bstStart=y.now(),this.bstType=n}),a.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),this.bstType])}),c.on(m,function(){this.bstStart=y.now()}),c.on(w,function(t,e){o(v,[e,this.bstStart,y.now(),"requestAnimationFrame"])}),i.on(g+p,function(t){this.time=y.now(),this.startPath=location.pathname+location.hash}),i.on(g+h,function(t){o("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),f in window.performance&&(window.performance["c"+s]?window.performance[f](u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["c"+s]()},!1):window.performance[f]("webkit"+u,function(t){o(d,[window.performance.getEntriesByType(l)]),window.performance["webkitC"+s]()},!1)),document[f]("scroll",r,{passive:!0}),document[f]("keypress",r,!1),document[f]("click",r,!1)}},{}],5:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf(e);e&&i(e)}function i(t){c.inPlace(t,[u,d],"-",o)}function o(t,e){return t[1]}var a=t("ee").get("events"),c=t("wrap-function")(a,!0),s=t("gos"),f=XMLHttpRequest,u="addEventListener",d="removeEventListener";e.exports=a,"getPrototypeOf"in Object?(r(document),r(wind ...
# <link href="//s.mxmcdn.net/site/css/styles-39907f576175ff4a85ae.css" rel="stylesheet" type="text/css"/>
# <link href="//s.mxmcdn.net/site/css/styles-54104562bfd9047a28bf.css" rel="stylesheet" type="text/css"/>
# <script>__mxmStatusCode = 200;__mxmSession = {"userCountry":{"code":"US","name":"United States","continentCode":"NA"}};__mxmHeaders = {};</script>
# <meta content="5381b8eb344dfaa4" name="yandex-verification"/>
# <meta content="notranslate" name="google"/>
# <title>Dave Matthews Band lyrics | Musixmatch</title><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge; chrome=1" http-equiv="X-UA-Compatible"/><meta content="All Dave Matthews Band lyrics sorted by popularity, with video and meanings." name="description"/><meta content="https://www.musixmatch.com" name="identifier"/><meta content="lyrics, video, meaning, writer, music video, top songs lyrics, synced lyrics, music player, artist, karaoke" name="keywords"/><meta content="_8faEqn-rAfu0zKe0faUhuSHMNf6SN9dudWkxouG_us" name="google-site-verification"/><meta content="m6xTItKX2q" name="baidu-site-verification"/><meta content="42d34374a1270f3e" name="yandex-verification"/><meta content="app-id=448278467, affiliate-data=http://clk.tradedoubler.com/click?p=24373&amp;amp;a=1805894, app-argument=mxm://artist/283" name="apple-itunes-app"/><link href="//s.mxmcdn.net" rel="dns-prefetch"/><link href="//www.google-analytics.com" rel="dns-prefetch"/><link href="//d2b1xqaw2ss8na.cloudfront.net" rel="dns-prefetch"/><link href="//platform.twitter.com" rel="dns-prefetch"/><link href="/opensearch.xml" rel="search" title="Musixmatch" type="application/opensearchdescription+xml"/><link href="https://www.musixmatch.com/artist/Dave-Matthews-Band" rel="canonical"/><link href="//s.mxmcdn.net/site/images/favicon.png" rel="shortcut icon"/><link href="https://plus.google.com/+musiXmatch" rel="publisher"/><meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=1.0" name="viewport"/><link href="https://www.musixmatch.com/artist/Dave-Matthews-Band" hreflang="en" rel="alternate"/><link href="https://www.musixmatch.com/it/testi/Dave-Matthews-Band" hreflang="it" rel="alternate"/><link href="https://www.musixmatch.com/fr/artist/Dave-Matthews-Band" hreflang="fr" rel="alternate"/><link href="https://www.musixmatch.com/es/artist/Dave-Matthews-Band" hreflang="es" rel="alternate"/><link href="https://www.musixmatch.com/ja/artist/Dave-Matthews-Band" hreflang="ja" rel="alternate"/><link href="https://www.musixmatch.com/de/songtexte/Dave-Matthews-Band" hreflang="de" rel="alternate"/><link href="https://www.musixmatch.com/pt/artist/Dave-Matthews-Band" hreflang="pt" rel="alternate"/><link href="https://www.musixmatch.com/pt-br/artist/Dave-Matthews-Band" hreflang="pt-br" rel="alternate"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="//s.mxmcdn.net/site/images/win_tile_144.png" name="msapplication-TileImage"/><meta content="#ff6600" name="msapplication-TileColor"/><link href="//s.mxmcdn.net/site/images/mxm_icn_72.png" rel="apple-touch-icon" sizes="72x72"/><link href="//s.mxmcdn.net/site/images/mxm_icn_114.png" rel="apple-touch-icon" sizes="114x114"/><link href="//s.mxmcdn.net/site/images/mxm_icn_57.png" rel="apple-touch-icon"/><meta content="131314396964274" property="fb:app_id"/><meta content="688442030" property="fb:admins"/><meta content="4f6d74a840fa7f3f5fe34b553ebbb4dc" name="p:domain_verify"/><link href="https://chrome.google.com/webstore/detail/gfenjblodoldnbiddmggcbkcapiolbig" rel="chrome-webstore-item"/><link href="android-app://com.musixmatch.android.lyrify/mxm/artist/283?origin=appindexing" rel="alternate"/><link href="ios-app://448278467/mxm/artist/283" rel="alternate"/><meta content="All Dave Matthews Band lyrics sorted by popularity, with video and meanings." property="og:description"/><meta content="283" property="og:artist_id"/><meta content="Dave Matthews Band lyrics | Musixmatch" property="og:title"/><meta content="musiXmatch" property="og:site_name"/><meta content="https://www.musixmatch.com/artist/Dave-Matthews-Band" property="og:url"/><meta content="musixmatch:lyrics" property="og:type"/><meta content="https:https://static.musixmatch.com/images-storage/mxmimages/2/2/8/4/3/34822_14.jpg" property="og:image"/><meta content="131314396964274" property="fb:app_id"/><meta co ...
# <script>
#     var pbjs = pbjs || {};
#     pbjs.que = pbjs.que || [];
#     pbjs.bidderSettings = {
#         rubicon: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85 * 0.84;
#             }
#         },
#         appnexus: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         },
#         ix: {
#             bidCpmAdjustment: function (bidCpm) {
#                 return bidCpm * 0.85;
#             }
#         }
#     };
# </script>
# <script>
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function () {
#         googletag.pubads().disableInitialLoad();
#     });
#
#     var priceGranularity = {
#         buckets: [{
#             min: 0,
#             max: 31.49,
#             increment: 0.01
#         }]
#     };
#
#     function sendAdserverRequest() {
#         if (pbjs.adserverRequestSent) return;
#         pbjs.adserverRequestSent = true;
#         googletag.cmd.push(function () {
#             pbjs.que.push(function () {
#                 pbjs.setTargetingForGPTAsync();
#                 googletag.pubads().refresh();
#             });
#         });
#     }
# </script>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     (function () {
#         var gads = document.createElement('script');
#         gads.async = true;
#         gads.type = 'text/javascript';
#         var useSSL = 'https:' == document.location.protocol;
#         gads.src = (useSSL ? 'https:' : 'http:') +
#             '//www.googletagservices.com/tag/js/gpt.js';
#         var node = document.getElementsByTagName('script')[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#     function getParameterByName(name, url) {
#         if (!url) url = window.location.href;
#         name = name.replace(/[\[\]]/g, "\\$&");
#         var regex = new RegExp("[?&]" + name + "(=([^&#]*)|&|#|$)"),
#             results = regex.exec(url);
#         if (!results) return null;
#         if (!results[2]) return '';
#         return decodeURIComponent(results[2].replace(/\+/g, " "));
#     }
#
#     googletag.cmd.push(function () {
#         googletag.pubads().enableSingleRequest();
#         googletag.pubads().disableInitialLoad();
#         googletag.pubads().collapseEmptyDivs();
#         var campaign = getParameterByName('utm_campaign');
#         if (campaign) {
#             googletag.pubads().setTargeting('utm_campaign', campaign);
#         }
#         googletag.enableServices();
#     });
#
#     // Make sure that the properties exist on the window.
#     window.googlefc = window.googlefc || {};
#     window.googlefc.ccpa = window.googlefc.ccpa || {}
#     window.googlefc.callbackQueue = window.googlefc.callbackQueue || [];
#
#     // Queue the callback on the callbackQueue.
#     googlefc.callbackQueue.push({
#         'CONSENT_DATA_READY':
#             () => __tcfapi('getTCData', 0, (data, success) => {
#                 var FAILSAFE_TIMEOUT = 3000;
#
#                 pbjs.que.push(function () {
#                     pbjs.enableAnalytics([{
#                         provider: 'ga'
#                     }]);
#                     pbjs.setConfig({
#                         bidderSequence: 'random',
#                         enableSendAllBids: true,
#                         priceGranularity: priceGranularity,
#                         consentManagement: {
#                             gdpr: {
#                                 cmpApi: 'iab',
#                                 defaultGdprScope: true
#                             }
#                         }
#                     })
#                     pbjs.addAdUnits(__prebidAdUnits);
#                     pbjs.requestBids({
#                         bidsBackHandler: sendAdserverRequest
#                     });
#                 });
#
#                 setTimeout(function () {
#                     sendAdserverRequest();
#                 }, FAILSAFE_TIMEOUT);
#             })
#     });
# </script>
# </head>
# <body class="" spellcheck="false">
# <div id="fb-root"></div>
# <div id="site"><div class="" data-reactroot="" id="artist-page"><div class="navbar" id="header" role="banner"><nav class="top-bar desktop-bar" data-topbar="true"><section class="top-bar-section"><ul class="title-area"><li class="name"><h1><a href="/" id="logo"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg" width="40"/></a></h1></li></ul><ul class="search-nav" role="search"><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div></form></li></ul><div class="top-bar-right"><ul class="site-nav" role="navigation"><li><a href="/explore">Top lyrics</a></li><li><a href="/community">Community</a></li><li><a href="/contribute">Contribute</a></li><li><a href="https://about.musixmatch.com/business/overview">Business</a></li></ul><ul class="user-nav"><li><ul class="user-nav-items loggedOut"><li id="sign-in"><a data-external-link="true" href="/sign-in">Sign in</a></li><li id="sign-up"><a data-external-link="true" href="/sign-up">Sign up</a></li></ul></li></ul></div></section></nav><nav class="top-bar mobile-top-bar"><ul class="title-area"><li class="offcanvas-toggler"><a href="#"><i class="icon icon-list"></i></a></li><li class="name"><h1><a href="/"><img alt="Musixmatch" src="//s.mxmcdn.net/site/images/logo_icon.svg"/></a></h1></li><li class="toggle-search-bar"><a href="#"><span><i class="icon icon-search"></i></span></a></li><li class="search has-form"><form><div id="search-bar"><input autocomplete="off" id="search-input" placeholder="Type song title, artist or lyrics" type="text" value=""/><button class="button-icon" id="search-button"><i class="icon icon-search"></i></button></div><button class="button button-link search-bar-cancel"><i class="icon icon-cross"></i></button></form></li></ul></nav><noscript></noscript></div><div id="content" role="main"><div class="artist-page main-wrapper" itemtype="http://schema.org/MusicGroup"><meta content="/artist/Dave-Matthews-Band" itemprop="url"/><div class="profile-header artist-header"><div class="main-wrapper"><div class="noCoverPlaceholder"></div><div class="bg"></div><div class="profile-info"><div class="profile-head-link"><div class="profile-image"><img alt="Dave Matthews Band - lyrics" class="profile-avatar large" itemprop="image" src="https://static.musixmatch.com/images-storage/mxmimages/2/2/8/4/3/34822_14.jpg"/></div><div class="profile-data"><meta content="Dave Matthews Band" itemprop="name"/><meta content="Discover and play Dave Matthews Band songs with lyrics" itemprop="description"/><span class="lyricsLabel">lyrics</span><h1 class="" itemprop="name" title="Dave Matthews Band">Dave Matthews Band</h1><ul class="genres"><li><a href="/explore/genre/Rock">Rock</a></li></ul></div><a class="verify-link" href="https://artists.musixmatch.com">Are you this artist? Verify your lyrics now!</a></div><button class="button-primary contribute-button">+ <!-- -->Add lyrics</button><ul class="profile-head-info"></ul><span></span></div></div></div><div class="profile-content"><div><div class="section-header"><ul class="tabs"><li class="selected" id="overview"><a href="/artist/Dave-Matthews-Band">Overview</a></li><li class="" id="community"><a href="/artist/Dave-Matthews-Band/community">Contributors</a></li><li class="" id="albums"><a href="/artist/Dave-Matthews-Band/albums">Albums</a></li></ul></div><div class="tab-content"><div class="main-wrapper"><div class="main"><div class="row"><div class="main-panel"><div class="_2-NbqRCcpnx1S7eZLj0p72" id="cf_async_100001909_283"></div><div class="box box-style-plain" id="top-songs"><div class="box-header"><h3 class="box-title"> <!-- -->Lyrics for top songs by Dave Matthews Band</h3><div class="actions"></div></div><div class="box-content"><div><div><ul class="tracks list"><li class="showPosition showCoverart"><span class="position">01</ ...
#   googletag.cmd.push(function() {
#     window['__ad_div_gpt_ad_336x280_musixmatch_artist_sidebar_top'] = googletag.defineSlot("/154438701/336x280_musixmatch_artist_sidebar_top", [336, 280],
#     "div_gpt_ad_336x280_musixmatch_artist_sidebar_top").addService(googletag.pubads());
#     googletag.display("div_gpt_ad_336x280_musixmatch_artist_sidebar_top");
#     googletag.pubads().refresh([window.__ad_div_gpt_ad_336x280_musixmatch_artist_sidebar_top]);
#   });
# </script></div></div></div></div><div class="box box-style-plain" id="albums"><div class="box-header"><h3 class="box-title"> <!-- -->Artist authors</h3><div class="actions"></div></div><div class="box-content"><ul class="song-writers"><li><a href="/writer/Matthews-David-John">Matthews David John</a></li><li><a href="/writer/DAVID-J-MATTHEWS-2">David J Matthews</a></li><li><a href="/writer/David-John-Matthews">David John Matthews</a></li><li><a href="/writer/LESSARD-STEFAN-K">Lessard Stefan K</a></li><li><a href="/writer/BEAUFORD-CARTER-A">Beauford Carter A</a></li><li><a href="/writer/MOORE-LEROI-H">Moore Leroi H</a></li><li><a href="/writer/TINSLEY-BOYD-C">Tinsley Boyd C</a></li><li><a href="/writer/Dave-Matthews">Dave Matthews</a></li><li><a href="/writer/David-Matthews">David Matthews</a></li><li><a href="/writer/Stefan-Lessard">Stefan Lessard</a></li></ul></div></div><div class="box box-style-plain" id="albums"><div class="box-header"><h3 class="box-title"> <!-- -->Albums</h3><div class="actions"><a class="see-all-action" href="/artist/Dave-Matthews-Band/albums">All albums</a></div></div><div class="box-content"><ul class="albums list"><li><div class="album-card media-card has-picture"><div class="media-card-picture"><img alt="Come Tomorrow by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums4/9/7/9/2/2/0/40022979.jpg 320w, https://s.mxmcdn.net/images-storage/albums4/9/7/9/2/2/0/40022979_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums4/9/7/9/2/2/0/40022979_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums4/9/7/9/2/2/0/40022979_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a href="/album/Dave-Matthews-Band/Come-Tomorrow">Come Tomorrow</a></h2><h3 class="media-card-subtitle">2018</h3></div></div><meta content="Come Tomorrow" itemprop="name"/><meta content="https://s.mxmcdn.net/images-storage/albums4/9/7/9/2/2/0/40022979_500_500.jpg" itemprop="image"/></div></li><li><div class="album-card media-card has-picture"><div class="media-card-picture"><img alt="Again And Again by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums5/4/0/1/0/8/1/40180104.jpg 320w, https://s.mxmcdn.net/images-storage/albums5/4/0/1/0/8/1/40180104_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums5/4/0/1/0/8/1/40180104_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums5/4/0/1/0/8/1/40180104_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a href="/album/Dave-Matthews-Band/Again-and-Again">Again And Again</a></h2><h3 class="media-card-subtitle">2018</h3></div></div><meta content="Again And Again" itemprop="name"/><meta content="https://s.mxmcdn.net/images-storage/albums5/4/0/1/0/8/1/40180104_500_500.jpg" itemprop="image"/></div></li><li><div class="album-card media-card has-picture"><div class="media-card-picture"><img alt="That Girl Is You by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums5/3/2/7/0/2/1/40120723.jpg 320w, https://s.mxmcdn.net/images-storage/albums5/3/2/7/0/2/1/40120723_350_350.jpg 640w, https://s.mxmcdn.net/images-storage/albums5/3/2/7/0/2/1/40120723_350_350.jpg 480w, https://s.mxmcdn.net/images-storage/albums5/3/2/7/0/2/1/40120723_350_350.jpg 1960w"/></div><div class="media-card-body"><div class="media-card-text"><h2 class="media-card-title"><a href="/album/Dave-Matthews-Band/That-Girl-Is-You">That Girl Is You</a></h2><h3 class="media-card-subtitle">2018</h3></div></div><meta content="That Girl Is You" itemprop="name"/><meta content="https://s.mxmcdn.net/images-storage/albums5/3/2/7/0/2/1/40120723_500_500.jpg" itemprop="image"/></div></li><li><div class="album-card media-card has-picture"><div class="media-card-picture"><img alt="Samurai Cop (Oh Joy Begin) by Dave Matthews Band â€“ cover art" srcset="https://s.mxmcdn.net/images-storage/albums5/4/1/9/9/0/0/400099 ...
#  ðŸŒŽ Enjoyed everywhere</p></div></div></div><span></span></div></div>
# <script></script></body></html>

# %%
for ul in bsdata.findAll("ul"):
    for li in ul.findAll("li"):
        h2 = li.find("h2")
        if h2 is None:
            continue
        ref = h2.find('a')
        if ref is None:
            continue
        href = ref.attrs['href']
        name = ref.text
        print("{0: <100}{1}".format(name,href))
# Out:
# You Might Die Trying - 06/07/08 Busch Stadium St. Louis                                             /lyrics/Dave-Matthews-Band/You-Might-Die-Trying-06-07-08-Busch-Stadium-St-Louis
# Two Step - 06/07/08 Busch Stadium St. Louis                                                         /lyrics/Dave-Matthews-Band/Two-Step-06-07-08-Busch-Stadium-St-Louis
# Sweet                                                                                               /lyrics/Dave-Matthews-Band/Sweet
# Rye Whiskey                                                                                         /lyrics/Dave-Matthews-Band/Rye-Whiskey
# Time Of The Season                                                                                  /lyrics/Dave-Matthews-Band/Time-of-the-Season
# So Damn Lucky - 06/07/08 Busch Stadium St. Louis                                                    /lyrics/Dave-Matthews-Band/So-Damn-Lucky-06-07-08-Busch-Stadium-St-Louis
# Drunken Soldier                                                                                     /lyrics/Dave-Matthews-Band/Drunken-Soldier
# Don't Burn The Pig                                                                                  /lyrics/Dave-Matthews-Band/Don-t-Burn-the-Pig
# VocÃª E Eu (You & Me) - Ao Vivo No Madison Square Garden                                            /lyrics/Ivete-Sangalo-feat-Dave-Matthews-Band/Voc%C3%AA-E-Eu-You-Me-Ao-Vivo-No-Madison-Square-Garden
# Come Tomorrow                                                                                       /album/Dave-Matthews-Band/Come-Tomorrow
# Again And Again                                                                                     /album/Dave-Matthews-Band/Again-and-Again
# That Girl Is You                                                                                    /album/Dave-Matthews-Band/That-Girl-Is-You
# Samurai Cop (Oh Joy Begin)                                                                          /album/Dave-Matthews-Band/Samurai-Cop-Oh-Joy-Begin
# Live Trax Vol. 30: The Muse, Nantucket, MA                                                          /album/Dave-Matthews-Band/Live-Trax-Vol-30-The-Muse-Nantucket-MA

# %%
url="https://www.musixmatch.com/artist/Dave-Matthews-Band/albums"
savename = "musixmatch_dmbalbums.p"
if not isFile(savename):
    data, code = downloadURL(url)
    saveFile(idata=data, ifile=savename)
    sleep(3)
# Out:
# Now Downloading https://www.musixmatch.com/artist/Dave-Matthews-Band/albums
#   --> This file is 103.6kB.

# %%
bsdata = getHTML(savename)
for ul in bsdata.findAll("ul"):
    for li in ul.findAll("li"):
        h2 = li.find("h2")
        if h2 is None:
            continue
        ref = h2.find('a')
        if ref is None:
            continue
        href = ref.attrs['href']
        name = ref.text
        print("{0: <100}{1}".format(name,href))
# Out:
# Come Tomorrow                                                                                       /album/Dave-Matthews-Band/Come-Tomorrow
# Again And Again                                                                                     /album/Dave-Matthews-Band/Again-and-Again
# That Girl Is You                                                                                    /album/Dave-Matthews-Band/That-Girl-Is-You
# Samurai Cop (Oh Joy Begin)                                                                          /album/Dave-Matthews-Band/Samurai-Cop-Oh-Joy-Begin
# Live Trax Vol. 30: The Muse, Nantucket, MA                                                          /album/Dave-Matthews-Band/Live-Trax-Vol-30-The-Muse-Nantucket-MA
# Live Trax Vol. 29: Blossom Music Center, Cuyahoga Falls, OH (Live)                                  /album/Dave-Matthews-Band/Live-Trax-Vol-29-Blossom-Music-Center-Cuyahoga-Falls-OH
# Live Trax Vol. 28: John Paul Jones Arena                                                            /album/Dave-Matthews-Band/Live-Trax-Vol-28-John-Paul-Jones-Arena
# Live Trax Vol. 27: Luna Park, Buenos Aires, Argentina (Live)                                        /album/Dave-Matthews-Band/Live-Trax-Vol-27-Luna-Park-Buenos-Aires-Argentina
