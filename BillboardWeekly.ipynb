# %% [markdown]
# # Billboard Functions

# %%
## Basic stuff
# %load_ext autoreload
# %autoreload

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("""<style>div.output_area{max-height:10000px;overflow:scroll;}</style>"""))
#IPython.Cell.options_default.cm_config.lineNumbers = true;

################################################################################
## Python Version
################################################################################
import sys


################################################################################
## General Stuff
################################################################################
from multiprocessing import Pool
from tqdm import tqdm


################################################################################
## Util Stuff
################################################################################
from timeUtils import clock, elapsed
from ioUtils import saveFile, getFile


################################################################################
## Music DB
################################################################################
from mainDB import mainDB
from musicDBMap import musicDBMap
from masterDBMatchClass import masterDBMatchClass
from matchDBArtist import matchDBArtist


################################################################################
## Music Names
################################################################################
from masterArtistNameDB import masterArtistNameDB


################################################################################
## Chart Stuff
################################################################################
from artistIgnores import getArtistIgnores
from billboardData import billboardData
from top40Data import top40Data


################################################################################
## Pandas Stuff
################################################################################
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

print("Python: {0}".format(sys.version))
import datetime as dt
start = dt.datetime.now()
print("Notebook Last Run Initiated: "+str(start))
# Out:
# <style>.container { width:100% !important; }</style>
# <style>div.output_area{max-height:10000px;overflow:scroll;}</style>
# Python: 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# Notebook Last Run Initiated: 2021-01-10 20:10:56.722631

# %% [markdown]
# # Final Aggregation

# %%
# %load_ext autoreload
# %autoreload
from billboardData import billboardData
bd = billboardData(minYear=1, maxYear=2021)
bd.setChartUsage(rank=[0,1,2])
bd.setFullChartData()
bd.setArtistAlbumData()

bd.saveArtistAlbumData()
bd.saveFullChartData()

_, _ = clock("Last Run")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Found 62 files.
#   Getting Chart For hot
#   Using 16 Charts
#   Getting Chart For adult
#   Using 4 Charts
#   Getting Chart For top
#   Using 3 Charts
#   Using 23 Charts
#   Getting Chart For alternative
#   Using 4 Charts
#   Getting Chart For countryMusic
#   Using 10 Charts
#   Getting Chart For rock
#   Using 14 Charts
#   Getting Chart For rnb
#   Using 16 Charts
#   Using 44 Charts
#   Getting Chart For christian
#   Using 21 Charts
#   Getting Chart For canadian
#   Using 4 Charts
#   Getting Chart For comedy
#   Using 2 Charts
#   Getting Chart For general
#   Using 2 Charts
#   Getting Chart For twitter
#   Using 5 Charts
#   Using 34 Charts
#   Using Charts (None): ['hot-100', 'pop-songs', 'radio-songs', 'streaming-songs', 'rhythmic-40', 'heatseekers-albums', 'billboard-200', 'artist-100', 'top-album-sales', 'TLN', 'HSB', 'HSI', 'TLP', 'TSL', 'TFM', 'ATS', 'adult-contemporary', 'adult-pop-songs', 'ASI', 'ATF', 'billboard-200', 'artist-100', 'top-album-sales', 'alternative-albums', 'alternative-songs', 'MRT', 'ALT', 'country-airplay', 'country-albums', 'country-digital-song-sales', 'country-songs', 'country-streaming-songs', 'CSA', 'CSI', 'CST', 'CLP', 'CDT', 'rock-airplay', 'hot-mainstream-rock-tracks', 'rock-albums', 'rock-digital-song-sales', 'rock-songs', 'rock-streaming-songs', 'hard-rock-albums', 'RCK', 'RKA', 'RKT', 'ROS', 'RTT', 'MTL', 'ARK', 'r-and-b-albums', 'r-and-b-hip-hop-digital-song-sales', 'r-and-b-hip-hop-streaming-songs', 'r-and-b-songs', 'r-b-hip-hop-albums', 'r-b-hip-hop-songs', 'rap-albums', 'rap-song', 'hot-r-and-b-hip-hop-airplay', 'RLP', 'RAP', 'RBL', 'RBM', 'RBS', 'RBT', 'BLP', 'christian-airplay', 'hot-christian-songs', 'christian-albums', 'christian-digital-song-sales', 'christian-songs', 'christian-streaming-songs', 'gospel-airplay', 'gospel-albums', 'gospel-digital-song-sales', 'gospel-songs', 'gospel-streaming-songs', 'CRI', 'CRT', 'ICO', 'ILL', 'SLL', 'GOS', 'GSI', 'GSS', 'CHS', 'GDT', 'canadian-albums', 'canadian-hot-100', 'CAN', 'CNA', 'comedy-albums', 'GIG', 'HDS', 'DLP', 'twitter-emerging-artists', 'twitter-top-tracks', 'social-50', 'STM', 'SOC']
# Saving 4335 Artist Album Data to currentBillboardArtistAlbumData.p
# Saving data to currentBillboardArtistAlbumData.p
#   --> This file is 211.4kB.
# Saved data to currentBillboardArtistAlbumData.p
#   --> This file is 211.4kB.
# Saving 4335 Full Artist Data
# Saving data to currentBillboardFullChartArtistAlbumData.p
#   --> This file is 712.0kB.
# Saved data to currentBillboardFullChartArtistAlbumData.p
#   --> This file is 712.0kB.
# Current Time is Thu Dec 10, 2020 23:18:20 for Last Run

# %% [markdown]
# ****
# ****
# ****
# ****

# %% [markdown]
# # Starter Class Section

# %%
basedir = "/Volumes/Piggy/Charts/"
try:
    filename = glob(join(basedir, "data", "billboard", "starter.html"))[0]
except:
    print("Could not find starter HTML file!")
fdata = getHTML(filename)

# %% [markdown]
# #### Extra

# %%
chartData  = {}
dirname = None
baseURL = "https://www.billboard.com"
for iul,ul in enumerate(fdata.findAll("ul")):
    lis = ul.findAll("li", {"class": "chart-group__item"})
    for j,li in enumerate(lis):  
        a = li.find('a')
        if a is not None:
            href = a['href']
            text = a.text
            subdir = getDirname(href)[1:]
            chartData[text] = [baseURL, subdir, getBasename(href)]

# %%
#chartData

# %% [markdown]
# # Download Yearly Information

# %%
from time import sleep
years = [str(x) for x in range(1958,2014)]
years = ['2019']
for year in years:
    url="https://www.billboard.com/archive/charts/{0}".format(year)
    user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    headers={'User-Agent':user_agent,}
    
    savedir = join(basedir, "data", "billboard", "yearly")
    savename = join(savedir, "{0}.p".format(year))
    if isFile(savename):
        continue
    
    request=urllib.request.Request(url,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read() # The data u need

    print("Saving {0}".format(savename))
    saveJoblib(data=data, filename=savename, compress=True)
    sleep(1)

# %% [markdown]
# # Parse Yearly Information

# %%
import urllib
baseURL = "https://www.billboard.com"

url="{0}/charts".format(baseURL)
savename="tmpWeekly.p"

user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
headers={'User-Agent':user_agent,}
    
request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
data = response.read() # The data u need

saveFile(ifile=savename, idata=data)
_,_ = clock("Last Run")
# Out:
#   --> This file is 31.8kB.
# Current Time is Wed Dec 30, 2020 23:41:13 for Last Run

# %%
from webUtils import getHTML
bsdata = getHTML("tmpWeekly.p")

# %%
categoryIDs = {}
for div in bsdata.findAll("div", {"class": ["chart-panel", "chart-panel--main"]}):
    categories = div.findAll("div", {"class": ["chart-panel__item", "chart-panel__item--selector", "chart-panel__item--selector-active"]})
    for category in categories:
        attrs = category.attrs
        if "data-category-id" in attrs:
            categoryID    = attrs['data-category-id']
            categoryPanel = attrs['data-target']
            try:
                str(categoryID)
            except:
                continue
            categoryIDs[categoryID] = categoryPanel
categoryIDs
# Out:
# {'top-charts': 'topchartsChartPanel',
#  'global': 'globalChartPanel',
#  'greatest-of-all-time': 'greatestofalltimeChartPanel',
#  'pop': 'popChartPanel',
#  'country': 'countryChartPanel',
#  'rock': 'rockChartPanel',
#  'rbhip-hop': 'rbhip-hopChartPanel',
#  'latin': 'latinChartPanel',
#  'danceelectronic': 'danceelectronicChartPanel',
#  'christiangospel': 'christiangospelChartPanel',
#  'classical': 'classicalChartPanel',
#  'jazz': 'jazzChartPanel',
#  'breaking-and-entering': 'breakingandenteringChartPanel',
#  'web': 'webChartPanel',
#  'holiday': 'holidayChartPanel',
#  'songs-of-the-summer': 'songsofthesummerChartPanel',
#  'international': 'internationalChartPanel',
#  'additional-charts': 'additionalchartsChartPanel'}

# %%
categoryRefs = {}
for categoryID,categoryPanel in categoryIDs.items():
    categoryRefs[categoryID] = []
    div = bsdata.find("div", {"class": ["chart-panel", "chart-panel--hidden", "chart-panel__charts"], "id": categoryPanel})
    for ref in div.findAll("a", {"class": ["chart-panel__link"]}):
        href = ref.attrs['href']
        categoryRefs[categoryID].append(href)
categoryRefs
# Out:
# {'top-charts': ['/charts/hot-100',
#   '/charts/billboard-200',
#   '/charts/artist-100',
#   '/charts/social-50',
#   '/charts/streaming-songs',
#   '/charts/radio-songs',
#   '/charts/digital-song-sales',
#   '/charts/top-album-sales',
#   '/charts/current-albums',
#   '/charts/catalog-albums',
#   '/charts/independent-albums',
#   '/charts/soundtracks',
#   '/charts/vinyl-albums'],
#  'global': ['/charts/billboard-global-200',
#   '/charts/billboard-global-excl-us'],
#  'greatest-of-all-time': ['/charts/greatest-billboard-200-albums',
#   '/charts/greatest-billboard-200-artists',
#   '/charts/greatest-hot-100-singles',
#   '/charts/greatest-hot-100-artists',
#   '/charts/greatest-hot-100-songs-by-women',
#   '/charts/greatest-hot-100-women-artists',
#   '/charts/greatest-billboard-200-albums-by-women',
#   '/charts/greatest-billboard-200-women-artists',
#   '/charts/greatest-billboards-top-songs-80s',
#   '/charts/greatest-billboards-top-songs-90s',
#   '/charts/greatest-of-all-time-pop-songs',
#   '/charts/greatest-of-all-time-pop-songs-artists',
#   '/charts/greatest-adult-pop-songs',
#   '/charts/greatest-adult-pop-artists',
#   '/charts/greatest-country-songs',
#   '/charts/greatest-country-albums',
#   '/charts/greatest-country-artists',
#   '/charts/greatest-of-all-time-latin-artists',
#   '/charts/greatest-hot-latin-songs',
#   '/charts/greatest-hot-latin-songs-artists',
#   '/charts/greatest-top-dance-club-artists',
#   '/charts/greatest-r-b-hip-hop-songs',
#   '/charts/greatest-r-b-hip-hop-albums',
#   '/charts/greatest-r-b-hip-hop-artists',
#   '/charts/greatest-alternative-songs',
#   '/charts/greatest-alternative-artists'],
#  'pop': ['/charts/pop-songs',
#   '/charts/adult-contemporary',
#   '/charts/adult-pop-songs'],
#  'country': ['/charts/country-songs',
#   '/charts/country-albums',
#   '/charts/country-streaming-songs',
#   '/charts/country-airplay',
#   '/charts/country-digital-song-sales',
#   '/charts/bluegrass-albums',
#   '/charts/americana-folk-albums'],
#  'rock': ['/charts/rock-songs',
#   '/charts/rock-albums',
#   '/charts/rock-streaming-songs',
#   '/charts/rock-airplay',
#   '/charts/rock-digital-song-sales',
#   '/charts/hot-alternative-songs',
#   '/charts/alternative-albums',
#   '/charts/alternative-streaming-songs',
#   '/charts/alternative-airplay',
#   '/charts/alternative-digital-song-sales',
#   '/charts/hot-hard-rock-songs',
#   '/charts/hard-rock-albums',
#   '/charts/hard-rock-streaming-songs',
#   '/charts/hard-rock-digital-song-sales',
#   '/charts/triple-a',
#   '/charts/hot-mainstream-rock-tracks'],
#  'rbhip-hop': ['/charts/r-b-hip-hop-songs',
#   '/charts/r-b-hip-hop-albums',
#   '/charts/r-and-b-hip-hop-streaming-songs',
#   '/charts/hot-r-and-b-hip-hop-airplay',
#   '/charts/r-and-b-hip-hop-digital-song-sales',
#   '/charts/r-and-b-songs',
#   '/charts/r-and-b-albums',
#   '/charts/r-and-b-streaming-songs',
#   '/charts/r-and-b-digital-song-sales',
#   '/charts/rap-song',
#   '/charts/rap-albums',
#   '/charts/rap-streaming-songs',
#   '/charts/hot-rap-tracks',
#   '/charts/rap-digital-song-sales',
#   '/charts/mainstream-r-and-b-hip-hop',
#   '/charts/hot-adult-r-and-b-airplay',
#   '/charts/rhythmic-40'],
#  'latin': ['/charts/latin-songs',
#   '/charts/latin-albums',
#   '/charts/latin-streaming-songs',
#   '/charts/latin-airplay',
#   '/charts/latin-digital-song-sales',
#   '/charts/regional-mexican-albums',
#   '/charts/latin-regional-mexican-airplay',
#   '/charts/latin-pop-albums',
#   '/charts/latin-pop-airplay',
#   '/charts/tropical-albums',
#   '/charts/latin-tropical-airplay',
#   '/charts/latin-rhythm-albums',
#   '/charts/latin-rhythm-airplay'],
#  'danceelectronic': ['/charts/dance-electronic-songs',
#   '/charts/dance-electronic-albums',
#   '/charts/dance-electronic-streaming-songs',
#   '/charts/dance-electronic-digital-song-sales',
#   '/charts/hot-dance-airplay',
#   '/charts/dance-club-play-songs'],
#  'christiangospel': ['/charts/christian-songs',
#   '/charts/christian-albums',
#   '/charts/christian-streaming-songs',
#   '/charts/christian-airplay',
#   '/charts/christian-digital-song-sales',
#   '/charts/hot-christian-adult-contemporary',
#   '/charts/gospel-songs',
#   '/charts/gospel-albums',
#   '/charts/gospel-streaming-songs',
#   '/charts/gospel-airplay',
#   '/charts/gospel-digital-song-sales'],
#  'classical': ['/charts/classical-albums',
#   '/charts/classical-crossover-albums',
#   '/charts/traditional-classic-albums'],
#  'jazz': ['/charts/jazz-albums',
#   '/charts/contemporary-jazz',
#   '/charts/traditional-jazz-albums',
#   '/charts/jazz-songs'],
#  'breaking-and-entering': ['/charts/emerging-artists',
#   '/charts/heatseekers-albums'],
#  'web': ['/charts/top-triller-global',
#   '/charts/top-triller-us',
#   '/charts/lyricfind-global',
#   '/charts/lyricfind-us',
#   '/charts/next-big-sound-25'],
#  'holiday': ['/charts/hot-holiday-songs',
#   '/charts/holiday-albums',
#   '/charts/holiday-streaming-songs',
#   '/charts/holiday-songs',
#   '/charts/holiday-season-digital-song-sales'],
#  'songs-of-the-summer': ['/charts/summer-songs'],
#  'international': ['/charts/canadian-hot-100',
#   '/charts/canadian-albums',
#   '/charts/hot-canada-digital-song-sales',
#   '/charts/canada-emerging-artists',
#   '/charts/canada-ac',
#   '/charts/canada-all-format-airplay',
#   '/charts/canada-chr-top-40',
#   '/charts/canada-country',
#   '/charts/canada-hot-ac',
#   '/charts/canada-rock',
#   '/charts/mexico',
#   '/charts/mexico-ingles',
#   '/charts/mexico-popular',
#   '/charts/mexico-espanol',
#   '/charts/japan-hot-100',
#   '/charts/billboard-korea-100',
#   '/charts/billboard-argentina-hot-100',
#   '/charts/official-uk-songs',
#   '/charts/official-uk-albums',
#   '/charts/uk-digital-song-sales',
#   '/charts/euro-digital-song-sales',
#   '/charts/france-digital-song-sales',
#   '/charts/germany-songs',
#   '/charts/german-albums',
#   '/charts/greece-albums',
#   '/charts/italy-albums',
#   '/charts/italy-digital-song-sales',
#   '/charts/spain-digital-song-sales',
#   '/charts/switzerland-digital-song-sales',
#   '/charts/australian-albums',
#   '/charts/australia-digital-song-sales'],
#  'additional-charts': ['/charts/blues-albums',
#   '/charts/bubbling-under-hot-100-singles',
#   '/charts/cast-albums',
#   '/charts/comedy-albums',
#   '/charts/compilation-albums',
#   '/charts/hot-singles-recurrents',
#   '/charts/kids-albums',
#   '/charts/new-age-albums',
#   '/charts/reggae-albums',
#   '/charts/tastemaker-albums',
#   '/charts/world-albums',
#   '/charts/world-digital-song-sales']}

# %%
from time import sleep
from fsUtils import isFile
def getData(url, savename):
    user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    headers={'User-Agent':user_agent,}

    request=urllib.request.Request(url,None,headers) #The assembled request
    response = urllib.request.urlopen(request)
    data = response.read() # The data u need

    saveFile(ifile=savename, idata=data)        
    sleep(5)

# %%
for categoryID,categoryIDRefs in categoryRefs.items():
    n = 0
    for href in categoryIDRefs:
        savenamebase = "__".join([categoryID] + [x for x in href.split("/") if len(x) > 0])
        savename     = "chartData/{0}.p".format(savenamebase)
        if "imprints" in savename:
            continue
        if "labels" in savename:
            continue
        if "producers" in savename:
            continue
        if "distributors" in savename:
            continue
        if not isFile(savename):
            url = "{0}{1}".format(baseURL, href)
            print(savename)
            getData(url, savename)
            n += 1
    if n > 0:
        sleep(10)
# Out:
# chartData/rock__charts__year-end__2020__alternative-album-distributors.p
#   --> This file is 16.7kB.
# chartData/rock__charts__year-end__2020__alternative-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rock__charts__year-end__2020__alternative-songs.p
#   --> This file is 23.7kB.
# chartData/rock__charts__year-end__2020__alternative-digital-song-sales-yearend.p
#   --> This file is 20.2kB.
# chartData/rock__charts__year-end__2020__adult-alternative-songs-artists.p
#   --> This file is 17.7kB.
# chartData/rock__charts__year-end__2020__adult-alternative-songs.p
#   --> This file is 23.1kB.
# chartData/rock__charts__year-end__2020__hard-rock-albums-artists.p
#   --> This file is 18.1kB.
# chartData/rock__charts__year-end__2020__hard-rock-albums.p
#   --> This file is 23.8kB.
# chartData/rock__charts__year-end__2020__hard-rock-album-distributors.p
#   --> This file is 16.7kB.
# chartData/rock__charts__year-end__2020__hard-rock-digital-song-sales-yearend.p
#   --> This file is 20.2kB.
# chartData/rock__charts__year-end__2020__mainstream-rock-artists.p
#   --> This file is 18.1kB.
# chartData/rock__charts__year-end__2020__mainstream-rock-songs-artists.p
#   --> This file is 23.5kB.
# chartData/rb--hip-hop__charts__year-end__2020__top-r-and-b-hip-hop-artists.p
#   --> This file is 22.9kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-and-b-hip-hop-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-and-b-hip-hop-artists-female.p
#   --> This file is 17.7kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-and-b-hip-hop-artists-male.p
#   --> This file is 17.6kB.
# chartData/rb--hip-hop__charts__year-end__2020__new-r-and-and-b-hip-hop-artists.p
#   --> This file is 17.7kB.
# chartData/rb--hip-hop__charts__year-end__2020__hot-r-and-b-hip-hop-songs-artists.p
#   --> This file is 20.5kB.
# chartData/rb--hip-hop__charts__year-end__2020__hot-r-and-and-b-hip-hop-songs.p
#   --> This file is 28.7kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-airplay-artists.p
#   --> This file is 18.1kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-airplay-songs.p
#   --> This file is 23.6kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-digital-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-digital-songs.p
#   --> This file is 23.4kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-streaming-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-b-hip-hop-streaming-songs.p
#   --> This file is 23.4kB.
# chartData/rb--hip-hop__charts__year-end__2020__top-r-and-b-hip-hop-albums-artists.p
#   --> This file is 20.4kB.
# chartData/rb--hip-hop__charts__year-end__2020__top-r-and-b-hip-hop-albums.p
#   --> This file is 29.2kB.
# chartData/rb--hip-hop__charts__year-end__2020__r-and-and-b-hip-hop-album-distributors.p
#   --> This file is 16.8kB.
# chartData/rb__charts__year-end__2020__hot-r-and-and-b-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rb__charts__year-end__2020__hot-r-and-and-b-songs.p
#   --> This file is 23.3kB.
# chartData/rb__charts__year-end__2020__r-and-b-digital-songs-artists.p
#   --> This file is 17.6kB.
# chartData/rb__charts__year-end__2020__r-and-b-digital-songs.p
#   --> This file is 19.8kB.
# chartData/rb__charts__year-end__2020__r-and-b-streaming-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rb__charts__year-end__2020__r-and-b-streaming-songs.p
#   --> This file is 20.5kB.
# chartData/rb__charts__year-end__2020__r-and-b-albums-artists.p
#   --> This file is 18.0kB.
# chartData/rb__charts__year-end__2020__r-and-b-albums.p
#   --> This file is 20.6kB.
# chartData/rb__charts__year-end__2020__r-and-b-albums-distributors.p
#   --> This file is 16.7kB.
# chartData/rb__charts__year-end__2020__adult-r-and-b-artists.p
#   --> This file is 17.5kB.
# chartData/rb__charts__year-end__2020__adult-r-and-b-songs.p
#   --> This file is 23.1kB.
# chartData/rb__charts__year-end__2020__hot-mainstream-r-and-and-b-hip-hop-artists.p
#   --> This file is 17.6kB.
# chartData/rb__charts__year-end__2020__hot-mainstream-r-and-and-b-hip-hop-songs.p
#   --> This file is 23.1kB.
# chartData/rap__charts__year-end__2020__hot-rap-songs-artists.p
#   --> This file is 18.0kB.
# chartData/rap__charts__year-end__2020__hot-rap-songs.p
#   --> This file is 23.4kB.
# chartData/rap__charts__year-end__2020__rap-airplay-artists.p
#   --> This file is 17.6kB.
# chartData/rap__charts__year-end__2020__rap-airplay-songs.p
#   --> This file is 20.2kB.
# chartData/rap__charts__year-end__2020__rap-digital-songs-artists.p
#   --> This file is 17.6kB.
# chartData/rap__charts__year-end__2020__rap-digital-songs.p
#   --> This file is 20.1kB.
# chartData/rap__charts__year-end__2020__rap-streaming-songs-artists.p
#   --> This file is 18.1kB.
# chartData/rap__charts__year-end__2020__rap-streaming-songs.p
#   --> This file is 20.8kB.
# chartData/rap__charts__year-end__2020__rap-albums-artists.p
#   --> This file is 18.1kB.
# chartData/rap__charts__year-end__2020__rap-albums.p
#   --> This file is 20.8kB.
# chartData/rap__charts__year-end__2020__rap-albums-distributors.p
#   --> This file is 16.6kB.
# chartData/rhythmic__charts__year-end__2020__rhythmic-artists.p
#   --> This file is 18.0kB.
# chartData/rhythmic__charts__year-end__2020__rhythmic-songs.p
#   --> This file is 23.5kB.
# chartData/latin__charts__year-end__2020__top-latin-artists.p
#   --> This file is 22.6kB.
# chartData/latin__charts__year-end__2020__top-latin-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/latin__charts__year-end__2020__top-latin-artists-female.p
#   --> This file is 17.6kB.
# chartData/latin__charts__year-end__2020__top-latin-artists-male.p
#   --> This file is 17.5kB.
# chartData/latin__charts__year-end__2020__top-new-latin-artists.p
#   --> This file is 17.5kB.
# chartData/latin__charts__year-end__2020__hot-latin-songs-artists.p
#   --> This file is 20.3kB.
# chartData/latin__charts__year-end__2020__hot-latin-songs.p
#   --> This file is 28.3kB.
# chartData/latin__charts__year-end__2020__latin-airplay-artists.p
#   --> This file is 18.0kB.
# chartData/latin__charts__year-end__2020__latin-airplay-songs.p
#   --> This file is 23.4kB.
# chartData/latin__charts__year-end__2020__latin-digital-songs-artists.p
#   --> This file is 18.1kB.
# chartData/latin__charts__year-end__2020__latin-digital-songs.p
#   --> This file is 23.3kB.
# chartData/latin__charts__year-end__2020__latin-streaming-songs-artists.p
#   --> This file is 18.1kB.
# chartData/latin__charts__year-end__2020__latin-streaming-songs.p
#   --> This file is 22.9kB.
# chartData/latin__charts__year-end__2020__top-latin-albums-artists.p
#   --> This file is 20.4kB.
# chartData/latin__charts__year-end__2020__top-latin-albums.p
#   --> This file is 28.8kB.
# chartData/latin__charts__year-end__2020__latin-album-distributors.p
#   --> This file is 16.7kB.
# chartData/latin__charts__year-end__2020__latin-pop-albums-artists.p
#   --> This file is 18.1kB.
# chartData/latin__charts__year-end__2020__latin-pop-albums.p
#   --> This file is 20.0kB.
# chartData/latin__charts__year-end__2020__latin-pop-airplay-artists.p
#   --> This file is 18.1kB.
# chartData/latin__charts__year-end__2020__latin-pop-airplay-songs.p
#   --> This file is 23.5kB.
# chartData/latin__charts__year-end__2020__regional-mexican-albums-artists.p
#   --> This file is 18.2kB.
# chartData/latin__charts__year-end__2020__regional-mexican-albums.p
#   --> This file is 20.2kB.
# chartData/latin__charts__year-end__2020__regional-mexican-airplay-artists.p
#   --> This file is 18.2kB.
# chartData/latin__charts__year-end__2020__regional-mexican-airplay-songs.p
#   --> This file is 23.8kB.
# chartData/latin__charts__year-end__2020__tropical-albums-artists.p
#   --> This file is 18.0kB.
# chartData/latin__charts__year-end__2020__tropical-albums.p
#   --> This file is 20.0kB.
# chartData/latin__charts__year-end__2020__tropical-airplay-artists.p
#   --> This file is 18.1kB.
# chartData/latin__charts__year-end__2020__tropical-airplay-songs.p
#   --> This file is 23.5kB.
# chartData/latin__charts__year-end__2020__latin-rhythm-albums-artists.p
#   --> This file is 17.6kB.
# chartData/latin__charts__year-end__2020__latin-rhythm-albums-.p
#   --> This file is 19.4kB.
# chartData/latin__charts__year-end__2020__latin-rhythm-airplay-artists.p
#   --> This file is 17.6kB.
# chartData/latin__charts__year-end__2020__latin-rhythm-airplay-songs.p
#   --> This file is 22.8kB.
# chartData/dance--electronic__charts__year-end__2020__top-dance-electronic-artists.p
#   --> This file is 22.6kB.
# chartData/dance--electronic__charts__year-end__2020__top-dance-electronic-new-artists.p
#   --> This file is 17.5kB.
# chartData/dance--electronic__charts__year-end__2020__hot-dance-electronic-songs-artists.p
#   --> This file is 20.3kB.
# chartData/dance--electronic__charts__year-end__2020__hot-dance-electronic-songs.p
#   --> This file is 28.5kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-digital-songs-artists.p
#   --> This file is 18.2kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-digital-songs.p
#   --> This file is 23.2kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-streaming-songs-artists.p
#   --> This file is 18.1kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-streaming-songs.p
#   --> This file is 23.5kB.
# chartData/dance--electronic__charts__year-end__2020__dance-mix-show-airplay-artists.p
#   --> This file is 18.1kB.
# chartData/dance--electronic__charts__year-end__2020__dance-mix-show-airplay-songs.p
#   --> This file is 23.5kB.
# chartData/dance--electronic__charts__year-end__2020__top-new-dance-eletronic-artists.p
#   --> This file is 18.1kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-albums.p
#   --> This file is 20.6kB.
# chartData/dance--electronic__charts__year-end__2020__dance-electronic-distributors.p
#   --> This file is 16.8kB.
# chartData/christian__charts__year-end__2020__top-christian-artists.p
#   --> This file is 22.9kB.
# chartData/christian__charts__year-end__2020__top-christian-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2020__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2020__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2020__top-christian-new-artists.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2020__christian-albums-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2020__christian-albums.p
#   --> This file is 23.5kB.
# chartData/christian__charts__year-end__2020__christian-album-distributors.p
#   --> This file is 16.8kB.
# chartData/christian__charts__year-end__2020__hot-christian-songs-artists.p
#   --> This file is 20.5kB.
# chartData/christian__charts__year-end__2020__hot-christian-songs.p
#   --> This file is 29.0kB.
# chartData/christian__charts__year-end__2020__christian-airplay-artists.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2020__christian-airplay-songs.p
#   --> This file is 23.3kB.
# chartData/christian__charts__year-end__2020__christian-digital-songs-artists.p
#   --> This file is 18.2kB.
# chartData/christian__charts__year-end__2020__christian-digital-songs.p
#   --> This file is 23.3kB.
# chartData/christian__charts__year-end__2020__christian-streaming-songs-artists.p
#   --> This file is 17.7kB.
# chartData/christian__charts__year-end__2020__christian-streaming-songs.p
#   --> This file is 22.9kB.
# chartData/christian__charts__year-end__2020__hot-christian-adult-contemporary-artists.p
#   --> This file is 17.7kB.
# chartData/christian__charts__year-end__2020__hot-christian-adult-contemporary.p
#   --> This file is 23.4kB.
# chartData/gospel__charts__year-end__2020__top-gospel-artists.p
#   --> This file is 20.2kB.
# chartData/gospel__charts__year-end__2020__top-gospel-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/gospel__charts__year-end__2020__top-gospel-artists-female.p
#   --> This file is 17.6kB.
# chartData/gospel__charts__year-end__2020__top-gospel-artists-male.p
#   --> This file is 17.5kB.
# chartData/gospel__charts__year-end__2020__top-gospel-new-artists.p
#   --> This file is 17.5kB.
# chartData/gospel__charts__year-end__2020__gospel-albums-artists.p
#   --> This file is 18.0kB.
# chartData/gospel__charts__year-end__2020__gospel-albums.p
#   --> This file is 23.9kB.
# chartData/gospel__charts__year-end__2020__gospel-album-distributors.p
#   --> This file is 16.7kB.
# chartData/gospel__charts__year-end__2020__hot-gospel-songs-artists.p
#   --> This file is 18.1kB.
# chartData/gospel__charts__year-end__2020__hot-gospel-songs.p
#   --> This file is 23.3kB.
# chartData/gospel__charts__year-end__2020__gospel-airplay-artists.p
#   --> This file is 17.6kB.
# chartData/gospel__charts__year-end__2020__gospel-airplay-songs.p
#   --> This file is 23.3kB.
# chartData/gospel__charts__year-end__2020__gospel-digital-songs-artists.p
#   --> This file is 18.1kB.
# chartData/gospel__charts__year-end__2020__gospel-digital-songs.p
#   --> This file is 20.5kB.
# chartData/gospel__charts__year-end__2020__gospel-streaming-songs-artists.p
#   --> This file is 17.5kB.
# chartData/gospel__charts__year-end__2020__gospel-streaming-songs.p
#   --> This file is 22.3kB.
# chartData/classical__charts__year-end__2020__classical-albums-artists.p
#   --> This file is 19.8kB.
# chartData/classical__charts__year-end__2020__classical-albums.p
#   --> This file is 23.4kB.
# chartData/classical__charts__year-end__2020__classical-distributors.p
#   --> This file is 16.7kB.
# chartData/classical__charts__year-end__2020__traditional-classical-albums-artists.p
#   --> This file is 18.2kB.
# chartData/classical__charts__year-end__2020__traditional-classical-albums.p
#   --> This file is 21.8kB.
# chartData/classical__charts__year-end__2020__classical-crossover-albums-artists.p
#   --> This file is 17.7kB.
# chartData/classical__charts__year-end__2020__classical-crossover-albums.p
#   --> This file is 19.5kB.
# chartData/jazz__charts__year-end__2020__jazz-albums-artists.p
#   --> This file is 18.1kB.
# chartData/jazz__charts__year-end__2020__jazz-albums.p
#   --> This file is 20.8kB.
# chartData/jazz__charts__year-end__2020__jazz-distributors.p
#   --> This file is 16.7kB.
# chartData/jazz__charts__year-end__2020__traditional-jazz-albums-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2020__contemporary-jazz-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2020__contemporary-jazz-albums.p
#   --> This file is 20.5kB.
# chartData/jazz__charts__year-end__2020__smooth-jazz-songs-artists.p
#   --> This file is 18.2kB.
# chartData/jazz__charts__year-end__2020__smooth-jazz-songs.p
#   --> This file is 23.1kB.
# chartData/new-age__charts__year-end__2020__new-age-albums-artists.p
#   --> This file is 18.0kB.
# chartData/new-age__charts__year-end__2020__new-age-albums.p
#   --> This file is 18.3kB.
# chartData/new-age__charts__year-end__2020__new-age-distributors.p
#   --> This file is 16.7kB.
# chartData/world__charts__year-end__2020__world-albums-artists.p
#   --> This file is 18.1kB.
# chartData/world__charts__year-end__2020__world-albums.p
#   --> This file is 19.5kB.
# chartData/world__charts__year-end__2020__world-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2020__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2020__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2020__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/reggae__charts__year-end__2020__reggae-albums-artists.p
#   --> This file is 18.0kB.
# chartData/reggae__charts__year-end__2020__reggae-albums.p
#   --> This file is 19.5kB.
# chartData/reggae__charts__year-end__2020__reggae-distributors.p
#   --> This file is 16.7kB.
# chartData/americana--folk__charts__year-end__2020__folk-artists.p
#   --> This file is 18.1kB.
# chartData/americana--folk__charts__year-end__2020__folk-albums.p
#   --> This file is 20.7kB.
# chartData/americana--folk__charts__year-end__2020__folk-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2020__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2020__bluegrass-albums.p
#   --> This file is 20.0kB.
# chartData/bluegrass__charts__year-end__2020__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2020__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2020__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/kid__charts__year-end__2020__kid-albums-artists.p
#   --> This file is 17.9kB.
# chartData/kid__charts__year-end__2020__kid-albums.p
#   --> This file is 20.6kB.
# chartData/kid__charts__year-end__2020__kid-distributors.p
#   --> This file is 16.7kB.
# chartData/comedy__charts__year-end__2020__comedy-albums-artists.p
#   --> This file is 18.0kB.
# chartData/comedy__charts__year-end__2020__comedy-albums.p
#   --> This file is 19.7kB.
# chartData/comedy__charts__year-end__2020__comedy-distributors.p
#   --> This file is 16.7kB.
# chartData/video__charts__year-end__2020__music-video-sales.p
#   --> This file is 20.3kB.
# chartData/soundtracks__charts__year-end__2020__top-soundtracks-albums.p
#   --> This file is 20.7kB.
# chartData/international__charts__year-end__2020__candaian-hot-100-artists.p
#   --> This file is 20.3kB.
# chartData/international__charts__year-end__2020__canadian-hot-100.p
#   --> This file is 28.9kB.
# chartData/international__charts__year-end__2020__top-canadian-albums.p
#   --> This file is 23.8kB.
# chartData/international__charts__year-end__2020__hot-canadian-digital-songs.p
#   --> This file is 23.0kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-100-songwriters.p
#   --> This file is 18.7kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-100-publishers.p
#   --> This file is 20.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-100-publishing-corporations.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-country-songwriters.p
#   --> This file is 18.7kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-country-songs-publishers.p
#   --> This file is 20.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-country-songs-publishing-corporations.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-r-and-and-b-hip-hop-songwriters.p
#   --> This file is 18.9kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-r-and-and-b-hip-hop-publishers.p
#   --> This file is 20.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-r-and-and-b-hip-hop-publishing-corporations.p
#   --> This file is 17.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__r-and-b-songwriters.p
#   --> This file is 17.0kB.
# chartData/songwriters--publishers__charts__year-end__2020__r-and-b-songs-publishers.p
#   --> This file is 18.4kB.
# chartData/songwriters--publishers__charts__year-end__2020__r-and-b-songs-publishing-corporations.p
#   --> This file is 16.8kB.
# chartData/songwriters--publishers__charts__year-end__2020__rap-songwriters.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__rap-songs-publishers.p
#   --> This file is 18.5kB.
# chartData/songwriters--publishers__charts__year-end__2020__rap-songs-publishing-corporations.p
#   --> This file is 16.8kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-latin-songswriters.p
#   --> This file is 19.0kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-latin-publishers.p
#   --> This file is 20.0kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-latin-publishing-corporations.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-rock-songwriters.p
#   --> This file is 18.7kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-rock-songs-publishers.p
#   --> This file is 20.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-rock-songs-publishing-corporations.p
#   --> This file is 17.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__dance-electronic-songwriters.p
#   --> This file is 18.8kB.
# chartData/songwriters--publishers__charts__year-end__2020__dance-electronic-songs-publishers.p
#   --> This file is 20.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__dance-electronic-publishing-corporations.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-songswriters.p
#   --> This file is 18.7kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-publishers.p
#   --> This file is 20.2kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-publishing-corporations.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-adult-contemporary-songwriters.p
#   --> This file is 17.1kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-adult-contemporary-publishers.p
#   --> This file is 18.6kB.
# chartData/songwriters--publishers__charts__year-end__2020__hot-christian-adult-contemporary-publishing-corporations.p
#   --> This file is 16.9kB.

# %%
from searchUtils import findExt
from fileUtils import getBaseFilename
files = sorted(findExt("chartData", ".p"))

for ifile in files:
    fvals = getBaseFilename(ifile).split("__")
    category,chart,chartType,year,chartName = fvals
    bsdata  = getHTML(ifile)
    ulYears = bsdata.find("ul", {"class": "dropdown__year-select-options"})
    n = 0
    if ulYears is not None:
        years = ulYears.findAll("a", {"class": "year-link"})
        for urlref in years:
            suburl   = urlref.attrs['href']
            year     = urlref.text
            url      = "{0}{1}".format(baseURL,suburl)
            savename = ifile.replace("__{0}__".format(2020), "__{0}__".format(year))
            if not isFile(savename):
                print(savename)
                getData(url, savename)
                n += 1
    if n > 0:
        sleep(5)
# Out:
# chartData/adult__charts__year-end__2006__hot-adult-40-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2019__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2018__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2017__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2016__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2015__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2014__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2013__hot-adult-contemporary-labels.p
#   --> This file is 17.2kB.
# chartData/adult__charts__year-end__2012__hot-adult-contemporary-labels.p
#   --> This file is 17.2kB.
# chartData/adult__charts__year-end__2011__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2010__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2009__hot-adult-contemporary-labels.p
#   --> This file is 17.2kB.
# chartData/adult__charts__year-end__2008__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2007__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/adult__charts__year-end__2006__hot-adult-contemporary-labels.p
#   --> This file is 17.1kB.
# chartData/americana--folk__charts__year-end__2019__folk-albums.p
#   --> This file is 20.8kB.
# chartData/americana--folk__charts__year-end__2018__folk-albums.p
#   --> This file is 20.8kB.
# chartData/americana--folk__charts__year-end__2017__folk-albums.p
#   --> This file is 20.7kB.
# chartData/americana--folk__charts__year-end__2016__folk-albums.p
#   --> This file is 20.8kB.
# chartData/americana--folk__charts__year-end__2015__folk-albums.p
#   --> This file is 21.1kB.
# chartData/americana--folk__charts__year-end__2014__folk-albums.p
#   --> This file is 23.8kB.
# chartData/americana--folk__charts__year-end__2013__folk-albums.p
#   --> This file is 23.9kB.
# chartData/americana--folk__charts__year-end__2012__folk-albums.p
#   --> This file is 24.1kB.
# chartData/americana--folk__charts__year-end__2011__folk-albums.p
p
#   --> This file is 18.1kB.
# chartData/billboard-200__charts__year-end__2010__the-billboard-200-artists-male.p
#   --> This file is 18.2kB.
# chartData/billboard-200__charts__year-end__2009__the-billboard-200-artists-male.p
#   --> This file is 18.1kB.
# chartData/billboard-200__charts__year-end__2008__the-billboard-200-artists-male.p
#   --> This file is 18.1kB.
# chartData/billboard-200__charts__year-end__2007__the-billboard-200-artists-male.p
#   --> This file is 18.1kB.
# chartData/billboard-200__charts__year-end__2006__the-billboard-200-artists-male.p
#   --> This file is 18.1kB.
# chartData/billboard-200__charts__year-end__2016__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2015__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2014__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2013__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2012__the-billboard-200-distributors.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2011__the-billboard-200-distributors.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2010__the-billboard-200-distributors.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2009__the-billboard-200-distributors.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2008__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2007__the-billboard-200-distributors.p
#   --> This file is 16.7kB.
# chartData/billboard-200__charts__year-end__2006__the-billboard-200-distributors.p
#   --> This file is 16.6kB.
# chartData/billboard-200__charts__year-end__2019__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2018__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2017__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2016__the-billboard-200-labels.p
#   --> This file is 17.2kB.
# chartData/billboard-200__charts__year-end__2015__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2014__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2013__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2012__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2011__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2010__the-billboard-200-labels.p
#   --> This file is 17.1kB.
# chartData/billboard-200__charts__year-end__2009__the-billboard-200-labels.p
#   --> This file is 17.2kB.
# chartData/billboard-200__charts__year-end__2008__the-billboard-200-labels.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2007__the-billboard-200-labels.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2006__the-billboard-200-labels.p
#   --> This file is 16.8kB.
# chartData/billboard-200__charts__year-end__2019__top-billboard-200-albums.p
#   --> This file is 40.8kB.
# chartData/billboard-200__charts__year-end__2018__top-billboard-200-albums.p
#   --> This file is 40.1kB.
# chartData/billboard-200__charts__year-end__2017__top-billboard-200-albums.p
#   --> This file is 39.8kB.
# chartData/billboard-200__charts__year-end__2016__top-billboard-200-albums.p
#   --> This file is 40.0kB.
# chartData/billboard-200__charts__year-end__2015__top-billboard-200-albums.p
#   --> This file is 40.4kB.
# chartData/billboard-200__charts__year-end__2014__top-billboard-200-albums.p
#   --> This file is 41.0kB.
# chartData/billboard-200__charts__year-end__2013__top-billboard-200-albums.p
#   --> This file is 40.6kB.
# chartData/billboard-200__charts__year-end__2012__top-billboard-200-albums.p
#   --> This file is 40.6kB.
# chartData/billboard-200__charts__year-end__2011__top-billboard-200-albums.p
#   --> This file is 40.2kB.
# chartData/billboard-200__charts__year-end__2010__top-billboard-200-albums.p
#   --> This file is 40.7kB.
# chartData/billboard-200__charts__year-end__2009__top-billboard-200-albums.p
#   --> This file is 40.0kB.
# chartData/billboard-200__charts__year-end__2008__top-billboard-200-albums.p
#   --> This file is 40.5kB.
# chartData/billboard-200__charts__year-end__2007__top-billboard-200-albums.p
#   --> This file is 40.7kB.
# chartData/billboard-200__charts__year-end__2006__top-billboard-200-albums.p
#   --> This file is 40.6kB.
# chartData/billboard-200__charts__year-end__2005__top-billboard-200-albums.p
#   --> This file is 40.6kB.
# chartData/billboard-200__charts__year-end__2004__top-billboard-200-albums.p
#   --> This file is 40.7kB.
# chartData/billboard-200__charts__year-end__2003__top-billboard-200-albums.p
#   --> This file is 40.8kB.
# chartData/billboard-200__charts__year-end__2002__top-billboard-200-albums.p
#   --> This file is 39.3kB.
# chartData/billboard-200__charts__year-end__2019__top-billboard-200-artists.p
#   --> This file is 27.3kB.
# chartData/billboard-200__charts__year-end__2018__top-billboard-200-artists.p
#   --> This file is 27.4kB.
# chartData/billboard-200__charts__year-end__2017__top-billboard-200-artists.p
#   --> This file is 27.1kB.
# chartData/billboard-200__charts__year-end__2016__top-billboard-200-artists.p
#   --> This file is 27.4kB.
# chartData/billboard-200__charts__year-end__2015__top-billboard-200-artists.p
#   --> This file is 22.8kB.
# chartData/billboard-200__charts__year-end__2014__top-billboard-200-artists.p
#   --> This file is 27.5kB.
# chartData/billboard-200__charts__year-end__2013__top-billboard-200-artists.p
#   --> This file is 27.3kB.
# chartData/billboard-200__charts__year-end__2012__top-billboard-200-artists.p
#   --> This file is 27.4kB.
# chartData/billboard-200__charts__year-end__2011__top-billboard-200-artists.p
#   --> This file is 27.5kB.
# chartData/billboard-200__charts__year-end__2010__top-billboard-200-artists.p
#   --> This file is 27.1kB.
# chartData/billboard-200__charts__year-end__2009__top-billboard-200-artists.p
#   --> This file is 27.3kB.
# chartData/billboard-200__charts__year-end__2008__top-billboard-200-artists.p
#   --> This file is 27.2kB.
# chartData/billboard-200__charts__year-end__2007__top-billboard-200-artists.p
#   --> This file is 27.2kB.
# chartData/billboard-200__charts__year-end__2006__top-billboard-200-artists.p
#   --> This file is 22.6kB.
# chartData/bluegrass__charts__year-end__2019__bluegrass-albums.p
#   --> This file is 19.7kB.
# chartData/bluegrass__charts__year-end__2018__bluegrass-albums.p
#   --> This file is 19.7kB.
# chartData/bluegrass__charts__year-end__2017__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2016__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2015__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2014__bluegrass-albums.p
#   --> This file is 19.7kB.
# chartData/bluegrass__charts__year-end__2013__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2012__bluegrass-albums.p
#   --> This file is 19.9kB.
# chartData/bluegrass__charts__year-end__2011__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2010__bluegrass-albums.p
#   --> This file is 19.9kB.
# chartData/bluegrass__charts__year-end__2009__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2008__bluegrass-albums.p
#   --> This file is 19.4kB.
# chartData/bluegrass__charts__year-end__2007__bluegrass-albums.p
#   --> This file is 19.8kB.
# chartData/bluegrass__charts__year-end__2006__bluegrass-albums.p
#   --> This file is 19.9kB.
# chartData/bluegrass__charts__year-end__2019__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2018__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2017__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2016__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2015__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2014__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2013__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2012__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2011__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2010__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2009__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2008__bluegrass-artists.p
#   --> This file is 17.5kB.
# chartData/bluegrass__charts__year-end__2007__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2006__bluegrass-artists.p
#   --> This file is 17.6kB.
# chartData/bluegrass__charts__year-end__2016__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2015__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2014__bluegrass-distributors.p
#   --> This file is 16.6kB.
# chartData/bluegrass__charts__year-end__2013__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2012__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2011__bluegrass-distributors.p
#   --> This file is 16.8kB.
# chartData/bluegrass__charts__year-end__2010__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2009__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2008__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2007__bluegrass-distributors.p
#   --> This file is 16.7kB.
# chartData/bluegrass__charts__year-end__2006__bluegrass-distributors.p
#   --> This file is 16.6kB.
# chartData/blues__charts__year-end__2019__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2018__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2017__blues-albums-artists.p
#   --> This file is 18.2kB.
# chartData/blues__charts__year-end__2016__blues-albums-artists.p
#   --> This file is 18.2kB.
# chartData/blues__charts__year-end__2015__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2014__blues-albums-artists.p
#   --> This file is 18.2kB.
# chartData/blues__charts__year-end__2013__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2012__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2011__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2010__blues-albums-artists.p
#   --> This file is 18.2kB.
# chartData/blues__charts__year-end__2009__blues-albums-artists.p
#   --> This file is 18.2kB.
# chartData/blues__charts__year-end__2008__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2007__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2006__blues-albums-artists.p
#   --> This file is 18.1kB.
# chartData/blues__charts__year-end__2019__blues-albums.p
#   --> This file is 19.6kB.
# chartData/blues__charts__year-end__2018__blues-albums.p
#   --> This file is 19.7kB.
# chartData/blues__charts__year-end__2017__blues-albums.p
#   --> This file is 19.7kB.
# chartData/blues__charts__year-end__2016__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2015__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2014__blues-albums.p
#   --> This file is 19.9kB.
# chartData/blues__charts__year-end__2013__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2012__blues-albums.p
#   --> This file is 19.7kB.
# chartData/blues__charts__year-end__2011__blues-albums.p
#   --> This file is 19.5kB.
# chartData/blues__charts__year-end__2010__blues-albums.p
#   --> This file is 19.6kB.
# chartData/blues__charts__year-end__2009__blues-albums.p
#   --> This file is 19.9kB.
# chartData/blues__charts__year-end__2008__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2007__blues-albums.p
#   --> This file is 19.8kB.
# chartData/blues__charts__year-end__2006__blues-albums.p
#   --> This file is 19.7kB.
# chartData/blues__charts__year-end__2016__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2015__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2014__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2013__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2012__blues-distributors.p
#   --> This file is 16.8kB.
# chartData/blues__charts__year-end__2011__blues-distributors.p
#   --> This file is 16.8kB.
# chartData/blues__charts__year-end__2010__blues-distributors.p
#   --> This file is 16.8kB.
# chartData/blues__charts__year-end__2009__blues-distributors.p
#   --> This file is 16.8kB.
# chartData/blues__charts__year-end__2008__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2007__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/blues__charts__year-end__2006__blues-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2016__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2015__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2014__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2013__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2012__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2011__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2010__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2009__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2008__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2007__cast-album-distributors.p
#   --> This file is 16.7kB.
# chartData/cast__charts__year-end__2006__cast-album-distributors.p
#   --> This file is 16.6kB.
# chartData/cast__charts__year-end__2019__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2018__cast-albums.p
#   --> This file is 18.8kB.
# chartData/cast__charts__year-end__2017__cast-albums.p
#   --> This file is 18.8kB.
# chartData/cast__charts__year-end__2016__cast-albums.p
#   --> This file is 18.6kB.
# chartData/cast__charts__year-end__2015__cast-albums.p
#   --> This file is 18.7kB.
# chartData/cast__charts__year-end__2014__cast-albums.p
#   --> This file is 19.1kB.
# chartData/cast__charts__year-end__2013__cast-albums.p
#   --> This file is 18.8kB.
# chartData/cast__charts__year-end__2012__cast-albums.p
#   --> This file is 18.7kB.
# chartData/cast__charts__year-end__2011__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2010__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2009__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2008__cast-albums.p
#   --> This file is 19.0kB.
# chartData/cast__charts__year-end__2007__cast-albums.p
#   --> This file is 18.9kB.
# chartData/cast__charts__year-end__2006__cast-albums.p
#   --> This file is 19.0kB.
# chartData/catalog__charts__year-end__2019__catalog-albums.p
#   --> This file is 23.8kB.
# chartData/catalog__charts__year-end__2018__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2017__catalog-albums.p
#   --> This file is 23.7kB.
# chartData/catalog__charts__year-end__2016__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2015__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2014__catalog-albums.p
#   --> This file is 23.8kB.
# chartData/catalog__charts__year-end__2013__catalog-albums.p
#   --> This file is 24.0kB.
# chartData/catalog__charts__year-end__2012__catalog-albums.p
#   --> This file is 23.7kB.
# chartData/catalog__charts__year-end__2011__catalog-albums.p
#   --> This file is 23.8kB.
# chartData/catalog__charts__year-end__2010__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2009__catalog-albums.p
#   --> This file is 23.4kB.
# chartData/catalog__charts__year-end__2008__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2007__catalog-albums.p
#   --> This file is 23.6kB.
# chartData/catalog__charts__year-end__2006__catalog-albums.p
#   --> This file is 23.7kB.
# chartData/catalog__charts__year-end__2019__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2018__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2017__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2016__catalog-artists.p
#   --> This file is 18.0kB.
# chartData/catalog__charts__year-end__2015__catalog-artists.p
#   --> This file is 18.0kB.
# chartData/catalog__charts__year-end__2014__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2013__catalog-artists.p
#   --> This file is 18.0kB.
# chartData/catalog__charts__year-end__2012__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2011__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2010__catalog-artists.p
#   --> This file is 18.0kB.
# chartData/catalog__charts__year-end__2009__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2008__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2007__catalog-artists.p
#   --> This file is 18.1kB.
# chartData/catalog__charts__year-end__2006__catalog-artists.p
#   --> This file is 18.2kB.
# chartData/catalog__charts__year-end__2016__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2015__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2014__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2013__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2012__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2011__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2010__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2009__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2008__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2007__pop-catalog-distributors.p
#   --> This file is 16.7kB.
# chartData/catalog__charts__year-end__2019__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2018__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2017__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2016__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2015__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2014__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2013__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2012__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2011__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2010__pop-catalog-labels.p
#   --> This file is 17.1kB.
# chartData/catalog__charts__year-end__2009__pop-catalog-labels.p
#   --> This file is 16.8kB.
# chartData/catalog__charts__year-end__2008__pop-catalog-labels.p
#   --> This file is 16.8kB.
# chartData/catalog__charts__year-end__2007__pop-catalog-labels.p
#   --> This file is 16.8kB.
# chartData/catalog__charts__year-end__2006__pop-catalog-labels.p
#   --> This file is 16.8kB.
# chartData/christian__charts__year-end__2019__christian-airplay-artists.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__
#   --> This file is 22.6kB.
# chartData/christian__charts__year-end__2014__hot-christian-adult-contemporary.p
#   --> This file is 22.8kB.
# chartData/christian__charts__year-end__2013__hot-christian-adult-contemporary.p
#   --> This file is 22.5kB.
# chartData/christian__charts__year-end__2012__hot-christian-adult-contemporary.p
#   --> This file is 22.7kB.
# chartData/christian__charts__year-end__2011__hot-christian-adult-contemporary.p
#   --> This file is 22.3kB.
# chartData/christian__charts__year-end__2010__hot-christian-adult-contemporary.p
#   --> This file is 22.6kB.
# chartData/christian__charts__year-end__2009__hot-christian-adult-contemporary.p
#   --> This file is 21.5kB.
# chartData/christian__charts__year-end__2008__hot-christian-adult-contemporary.p
#   --> This file is 21.4kB.
# chartData/christian__charts__year-end__2007__hot-christian-adult-contemporary.p
#   --> This file is 21.5kB.
# chartData/christian__charts__year-end__2006__hot-christian-adult-contemporary.p
#   --> This file is 21.4kB.
# chartData/christian__charts__year-end__2019__hot-christian-songs-artists.p
#   --> This file is 20.4kB.
# chartData/christian__charts__year-end__2018__hot-christian-songs-artists.p
#   --> This file is 20.4kB.
# chartData/christian__charts__year-end__2017__hot-christian-songs-artists.p
#   --> This file is 20.3kB.
# chartData/christian__charts__year-end__2016__hot-christian-songs-artists.p
#   --> This file is 18.2kB.
# chartData/christian__charts__year-end__2015__hot-christian-songs-artists.p
#   --> This file is 18.2kB.
# chartData/christian__charts__year-end__2014__hot-christian-songs-artists.p
#   --> This file is 20.5kB.
# chartData/christian__charts__year-end__2013__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2012__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2011__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2010__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2009__hot-christian-songs-artists.p
#   --> This file is 18.2kB.
# chartData/christian__charts__year-end__2008__hot-christian-songs-artists.p
#   --> This file is 18.2kB.
# chartData/christian__charts__year-end__2007__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2006__hot-christian-songs-artists.p
#   --> This file is 18.1kB.
# chartData/christian__charts__year-end__2019__hot-christian-songs.p
#   --> This file is 28.5kB.
# chartData/christian__charts__year-end__2018__hot-christian-songs.p
#   --> This file is 28.4kB.
# chartData/christian__charts__year-end__2017__hot-christian-songs.p
#   --> This file is 28.1kB.
# chartData/christian__charts__year-end__2016__hot-christian-songs.p
#   --> This file is 23.0kB.
# chartData/christian__charts__year-end__2015__hot-christian-songs.p
#   --> This file is 23.0kB.
# chartData/christian__charts__year-end__2014__hot-christian-songs.p
#   --> This file is 28.0kB.
# chartData/christian__charts__year-end__2013__hot-christian-songs.p
#   --> This file is 23.1kB.
# chartData/christian__charts__year-end__2012__hot-christian-songs.p
#   --> This file is 22.9kB.
# chartData/christian__charts__year-end__2011__hot-christian-songs.p
#   --> This file is 22.9kB.
# chartData/christian__charts__year-end__2010__hot-christian-songs.p
#   --> This file is 22.9kB.
# chartData/christian__charts__year-end__2009__hot-christian-songs.p
#   --> This file is 23.2kB.
# chartData/christian__charts__year-end__2008__hot-christian-songs.p
#   --> This file is 21.0kB.
# chartData/christian__charts__year-end__2007__hot-christian-songs.p
#   --> This file is 21.9kB.
# chartData/christian__charts__year-end__2006__hot-christian-songs.p
#   --> This file is 21.8kB.
# chartData/christian__charts__year-end__2019__top-christian-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2018__top-christian-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2017__top-christian-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2016__top-christian-artists-duo-group.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2015__top-christian-artists-duo-group.p
#   --> This file is 17.5kB.
# chartData/christian__charts__year-end__2014__top-christian-artists-duo-group.p
#   --> This file is 17.5kB.
# chartData/christian__charts__year-end__2019__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2018__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2017__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2016__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2015__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2014__top-christian-artists-female.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2019__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2018__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2017__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2016__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2015__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2014__top-christian-artists-male.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2019__top-christian-artists.p
#   --> This file is 22.5kB.
# chartData/christian__charts__year-end__2018__top-christian-artists.p
#   --> This file is 22.8kB.
# chartData/christian__charts__year-end__2017__top-christian-artists.p
#   --> This file is 22.6kB.
# chartData/christian__charts__year-end__2016__top-christian-artists.p
#   --> This file is 22.7kB.
# chartData/christian__charts__year-end__2015__top-christian-artists.p
#   --> This file is 22.8kB.
# chartData/christian__charts__year-end__2014__top-christian-artists.p
#   --> This file is 22.8kB.
# chartData/christian__charts__year-end__2019__top-christian-new-artists.p
#   --> This file is 17.5kB.
# chartData/christian__charts__year-end__2018__top-christian-new-artists.p
#   --> This file is 17.5kB.
# chartData/christian__charts__year-end__2017__top-christian-new-artists.p
#   --> This file is 17.6kB.
# chartData/christian__charts__year-end__2016__top-christian-new-artists.p
#   --> This file is 17.4kB.
# chartData/christian__charts__year-end__2015__top-christian-new-artists.p
#   --> This file is 17.5kB.
# chartData/christian__charts__year-end__2014__top-christian-new-artists.p
#   --> This file is 17.5kB.
# chartData/classical__charts__year-end__2019__classical-albums-artists.p
#   --> This file is 19.9kB.
# chartData/classical__charts__year-end__2018__classical-albums-artists.p
#   --> This file is 19.8kB.
# chartData/classical__charts__year-end__2017__classical-albums-artists.p
#   --> This file is 19.7kB.
# chartData/classical__charts__year-end__2016__classical-albums-artists.p
#   --> This file is 19.8kB.
# chartData/classical__charts__year-end__2015__classical-albums-artists.p
#   --> This file is 19.7kB.
# chartData/classical__charts__year-end__2014__classical-albums-artists.p
#   --> This file is 19.7kB.
# chartData/classical__charts__year-end__2013__classical-albums-artists.p
#   --> This file is 19.8kB.
# chartData/classical__charts__year-end__2012__classical-albums-artists.p
#   --> This file is 19.6kB.
# chartData/classical__charts__year-end__2011__classical-albums-artists.p
#   --> This file is 19.6kB.
# chartData/classical__charts__year-end__2010__classical-albums-artists.p
#   --> This file is 19.6kB.
# chartData/classical__charts__year-end__2009__classical-albums-artists.p
#   --> This file is 19.7kB.
# chartData/classical__charts__year-end__2019__classical-albums.p
#   --> This file is 22.9kB.
# chartData/classical__charts__year-end__2018__classical-albums.p
#   --> This file is 22.9kB.
# chartData/classical__charts__year-end__2017__classical-albums.p
#   --> This file is 23.0kB.
# chartData/classical__charts__year-end__2016__classical-albums.p
#   --> This file is 23.4kB.
# chartData/classical__charts__year-end__2015__classical-albums.p
#   --> This file is 23.2kB.
# chartData/classical__charts__year-end__2014__classical-albums.p
#   --> This file is 23.1kB.
# chartData/classical__charts__year-end__2013__classical-albums.p
#   --> This file is 22.9kB.
# chartData/classical__charts__year-end__2012__classical-albums.p
#   --> This file is 22.8kB.
# chartData/classical__charts__year-end__2011__classical-albums.p
#   --> This file is 22.6kB.
# chartData/classical__charts__year-end__2010__classical-albums.p
#   --> This file is 22.8kB.
# chartData/classical__charts__year-end__2009__classical-albums.p
#   --> This file is 23.2kB.
# chartData/classical__charts__year-end__2019__classical-crossover-albums-artists.p
#   --> This file is 17.7kB.
# chartData/classical__charts__year-end__2018__classical-crossover-albums-artists.p
# ...
# chartData/hot-100__charts__year-end__2015__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2014__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2013__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2012__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2011__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2010__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2009__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2008__hot-100-artists-male.p
#   --> This file is 18.0kB.
# chartData/hot-100__charts__year-end__2007__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2006__hot-100-artists-male.p
#   --> This file is 18.1kB.
# chartData/hot-100__charts__year-end__2019__hot-100-artists.p
#   --> This file is 27.6kB.
# chartData/hot-100__charts__year-end__2018__hot-100-artists.p
#   --> This file is 27.2kB.
# chartData/hot-100__charts__year-end__2017__hot-100-artists.p
#   --> This file is 27.1kB.
# chartData/hot-100__charts__year-end__2016__hot-100-artists.p
#   --> This file is 26.9kB.
# chartData/hot-100__charts__year-end__2015__hot-100-artists.p
#   --> This file is 27.3kB.
# chartData/hot-100__charts__year-end__2014__hot-100-artists.p
#   --> This file is 27.4kB.
# chartData/hot-100__charts__year-end__2013__hot-100-artists.p
#   --> This file is 27.3kB.
# chartData/hot-100__charts__year-end__2012__hot-100-artists.p
#   --> This file is 27.0kB.
# chartData/hot-100__charts__year-end__2011__hot-100-artists.p
#   --> This file is 27.2kB.
# chartData/hot-100__charts__year-end__2010__hot-100-artists.p
#   --> This file is 27.3kB.
# chartData/hot-100__charts__year-end__2009__hot-100-artists.p
#   --> This file is 27.2kB.
# chartData/hot-100__charts__year-end__2008__hot-100-artists.p
#   --> This file is 27.0kB.
# chartData/hot-100__charts__year-end__2007__hot-100-artists.p
#   --> This file is 27.0kB.
# chartData/hot-100__charts__year-end__2006__hot-100-artists.p
#   --> This file is 27.0kB.
# chartData/hot-100__charts__year-end__2019__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2018__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2017__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2016__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2015__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2014__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2013__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2012__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2011__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2010__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2009__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2008__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2007__hot-100-labels.p
#   --> This file is 17.1kB.
# chartData/hot-100__charts__year-end__2006__hot-100-labels.p
#   --> This file is 16.8kB.
# chartData/hot-100__charts__year-end__2016__hot-100-producers.p
#   --> This file is 18.6kB.
# chartData/hot-100__charts__year-end__2015__hot-100-producers.p
#   --> This file is 18.6kB.
# chartData/hot-100__charts__year-end__2014__hot-100-producers.p
#   --> This file is 18.5kB.
# chartData/hot-100__charts__year-end__2013__hot-100-producers.p
#   --> This file is 18.6kB.
# chartData/hot-100__charts__year-end__2012__hot-100-producers.p
#   --> This file is 18.6kB.
# chartData/hot-100__charts__year-end__2011__hot-100-producers.p
#   --> This file is 18.6kB.
# chartData/hot-100__charts__year-end__2019__hot-100-songs.p
#   --> This file is 29.0kB.
# chartData/hot-100__charts__year-end__2018__hot-100-songs.p
#   --> This file is 28.5kB.
# chartData/hot-100__charts__year-end__2017__hot-100-songs.p
#   --> This file is 28.6kB.
# chartData/hot-100__charts__year-end__2016__hot-100-songs.p
#   --> This file is 27.8kB.
# chartData/hot-100__charts__year-end__2015__hot-100-songs.p
#   --> This file is 28.4kB.
# chartData/hot-100__charts__year-end__2014__hot-100-songs.p
#   --> This file is 28.4kB.
# chartData/hot-100__charts__year-end__2013__hot-100-songs.p
#   --> This file is 28.2kB.
# chartData/hot-100__charts__year-end__2012__hot-100-songs.p
#   --> This file is 27.9kB.
# chartData/hot-100__charts__year-end__2011__hot-100-songs.p
#   --> This file is 28.3kB.
# chartData/hot-100__charts__year-end__2010__hot-100-songs.p
#   --> This file is 28.2kB.
# chartData/hot-100__charts__year-end__2009__hot-100-songs.p
#   --> This file is 27.9kB.
# chartData/hot-100__charts__year-end__2008__hot-100-songs.p
#   --> This file is 28.2kB.
# chartData/hot-100__charts__year-end__2007__hot-100-songs.p
#   --> This file is 28.2kB.
# chartData/hot-100__charts__year-end__2006__hot-100-songs.p
#   --> This file is 28.2kB.
# chartData/independent__charts__year-end__2019__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2018__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2017__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2016__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2015__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2014__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2013__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2012__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2011__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2010__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2009__independent-album-labels.p
#   --> This file is 17.1kB.
# chartData/independent__charts__year-end__2008__independent-album-labels.p
#   --> This file is 16.8kB.
# chartData/independent__charts__year-end__2007__independent-album-labels.p
#   --> This file is 16.8kB.
# chartData/independent__charts__year-end__2006__independent-album-labels.p
#   --> This file is 16.8kB.
# chartData/independent__charts__year-end__2019__independent-albums.p
#   --> This file is 23.3kB.
# chartData/independent__charts__year-end__2018__independent-albums.p
#   --> This file is 23.3kB.
# chartData/independent__charts__year-end__2017__independent-albums.p
#   --> This file is 23.3kB.
# chartData/independent__charts__year-end__2016__independent-albums.p
#   --> This file is 23.6kB.
# chartData/independent__charts__year-end__2015__independent-albums.p
#   --> This file is 23.9kB.
# chartData/independent__charts__year-end__2014__independent-albums.p
#   --> This file is 24.0kB.
# chartData/independent__charts__year-end__2013__independent-albums.p
#   --> This file is 24.1kB.
# chartData/independent__charts__year-end__2012__independent-albums.p
#   --> This file is 23.5kB.
# chartData/independent__charts__year-end__2011__independent-albums.p
#   --> This file is 24.0kB.
# chartData/independent__charts__year-end__2010__independent-albums.p
#   --> This file is 23.6kB.
# chartData/independent__charts__year-end__2009__independent-albums.p
#   --> This file is 24.0kB.
# chartData/independent__charts__year-end__2008__independent-albums.p
#   --> This file is 23.8kB.
# chartData/independent__charts__year-end__2007__independent-albums.p
#   --> This file is 23.9kB.
# chartData/independent__charts__year-end__2006__independent-albums.p
#   --> This file is 24.4kB.
# chartData/independent__charts__year-end__2019__independent-artists.p
#   --> This file is 18.1kB.
# chartData/independent__charts__year-end__2018__independent-artists.p
#   --> This file is 18.1kB.
# chartData/independent__charts__year-end__2017__independent-artists.p
#   --> This file is 18.1kB.
# chartData/independent__charts__year-end__2016__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2015__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2014__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2013__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2012__independent-artists.p
#   --> This file is 19.7kB.
# chartData/independent__charts__year-end__2011__independent-artists.p
#   --> This file is 19.7kB.
# chartData/independent__charts__year-end__2010__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2009__independent-artists.p
#   --> This file is 19.7kB.
# chartData/independent__charts__year-end__2008__independent-artists.p
#   --> This file is 19.8kB.
# chartData/independent__charts__year-end__2007__independent-artists.p
#   --> This file is 19.7kB.
# chartData/independent__charts__year-end__2006__independent-artists.p
#   --> This file is 19.7kB.
# chartData/international__charts__year-end__2019__canadian-hot-100.p
#   --> This file is 29.4kB.
# chartData/international__charts__year-end__2018__canadian-hot-100.p
#   --> This file is 28.6kB.
# chartData/international__charts__year-end__2017__canadian-hot-100.p
#   --> This file is 28.6kB.
# chartData/international__charts__year-end__2016__canadian-hot-100.p
#   --> This file is 28.2kB.
# chartData/international__charts__year-end__2015__canadian-hot-100.p
#   --> This file is 28.2kB.
# chartData/international__charts__year-end__2014__canadian-hot-100.p
#   --> This file is 28.4kB.
# chartData/international__charts__year-end__2013__canadian-hot-100.p
#   --> This file is 28.2kB.
# chartData/international__charts__year-end__2012__canadian-hot-100.p
#   --> This file is 28.4kB.
# chartData/international__charts__year-end__2011__canadian-hot-100.p
#   --> This file is 27.9kB.
# chartData/international__charts__year-end__2010__canadian-hot-100.p
#   --> This file is 27.8kB.
# chartData/international__charts__year-end__2009__canadian-hot-100.p
#   --> This file is 28.1kB.
# chartData/international__charts__year-end__2008__canadian-hot-100.p
#   --> This file is 28.0kB.
# chartData/international__charts__year-end__2019__candaian-hot-100-artists.p
#   --> This file is 20.4kB.
# chartData/international__charts__year-end__2018__candaian-hot-100-artists.p
#   --> This file is 20.4kB.
# chartData/international__charts__year-end__2017__candaian-hot-100-artists.p
#   --> This file is 20.4kB.
# chartData/international__charts__year-end__2016__candaian-hot-100-artists.p
#   --> This file is 20.2kB.
# chartData/international__charts__year-end__2015__candaian-hot-100-artists.p
#   --> This file is 20.3kB.
# chartData/international__charts__year-end__2014__candaian-hot-100-artists.p
#   --> This file is 20.3kB.
# chartData/international__charts__year-end__2013__candaian-hot-100-artists.p
#   --> This file is 20.4kB.
# chartData/international__charts__year-end__2012__candaian-hot-100-artists.p
#   --> This file is 20.2kB.
# chartData/international__charts__year-end__2011__candaian-hot-100-artists.p
#   --> This file is 20.2kB.
# chartData/international__charts__year-end__2010__candaian-hot-100-artists.p
#   --> This file is 20.2kB.
# chartData/international__charts__year-end__2009__candaian-hot-100-artists.p
#   --> This file is 20.3kB.
# chartData/international__charts__year-end__2008__candaian-hot-100-artists.p
#   --> This file is 20.4kB.
# chartData/international__charts__year-end__2019__hot-canadian-digital-songs.p
#   --> This file is 23.1kB.
# chartData/international__charts__year-end__2018__hot-canadian-digital-songs.p
#   --> This file is 22.9kB.
# chartData/international__charts__year-end__2017__hot-canadian-digital-songs.p
#   --> This file is 23.0kB.
# chartData/international__charts__year-end__2016__hot-canadian-digital-songs.p
#   --> This file is 22.6kB.
# chartData/international__charts__year-end__2015__hot-canadian-digital-songs.p
#   --> This file is 22.8kB.
# chartData/international__charts__year-end__2014__hot-canadian-digital-songs.p
#   --> This file is 22.7kB.
# chartData/international__charts__year-end__2013__hot-canadian-digital-songs.p
#   --> This file is 23.0kB.
# chartData/international__charts__year-end__2012__hot-canadian-digital-songs.p
#   --> This file is 22.7kB.
# chartData/international__charts__year-end__2011__hot-canadian-digital-songs.p
#   --> This file is 22.8kB.
# chartData/international__charts__year-end__2010__hot-canadian-digital-songs.p
#   --> This file is 22.6kB.
# chartData/international__charts__year-end__2009__hot-canadian-digital-songs.p
#   --> This file is 22.8kB.
# chartData/international__charts__year-end__2008__hot-canadian-digital-songs.p
#   --> This file is 20.0kB.
# chartData/international__charts__year-end__2019__top-canadian-albums.p
#   --> This file is 23.5kB.
# chartData/international__charts__year-end__2018__top-canadian-albums.p
#   --> This file is 23.4kB.
# chartData/international__charts__year-end__2017__top-canadian-albums.p
#   --> This file is 23.5kB.
# chartData/international__charts__year-end__2016__top-canadian-albums.p
#   --> This file is 23.4kB.
# chartData/international__charts__year-end__2015__top-canadian-albums.p
#   --> This file is 23.4kB.
# chartData/international__charts__year-end__2014__top-canadian-albums.p
#   --> This file is 23.5kB.
# chartData/international__charts__year-end__2013__top-canadian-albums.p
#   --> This file is 23.8kB.
# chartData/international__charts__year-end__2012__top-canadian-albums.p
#   --> This file is 23.6kB.
# chartData/international__charts__year-end__2011__top-canadian-albums.p
#   --> This file is 23.6kB.
# chartData/international__charts__year-end__2010__top-canadian-albums.p
#   --> This file is 23.5kB.
# chartData/international__charts__year-end__2009__top-canadian-albums.p
#   --> This file is 23.4kB.
# chartData/international__charts__year-end__2008__top-canadian-albums.p
#   --> This file is 20.8kB.
# chartData/jazz__charts__year-end__2019__contemporary-jazz-albums.p
#   --> This file is 20.3kB.
# chartData/jazz__charts__year-end__2018__contemporary-jazz-albums.p
#   --> This file is 20.0kB.
# chartData/jazz__charts__year-end__2017__contemporary-jazz-albums.p
#   --> This file is 20.3kB.
# chartData/jazz__charts__year-end__2016__contemporary-jazz-albums.p
#   --> This file is 19.2kB.
# chartData/jazz__charts__year-end__2015__contemporary-jazz-albums.p
#   --> This file is 19.2kB.
# chartData/jazz__charts__year-end__2014__contemporary-jazz-albums.p
#   --> This file is 20.4kB.
# chartData/jazz__charts__year-end__2013__contemporary-jazz-albums.p
#   --> This file is 20.2kB.
# chartData/jazz__charts__year-end__2012__contemporary-jazz-albums.p
#   --> This file is 20.4kB.
# chartData/jazz__charts__year-end__2011__contemporary-jazz-albums.p
#   --> This file is 20.3kB.
# chartData/jazz__charts__year-end__2010__contemporary-jazz-albums.p
#   --> This file is 20.4kB.
# chartData/jazz__charts__year-end__2009__contemporary-jazz-albums.p
#   --> This file is 20.4kB.
# chartData/jazz__charts__year-end__2008__contemporary-jazz-albums.p
#   --> This file is 20.5kB.
# chartData/jazz__charts__year-end__2007__contemporary-jazz-albums.p
#   --> This file is 20.4kB.
# chartData/jazz__charts__year-end__2006__contemporary-jazz-albums.p
#   --> This file is 20.5kB.
# chartData/jazz__charts__year-end__2019__contemporary-jazz-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2018__contemporary-jazz-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2017__contemporary-jazz-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2016__contemporary-jazz-artists.p
#   --> This file is 17.6kB.
# chartData/jazz__charts__year-end__2015__contemporary-jazz-artists.p
#   --> This file is 17.6kB.
# chartData/jazz__charts__year-end__2014__contemporary-jazz-artists.p
#   --> This file is 17.7kB.
# chartData/jazz__charts__year-end__2013__contemporary-jazz-artists.p

# %%
bYECharts = billboardYECharts()
# Out:
# ['gospel', 'rhythmic', 'soundtracks', 'blues', 'new_age', 'pop', 'streaming_songs', 'reggae', 'independent', 'social', 'hot_100', 'americana__folk', 'songwriters__publishers', 'rap', 'international', 'rb', 'digital_song_sales', 'other_albums', 'billboard_200', 'bluegrass', 'overall', 'dance__electronic', 'rb__hip_hop', 'catalog', 'radio_songs', 'ratio', 'chartNames', 'chartRanks']

# %%
categories = {}
files = bYE.getSummaryFiles()
for ifile in files:
    category = getBaseFilename(ifile)
    categories[category] = {}
    categoryData = getFile(ifile)
    for year,yearData in categoryData.items():
        for chartName,chartData in yearData.items():
            categories[category][chartName] = True
# Out:
# Found 36 summary files

# %%
for category,categoryData in categories.items():
    print("        self.{0} = {1}\n".format(category.replace("-","_"), list(categoryData.keys())))
# Out:
#         self.country = ['country-digital-songs', 'country-artists-duo-group', 'hot-country-songs-artists', 'top-country-albums', 'country-streaming-songs-artists', 'country-airplay-artists', 'country-digital-songs-artists', 'country-streaming-songs', 'top-country-artists', 'country-artists-male', 'hot-country-songs', 'country-artists-female', 'top-country-albums-artists', 'new-country-artists', 'country-airplay-songs']
#
#         self.gospel = ['hot-gospel-songs', 'gospel-albums', 'hot-gospel-songs-artists', 'gospel-albums-artists', 'gospel-digital-songs', 'gospel-digital-songs-artists', 'gospel-streaming-songs', 'gospel-airplay-songs', 'top-gospel-new-artists', 'top-gospel-artists-female', 'gospel-airplay-artists', 'top-gospel-artists-duo-group', 'gospel-streaming-songs-artists', 'top-gospel-artists', 'top-gospel-artists-male']
#
#         self.adult = ['adult-contemporary-artists', 'adult-pop-songs-artists', 'adult-pop-songs', 'adult-contemporary-songs']
#
#         self.cast = ['cast-albums']
#
#         self.rhythmic = ['rhythmic-songs', 'rhythmic-artists']
#
#         self.soundtracks = ['top-soundtracks-albums']
#
#         self.blues = ['blues-albums-artists', 'blues-albums']
#
#         self.jazz = ['jazz-albums-artists', 'contemporary-jazz-albums', 'smooth-jazz-songs-artists', 'smooth-jazz-songs', 'contemporary-jazz-artists', 'jazz-albums', 'traditional-jazz-albums-artists']
#
#         self.new_age = ['new-age-albums', 'new-age-albums-artists']
#
#         self.pop = ['pop-songs', 'pop-songs-artists']
#
#         self.streaming_songs = ['on-demand-songs', 'streaming-songs-artists', 'on-demand-songs-artists', 'streaming-songs']
#
#         self.reggae = ['reggae-albums-artists', 'reggae-albums']
#
#         self.world = ['world-albums', 'world-albums-artists']
#
#         self.independent = ['independent-artists', 'independent-albums']
#
#         self.social = ['social-50-artists']
#
#         self.comedy = ['comedy-albums', 'comedy-albums-artists']
#
#         self.hot_100 = ['hot-100-songs', 'hot-100-artists-male', 'hot-100-artists', 'hot-100-artists-female', 'hot-100-artists-duo-group']
#
#         self.christian = ['top-christian-new-artists', 'hot-christian-songs-artists', 'christian-digital-songs', 'christian-digital-songs-artists', 'hot-christian-songs', 'christian-streaming-songs-artists', 'hot-christian-adult-contemporary', 'top-christian-artists-male', 'christian-albums', 'top-christian-artists', 'christian-airplay-artists', 'top-christian-artists-female', 'top-christian-artists-duo-group', 'christian-streaming-songs', 'christian-airplay-songs', 'christian-albums-artists', 'hot-christian-adult-contemporary-artists']
#
#         self.americana__folk = ['folk-albums', 'folk-artists']
#
#         self.songwriters__publishers = ['dance-electronic-songwriters', 'hot-christian-songswriters', 'hot-country-songwriters', 'hot-latin-songswriters', 'hot-100-songwriters', 'hot-r-and-and-b-hip-hop-songwriters', 'hot-rock-songwriters', 'rap-songwriters', 'r-and-b-songwriters', 'hot-christian-adult-contemporary-songwriters']
#
#         self.rap = ['rap-digital-songs-artists', 'rap-airplay-artists', 'hot-rap-songs-artists', 'rap-airplay-songs', 'hot-rap-songs', 'rap-streaming-songs', 'rap-digital-songs', 'rap-streaming-songs-artists', 'rap-albums', 'rap-albums-artists']
#
#         self.international = ['top-canadian-albums', 'canadian-hot-100', 'candaian-hot-100-artists', 'hot-canadian-digital-songs']
#
#         self.latin = ['latin-streaming-songs-artists', 'latin-digital-songs-artists', 'hot-latin-songs-artists', 'latin-rhythm-albums-artists', 'regional-mexican-airplay-songs', 'top-new-latin-artists', 'latin-pop-airplay-artists', 'top-latin-albums-artists', 'latin-pop-albums-artists', 'regional-mexican-airplay-artists', 'regional-mexican-albums-artists', 'top-latin-artists-female', 'latin-pop-albums', 'tropical-airplay-songs', 'latin-digital-songs', 'regional-mexican-albums', 'hot-latin-songs', 'tropical-albums', 'latin-rhythm-albums-', 'top-latin-albums', 'latin-airplay-artists', 'top-latin-artists-male', 'latin-airplay-songs', 'top-latin-artists-duo-group', 'latin-rhythm-airplay-artists', 'latin-pop-airplay-songs', 'tropical-airplay-artists', 'tropical-albums-artists', 'latin-rhythm-airplay-songs', 'latin-streaming-songs', 'top-latin-artists']
#
#         self.rb = ['hot-mainstream-r-and-and-b-hip-hop-songs', 'hot-r-and-and-b-songs', 'adult-r-and-b-artists', 'r-and-b-digital-songs-artists', 'r-and-b-albums-artists', 'hot-r-and-and-b-songs-artists', 'r-and-b-streaming-songs-artists', 'r-and-b-digital-songs', 'r-and-b-albums', 'r-and-b-streaming-songs', 'adult-r-and-b-songs', 'hot-mainstream-r-and-and-b-hip-hop-artists']
#
#         self.digital_song_sales = ['digital-songs', 'digital-songs-artists']
#
#         self.other_albums = ['current-albums', 'tastemakers-albums', 'compilation-albums', 'vinyl-albums', 'top-album-title-sales', 'top-album-sales-artists']
#
#         self.kid = ['kid-albums', 'kid-albums-artists']
#
#         self.rock = ['mainstream-rock-artists', 'rock-digital-songs', 'adult-alternative-songs', 'alternative-digital-song-sales-yearend', 'mainstream-rock-songs-artists', 'alternative-songs', 'alternative-songs-artists', 'top-rock-albums', 'top-new-rock-artists', 'adult-alternative-songs-artists', 'hard-rock-digital-song-sales-yearend', 'hard-rock-albums-artists', 'top-alternative-album-artists', 'hot-rock-songs', 'rock-streaming-songs', 'hard-rock-albums', 'rock-digital-songs-artists', 'top-rock-artists', 'rock-airplay-artists', 'hot-rock-songs-artists', 'top-rock-albums-artists', 'top-alternative-albums', 'rock-airplay-songs', 'rock-streaming-songs-artists']
#
#         self.classical = ['classical-albums-artists', 'classical-crossover-albums', 'traditional-classical-albums-artists', 'classical-crossover-albums-artists', 'traditional-classical-albums', 'classical-albums']
#
#         self.billboard_200 = ['the-billboard-200-artists-male', 'top-billboard-200-artists', 'the-billboard-200-artists-female', 'top-billboard-200-albums', 'the-billboard-200-artists-duo-group']
#
#         self.bluegrass = ['bluegrass-artists', 'bluegrass-albums']
#
#         self.overall = ['top-artists-female', 'top-artists-duo-group', 'top-artists', 'top-new-artists', 'top-artists-male']
#
#         self.dance__electronic = ['top-dance-electronic-artists', 'dance-electronic-digital-songs-artists', 'dance-electronic-digital-songs', 'dance-mix-show-airplay-songs', 'dance-electronic-albums', 'dance-mix-show-airplay-artists', 'top-dance-electronic-new-artists', 'hot-dance-electronic-songs', 'dance-electronic-streaming-songs-artists', 'hot-dance-electronic-songs-artists', 'dance-electronic-streaming-songs', 'top-new-dance-eletronic-artists']
#
#         self.rb__hip_hop = ['r-and-and-b-hip-hop-artists-female', 'top-r-and-b-hip-hop-albums', 'r-and-b-hip-hop-digital-songs', 'new-r-and-and-b-hip-hop-artists', 'top-r-and-b-hip-hop-albums-artists', 'r-and-and-b-hip-hop-artists-duo-group', 'r-and-and-b-hip-hop-artists-male', 'hot-r-and-and-b-hip-hop-songs', 'r-and-b-hip-hop-digital-songs-artists', 'hot-r-and-b-hip-hop-songs-artists', 'r-and-b-hip-hop-airplay-songs', 'top-r-and-b-hip-hop-artists', 'r-and-b-hip-hop-streaming-songs-artists', 'r-and-b-hip-hop-streaming-songs', 'r-and-b-hip-hop-airplay-artists']
#
#         self.catalog = ['catalog-artists', 'catalog-albums']
#
#         self.radio_songs = ['radio-songs-artists', 'radio-songs']

# %%
from copy import deepcopy
results = deepcopy(bYE.chartData)

# %%
bYE = billboardYE()
#bYE.parse()
bYE.chartData = results
bYE.saveChartData()
# Out:
# Saving data to chartData/summary/jazz.p
#   --> This file is 39.5kB.
# Saved data to chartData/summary/jazz.p
#   --> This file is 39.5kB.
# Saving data to chartData/summary/rb--hip-hop.p
#   --> This file is 72.6kB.
# Saved data to chartData/summary/rb--hip-hop.p
#   --> This file is 72.6kB.
# Saving data to chartData/summary/latin.p
#   --> This file is 159.0kB.
# Saved data to chartData/summary/latin.p
#   --> This file is 159.0kB.
# Saving data to chartData/summary/christian.p
#   --> This file is 60.8kB.
# Saved data to chartData/summary/christian.p
#   --> This file is 60.8kB.
# Saving data to chartData/summary/rb.p
#   --> This file is 47.7kB.
# Saved data to chartData/summary/rb.p
#   --> This file is 47.7kB.
# Saving data to chartData/summary/rock.p
#   --> This file is 121.9kB.
# Saved data to chartData/summary/rock.p
#   --> This file is 121.9kB.
# Saving data to chartData/summary/other-albums.p
#   --> This file is 37.7kB.
# Saved data to chartData/summary/other-albums.p
#   --> This file is 37.7kB.
# Saving data to chartData/summary/hot-100.p
#   --> This file is 26.9kB.
# Saved data to chartData/summary/hot-100.p
#   --> This file is 26.9kB.
# Saving data to chartData/summary/reggae.p
#   --> This file is 10.1kB.
# Saved data to chartData/summary/reggae.p
#   --> This file is 10.1kB.
# Saving data to chartData/summary/streaming-songs.p
#   --> This file is 17.1kB.
# Saved data to chartData/summary/streaming-songs.p
#   --> This file is 17.1kB.
# Saving data to chartData/summary/international.p
#   --> This file is 31.4kB.
# Saved data to chartData/summary/international.p
#   --> This file is 31.4kB.
# Saving data to chartData/summary/gospel.p
#   --> This file is 49.5kB.
# Saved data to chartData/summary/gospel.p
#   --> This file is 49.5kB.
# Saving data to chartData/summary/independent.p
#   --> This file is 17.0kB.
# Saved data to chartData/summary/independent.p
#   --> This file is 17.0kB.
# Saving data to chartData/summary/country.p
#   --> This file is 69.7kB.
# Saved data to chartData/summary/country.p
#   --> This file is 69.7kB.
# Saving data to chartData/summary/songwriters--publishers.p
#   --> This file is 22.7kB.
# Saved data to chartData/summary/songwriters--publishers.p
#   --> This file is 22.7kB.
# Saving data to chartData/summary/classical.p
#   --> This file is 35.8kB.
# Saved data to chartData/summary/classical.p
#   --> This file is 35.8kB.
# Saving data to chartData/summary/kid.p
#   --> This file is 10.8kB.
# Saved data to chartData/summary/kid.p
#   --> This file is 10.8kB.
# Saving data to chartData/summary/billboard-200.p
#   --> This file is 29.6kB.
# Saved data to chartData/summary/billboard-200.p
#   --> This file is 29.6kB.
# Saving data to chartData/summary/new-age.p
#   --> This file is 9.3kB.
# Saved data to chartData/summary/new-age.p
#   --> This file is 9.3kB.
# Saving data to chartData/summary/soundtracks.p
#   --> This file is 8.3kB.
# Saved data to chartData/summary/soundtracks.p
#   --> This file is 8.3kB.
# Saving data to chartData/summary/overall.p
#   --> This file is 18.1kB.
# Saved data to chartData/summary/overall.p
#   --> This file is 18.1kB.
# Saving data to chartData/summary/rap.p
#   --> This file is 46.9kB.
# Saved data to chartData/summary/rap.p
#   --> This file is 46.9kB.
# Saving data to chartData/summary/digital-song-sales.p
#   --> This file is 18.1kB.
# Saved data to chartData/summary/digital-song-sales.p
#   --> This file is 18.1kB.
# Saving data to chartData/summary/adult.p
#   --> This file is 25.6kB.
# Saved data to chartData/summary/adult.p
#   --> This file is 25.6kB.
# Saving data to chartData/summary/cast.p
#   --> This file is 5.7kB.
# Saved data to chartData/summary/cast.p
#   --> This file is 5.7kB.
# Saving data to chartData/summary/world.p
#   --> This file is 10.4kB.
# Saved data to chartData/summary/world.p
#   --> This file is 10.4kB.
# Saving data to chartData/summary/blues.p
#   --> This file is 11.1kB.
# Saved data to chartData/summary/blues.p
#   --> This file is 11.1kB.
# Saving data to chartData/summary/americana--folk.p
#   --> This file is 9.8kB.
# Saved data to chartData/summary/americana--folk.p
#   --> This file is 9.8kB.
# Saving data to chartData/summary/rhythmic.p
#   --> This file is 14.2kB.
# Saved data to chartData/summary/rhythmic.p
#   --> This file is 14.2kB.
# Saving data to chartData/summary/dance--electronic.p
#   --> This file is 53.6kB.
# Saved data to chartData/summary/dance--electronic.p
#   --> This file is 53.6kB.
# Saving data to chartData/summary/radio-songs.p
#   --> This file is 15.8kB.
# Saved data to chartData/summary/radio-songs.p
#   --> This file is 15.8kB.
# Saving data to chartData/summary/catalog.p
#   --> This file is 13.3kB.
# Saved data to chartData/summary/catalog.p
#   --> This file is 13.3kB.
# Saving data to chartData/summary/comedy.p
#   --> This file is 11.1kB.
# Saved data to chartData/summary/comedy.p
#   --> This file is 11.1kB.
# Saving data to chartData/summary/pop.p
#   --> This file is 12.6kB.
# Saved data to chartData/summary/pop.p
#   --> This file is 12.6kB.
# Saving data to chartData/summary/social.p
#   --> This file is 4.3kB.
# Saved data to chartData/summary/social.p
#   --> This file is 4.3kB.
# Saving data to chartData/summary/bluegrass.p
#   --> This file is 9.7kB.
# Saved data to chartData/summary/bluegrass.p
#   --> This file is 9.7kB.

# %%
manDB   = masterArtistNameDB("main", init=False)
# Out:
# ========================= masterArtistNameDB =========================
#   Loading data from /Users/tgadfort/opt/anaconda3/envs/py37/musicnames/mainArtistNameDB.p
#   There are currently 6664 artist keys.
#   There are currently 7714 renamed artist keys.

# %%
# %load_ext autoreload
# %autoreload
from billboardYECharts import billboardYECharts
from billboardYE import billboardYE
bYE = billboardYE(minYear=1019,maxYear=2021)
bYE.setChartUsage(rank=[0])
bYE.setDBRenames(manDB)
bYE.setFullChartData()
bYE.setArtistAlbumData()
bYE.saveFullChartData()
bYE.saveArtistAlbumData()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   Getting Chart For hot
#   Using 5 Charts
#   Using 5 Charts
#   Using Charts (None): ['hot-100-songs', 'hot-100-artists-male', 'hot-100-artists', 'hot-100-artists-female', 'hot-100-artists-duo-group']
# Found 36 summary files
# Renamed 72 single artists
# Saving 339 Full Artist Data
# Saving data to currentBillboardYEFullChartArtistAlbumData.p
#   --> This file is 13.8kB.
# Saved data to currentBillboardYEFullChartArtistAlbumData.p
#   --> This file is 13.8kB.
# Saving 339 Artist Album Data to currentBillboardYEArtistAlbumData.p
# Saving data to currentBillboardYEArtistAlbumData.p
#   --> This file is 8.9kB.
# Saved data to currentBillboardYEArtistAlbumData.p
#   --> This file is 8.9kB.

# %%
# Out:
# Found 36 summary files
# Saving 256 Full Artist Data
# Saving data to currentBillboardYEFullChartArtistAlbumData.p
#   --> This file is 5.1kB.
# Saved data to currentBillboardYEFullChartArtistAlbumData.p
#   --> This file is 5.1kB.
# Saving 256 Artist Album Data to currentBillboardYEArtistAlbumData.p
# Saving data to currentBillboardYEArtistAlbumData.p
#   --> This file is 3.6kB.
# Saved data to currentBillboardYEArtistAlbumData.p
#   --> This file is 3.6kB.

# %%
fullChartData
# Out:
# {'Michael Buble': {'Songs': {"It's A Beautiful Day": {'adult-contemporary-songs': {'2013': 0}},
#    "It's All Good": {'smooth-jazz-songs': {'2006': 0}}},
#   'Albums': {}},
#  'Boney James Featuring Rick Braun': {'Songs': {'Batucada (The Beat)': {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Dave Koz Featuring Gerald Albright, Mindi Abair & Richard Elliot': {'Songs': {'Got To Get You Into My Life': {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Althea Rene': {'Songs': {'In The Flow': {'smooth-jazz-songs': {'2013': 0}},
#    'Gypsy Soul': {'smooth-jazz-songs': {'2017': 0}}},
#   'Albums': {}},
#  'Bob James & David Sanborn': {'Songs': {'Deep In The Weeds': {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Jeff Golub With Brian Auger': {'Songs': {'Pusherman': {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Greg Manning': {'Songs': {'Dance With You': {'smooth-jazz-songs': {'2013': 0}},
#    'Top Down': {'smooth-jazz-songs': {'2019': 0}}},
#   'Albums': {}},
#  'Kim Waters': {'Songs': {"It's A Party In Here": {'smooth-jazz-songs': {'2013': 0}},
#    'Go-Go Smooth': {'smooth-jazz-songs': {'2015': 0}},
#    'Got To Give It Up': {'smooth-jazz-songs': {'2007': 0}},
#    "Let's Get On It": {'smooth-jazz-songs': {'2009': 0}},
#    "Steppin' Out": {'smooth-jazz-songs': {'2006': 0}}},
#   'Albums': {'You Are My Lady': {'contemporary-jazz-albums': {'2007': 0}}}},
#  'Yellowjackets': {'Songs': {"Can't We Elope": {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Lebron': {'Songs': {'Groove City': {'smooth-jazz-songs': {'2013': 0}},
#    'Say You Will': {'smooth-jazz-songs': {'2019': 0}},
#    'Green Light': {'smooth-jazz-songs': {'2020': 0}}},
#   'Albums': {}},
#  'Marc Antoine': {'Songs': {'Montuno Bay': {'smooth-jazz-songs': {'2013': 0}}},
#   'Albums': {}},
#  'David Benoit': {'Songs': {"You're Amazing": {'smooth-jazz-songs': {'2013': 0}},
#    "Feelin' It": {'smooth-jazz-songs': {'2012': 0}},
#    "Will's Chill": {'smooth-jazz-songs': {'2010': 0}},
#    'Botswana Bossa Nova': {'smooth-jazz-songs': {'2011': 0}}},
#   'Albums': {}},
#  'Dave Koz/Gerald Albright/Mindi Abair/Richard Elliot': {'Songs': {},
#   'Albums': {'Dave Koz And Friends: Summer Horns': {'jazz-albums': {'2013': 0,
#      '2014': 0},
#     'contemporary-jazz-albums': {'2014': 0}}}},
#  'Tony Bennett/Dave Brubeck': {'Songs': {},
#   'Albums': {'Bennett/Brubeck: The White House Sessions, Live 1962': {'jazz-albums': {'2013': 0}}}},
#  'Various Artists': {'Songs': {},
#   'Albums': {'In Love... With Cole Porter': {'jazz-albums': {'2013': 0}},
#    'Fascinating Gershwin: Landmark Performances From The Gershwin Songbook': {'jazz-albums': {'2015': 0}},
#    'Blue Note Blend': {'jazz-albums': {'2015': 0}},
#     'compilation-albums': {'2013': 0}},
#    'NOW 44': {'compilation-albums': {'2013': 0, '2012': 0}},
#    'NOW 45': {'compilation-albums': {'2013': 0}},
#    'NOW 46': {'compilation-albums': {'2013': 0}},
#    'NOW 47': {'compilation-albums': {'2013': 0, '2014': 0}},
#    'NOW 43': {'compilation-albums': {'2013': 0, '2012': 0}},
#    '12-12-12 The Concert For Sandy Relief': {'compilation-albums': {'2013': 0}},
#    "NOW That's What I Call Disney": {'compilation-albums': {'2013': 0,
#      '2014': 0},
#     'kid-albums': {'2016': 0, '2014': 0, '2013': 0, '2015': 0}},
#    'WOW Gospel 2013': {'compilation-albums': {'2013': 0},
#     'gospel-albums': {'2013': 0, '2014': 0}},
#    "The Essential NOW That's What I Call Christmas": {'compilation-albums': {'2013': 0,
#      '2009': 0,
#      '2017': 0,
#      '2012': 0,
#      '2019': 0,
#      '2020': 0,
#      '2018': 0,
#      '2014': 0}},
#    'NOW 48': {'compilation-albums': {'2013': 0, '2014': 0}},
#    "NOW That's What I Call Today's Christmas": {'compilation-albums': {'2013': 0}},
#    'Holidays Rule': {'compilation-albums': {'2013': 0}},
#    'Alabama & Friends': {'compilation-albums': {'2013': 0}},
#    'A Very Special Christmas: 25 Years Bringing Joy To The World': {'compilation-albums': {'2013': 0}},
#    'NOW 29': {'compilation-albums': {'2009': 0, '2008': 0},
#     'top-billboard-200-albums': {'2009': 0}},
#    'NOW 31': {'compilation-albums': {'2009': 0, '2010': 0}},
#    'NOW 30': {'compilation-albums': {'2009': 0}},
#    'Grammy Nominees 2009': {'compilation-albums': {'2009': 0}},
#    'I Can Only Imagine: Platinum Edition': {'compilation-albums': {'2009': 0,
#      '2008': 0},
#     'catalog-albums': {'2008': 0}},
#    'All Wrapped Up! (EP)': {'compilation-albums': {'2009': 0}},
#    "NOW That's What I Call Country": {'compilation-albums': {'2009': 0,
#      '2008': 0}},
#    'NOW 32': {'compilation-albums': {'2009': 0, '2010': 0}},
#    "WOW Gospel 2009: 30 Of The Year's Top Gospel Artists And Songs": {'compilation-albums': {'2009': 0},
#     'gospel-albums': {'2010': 0}},
#    "The Best Of NOW That's What I Call Music! 10th Anniversary": {'compilation-albums': {'2009': 0}},
#    'Walt Disney Records Presents: Radio Disney Jams 11': {'compilation-albums': {'2009': 0},
#     'kid-albums': {'2009': 0}},
#    "NOW That's What I Call Country Vol. 2": {'compilation-albums': {'2009': 0,
#      '2010': 0}},
#    'Winter Wonderland': {'compilation-albums': {'2009': 0},
#     'independent-albums': {'2009': 0}},
#    "NOW That's What I Call Christmas! 3": {'compilation-albums': {'2009': 0,
#      '2010': 0,
#      '2007': 0,
#      '2008': 0},
#     'catalog-albums': {'2008': 0}},
#    'Playing For Change: Songs Around The World': {'compilation-albums': {'2009': 0},
#     'world-albums': {'2009': 0, '2010': 0}},
#    "NOW That's What I Call Motown": {'compilation-albums': {'2009': 0}},
#    'NOW 28': {'compilation-albums': {'2009': 0, '2008': 0}},
#    'Nightmare Revisited': {'compilation-albums': {'2009': 0}},
#    'NOW 53': {'compilation-albums': {'2015': 0}},
#    'NOW 52': {'compilation-albums': {'2015': 0, '2014': 0}},
#    '2015 Grammy Nominees': {'compilation-albums': {'2015': 0}},
#    'NOW 54': {'compilation-albums': {'2015': 0}},
#    'NOW 55': {'compilation-albums': {'2015': 0, '2016': 0}},
#    'Disney Karaoke Series: Frozen (EP)': {'compilation-albums': {'2015': 0,
#      '2017': 0,
#      '2016': 0,
#      '2018': 0,
#      '2014': 0},
#     'kid-albums': {'2019': 0,
#      '2016': 0,
#      '2014': 0,
#      '2018': 0,
#      '2017': 0,
#      '2015': 0}},
#    "NOW That's What I Call Country, Volume 8": {'compilation-albums': {'2015': 0,
#      '2016': 0}},
#    'NOW 51': {'compilation-albums': {'2015': 0, '2014': 0}},
#    'NOW 56': {'compilation-albums': {'2015': 0, '2016': 0}},
#    'WOW Gospel 2015': {'compilation-albums': {'2015': 0},
#     'gospel-albums': {'2016': 0, '2015': 0}},
#    "Ellen's The Only Holiday Album You'll Ever Need - Volume 1": {'compilation-albums': {'2015': 0}},
#    "NOW That's What I Call #1's": {'compilation-albums': {'2015': 0}},
#    "NOW That's What I Call Country: Volume 7": {'compilation-albums': {'2015': 0,
#      '2014': 0}},
#    'NOW 50': {'compilation-albums': {'2015': 0, '2014': 0},
#     'current-albums': {'2014': 0},
#     'top-billboard-200-albums': {'2014': 0}},
#    "NOW That's What I Call Disney 3": {'compilation-albums': {'2015': 0},
#     'kid-albums': {'2015': 0}},
#    'The Art Of McCartney': {'compilation-albums': {'2015': 0}},
#    'Christmas At Downton Abbey': {'compilation-albums': {'2015': 0},
#     'traditional-classical-albums': {'2015': 0},
#     'classical-albums': {'2015': 0}},
#    'The Hamilton Mixtape': {'compilation-albums': {'2017': 0}},
#    'NOW 61': {'compilation-albums': {'2017': 0}},
#    'NOW 62': {'compilation-albums': {'2017': 0}},
#    'NOW 60': {'compilation-albums': {'2017': 0}},
#    '2017 Grammy Nominees': {'compilation-albums': {'2017': 0}},
#    "NOW That's What I Call Country Volume 10": {'compilation-albums': {'2017': 0,
#      '2018': 0}},
#    'NOW 63': {'compilation-albums': {'2017': 0, '2018': 0}},
#    "NOW That's What I Call A Workout 2017": {'compilation-albums': {'2017': 0},
#     'dance-electronic-albums': {'2017': 0}},
#    'NOW 59': {'compilation-albums': {'2017': 0, '2016': 0}},
#    "NOW That's What I Call Country #1's": {'compilation-albums': {'2017': 0}},
#    "NOW That's What I Call Merry Christmas": {'compilation-albums': {'2017': 0}},
#    'Roots Of Country Music': {'compilation-albums': {'2017': 0, '2016': 0}},
#    'WOW Gospel 2017': {'compilation-albums': {'2017': 0},
#     'gospel-albums': {'2017': 0}},
#    "NOW That's What I Call Country, Volume 9": {'compilation-albums': {'2017': 0,
#      '2016': 0}},
#    "Rock 'N' Roll Hall Of Fame": {'compilation-albums': {'2017': 0, '2016': 0},
#     'independent-albums': {'2016': 0}},
#    "Children's Favorites, Volume 1: 30 Classic Tunes": {'compilation-albums': {'2017': 0,
#      '2016': 0,
#      '2012': 0,
#      '2019': 0},
#     'kid-albums': {'2019': 0,
#      '2016': 0,
#      '2014': 0,
#      '2012': 0,
#      '2018': 0,
#      '2017': 0,
#      '2013': 0,
#      '2015': 0}},
#    'NOW 64': {'compilation-albums': {'2017': 0, '2018': 0}},
#    'NOW 57': {'compilation-albums': {'2016': 0}},
#    'NOW 58': {'compilation-albums': {'2016': 0}},
#    '2016 Grammy Nominees': {'compilation-albums': {'2016': 0}},
#    "Now That's What I Call A Workout 2016": {'compilation-albums': {'2016': 0},
#     'dance-electronic-albums': {'2016': 0}},
#    'We Love Disney': {'compilation-albums': {'2016': 0},
#     'kid-albums': {'2016': 0, '2015': 0}},
#    'WOW Gospel 2016': {'compilation-albums': {'2016': 0},
#     'gospel-albums': {'2016': 0}},
#    "NOW That's What I Call Disney Princess": {'compilation-albums': {'2016': 0},
#     'kid-albums': {'2016': 0}},
#    "NOW That's What I Call Power Ballads Hits": {'compilation-albums': {'2016': 0}},
#    "NOW That's What I Call Country Christmas": {'compilation-albums': {'2016': 0}},
#    'NOW 41': {'current-albums': {'2012': 0},
#     'compilation-albums': {'2012': 0}},
#    'NOW 40': {'compilation-albums': {'2012': 0, '2011': 0}},
#    'NOW 42': {'compilation-albums': {'2012': 0}},
#    '2012 Grammy Nominees': {'compilation-albums': {'2012': 0}},
#    'Maybach Music Group Presents: Self Made 2': {'compilation-albums': {'2012': 0},
#     'rap-albums': {'2012': 0}},
#    'NOW 39': {'compilation-albums': {'2012': 0, '2011': 0}},
#    "NOW That's What I Call Country: Volume 5": {'compilation-albums': {'2012': 0}},
#    'WOW Gospel 2012': {'compilation-albums': {'2012': 0},
#     'gospel-albums': {'2012': 0, '2013': 0}},
#    "NOW That's What I Call Christmas! 4": {'compilation-albums': {'2012': 0,
#      '2011': 0}},
#    "NOW That's What I Call Country: Volume 4": {'compilation-albums': {'2012': 0,
#      '2011': 0}},
#    'Let It Snow': {'compilation-albums': {'2012': 0}},
#    "NOW That's What I Call Country Ballads": {'compilation-albums': {'2012': 0}},
#    'Positively Christmas': {'compilation-albums': {'2012': 0}},
#    'The Greatest Showman: Reimagined': {'compilation-albums': {'2019': 0}},
#    'WOW Hits 2019': {'compilation-albums': {'2019': 0, '2020': 0}},
#    'NOW 69': {'compilation-albums': {'2019': 0}},
#    'NOW 68': {'compilation-albums': {'2019': 0}},
#    "NOW That's What I Call Music! 71": {'compilation-albums': {'2019': 0,
#      '2020': 0}},
#    'Grammy Nominees 2019': {'compilation-albums': {'2019': 0}},
#    'NOW 70': {'compilation-albums': {'2019': 0}},
#    "NOW That's What I Call Country, Volume 12": {'compilation-albums': {'2019': 0}},
#    "NOW That's What I Call Music! 20th Anniversary": {'compilation-albums': {'2019': 0}},
#    "NOW That's What I Call Country, Volume 11": {'compilation-albums': {'2019': 0,
#      '2018': 0}},
#    "NOW That's What I Call Music! 20th Anniversary, Volume 2": {'compilation-albums': {'2019': 0}},
#    "NOW That's What I Call Merry Christmas (2018)": {'compilation-albums': {'2019': 0,
airplay-songs': {'2014': 0}}},
#   'Albums': {}},
#  'Becky G Featuring Pitbull': {'Songs': {"Can't Get Enough": {'latin-rhythm-airplay-songs': {'2014': 0}}},
#   'Albums': {}},
#  'Wisin Featuring Chris Brown & Pitbull': {'Songs': {'Control': {'latin-rhythm-airplay-songs': {'2014': 0}}},
#   'Albums': {}},
#  'Cartel de Santa': {'Songs': {},
#   'Albums': {'Golpe Avisa': {'latin-rhythm-albums-': {'2014': 0}}}},
#  'Cosculluela': {'Songs': {},
#   'Albums': {'Santa Cos': {'latin-rhythm-albums-': {'2014': 0}},
#    'War Kingz': {'latin-rhythm-albums-': {'2013': 0}},
#    'El Principe': {'latin-rhythm-albums-': {'2010': 0}},
#    'BlancoPerla': {'latin-rhythm-albums-': {'2016': 0, '2017': 0}},
#    'The Ones': {'latin-rhythm-albums-': {'2016': 0}},
#    'El Nino': {'latin-rhythm-albums-': {'2012': 0}}}},
#  'Kinto Sol': {'Songs': {},
#   'Albums': {'La Tumba del Alma': {'latin-rhythm-albums-': {'2013': 0}},
#    'Carcel de Suenos': {'latin-rhythm-albums-': {'2009': 0}},
#    'El Ultimo Suspiro': {'latin-rhythm-albums-': {'2011': 0}},
#    'Los Hijos Del Maiz': {'latin-rhythm-albums-': {'2007': 0}},
#    'Familia, Fe y Patria': {'latin-rhythm-albums-': {'2012': 0}}}},
#  'Dyland & Lenny': {'Songs': {'Pegate Mas': {'latin-rhythm-airplay-songs': {'2012': 0}}},
#   'Albums': {'My World 2': {'latin-rhythm-albums-': {'2013': 0}}}},
#  'Wisin & Yandel Featuring Chris Brown & T-Pain': {'Songs': {'Algo Me Gusta De Ti': {'hot-latin-songs': {'2013': 0},
#     'latin-streaming-songs': {'2013': 0},
#     'latin-digital-songs': {'2013': 0},
#     'latin-pop-airplay-songs': {'2013': 0},
#     'latin-rhythm-airplay-songs': {'2013': 0, '2012': 0}}},
#   'Albums': {}},
#  'Tito El Bambino + El Patron Featuring Marc Anthony': {'Songs': {'Por Que Les Mientes?': {'hot-latin-songs': {'2013': 0},
#     'latin-pop-airplay-songs': {'2013': 0},
#     'tropical-airplay-songs': {'2013': 0},
#     'latin-airplay-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Thalia Featuring Prince Royce': {'Songs': {'Te Perdiste Mi Amor': {'hot-latin-songs': {'2013': 0},
#     'latin-pop-airplay-songs': {'2013': 0},
#     'latin-airplay-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Carlos Vives Featuring Michel Telo': {'Songs': {'Como Le Gusta A Tu Cuerpo': {'hot-latin-songs': {'2013': 0},
#     'latin-pop-airplay-songs': {'2013': 0},
#     'tropical-airplay-songs': {'2013': 0},
#     'latin-airplay-songs': {'2013': 0}}},
#   'Albums': {}},
#  'Ruben Blades/Seis del Solar': {'Songs': {},
#   'Albums': {'Todos Vuelven: Live': {'tropical-albums': {'2013': 0}}}},
#  'Olga Tanon': {'Songs': {},
#   'Albums': {'Una Mujer': {'tropical-albums': {'2013': 0}},
#    'Fuego En Vivo Vol. 2: Solo Exitos': {'tropical-albums': {'2009': 0}},
#    'Fuego En Vivo Vol. 1: Solo Exitos': {'tropical-albums': {'2009': 0}},
#    'Exitos En 2 Tiempos': {'tropical-albums': {'2008': 0}},
#    'Soy Como Tu': {'tropical-albums': {'2006': 0, '2007': 0}},
#    'Ni Una Lagrima Mas': {'tropical-albums': {'2011': 0}}}},
#  ...}

# %%
        
        
    
    def setFullChartData(self):        
        dbRenameStats     = 0    
        multiRenameStats  = 0
        
        
        if len(self.files) == 0:
            raise ValueError("There are no files. Something is wrong...")
        
        for ifile in self.files:
            fdata = getFile(ifile)
            for chartName, cnameResults in fdata.items():
                if chartName not in self.charts:
                    continue
                
                for date, dResults in cnameResults.items():
                    if self.minYear is not None:
                        if getDateTime(date).year < int(self.minYear):
                            continue
                    if self.maxYear is not None:
                        if getDateTime(date).year > int(self.maxYear):
                            continue
                    stryear = getDateTime(date).year

                    artistName = dResults["Artist"]
                    

                    ## Test for rename
                    renamedArtistName = artistName
                    if self.dbRenames is not None:
                        tmpName = self.dbRenames.renamed(renamedArtistName)
                        if tmpName != renamedArtistName:
                            dbRenameStats += 1
                        renamedArtistName = tmpName

                    ## Test for multi rename
                    #renamedArtistName = artistName
                    if self.multirenameDB is not None:
                        tmpName = self.multirenameDB.renamed(renamedArtistName)
                        if tmpName != renamedArtistName:
                            multiRenameStats += 1
                        renamedArtistName = tmpName

                    artist = renamedArtistName

                    ignoreStatus = getArtistIgnores(artist)
                    if ignoreStatus is False:
                        continue

                    album  = dResults["Name"]

                    if self.chartData.get(artist) is None:
                        self.chartData[artist] = Counter()
                    self.chartData[artist][album] += 1
                    
                    if self.fullChartData.get(artist) is None:
                        self.fullChartData[artist] = {"Songs": {}, "Albums": {}}
                    if chartName.endswith("Albums"):
                        key = "Albums"
                    else:
                        key = "Songs"
                    if self.fullChartData[artist][key].get(album) is None:
                        self.fullChartData[artist][key][album] = {}
                    if self.fullChartData[artist][key][album].get(chartName) is None:
                        self.fullChartData[artist][key][album][chartName] = {}
                    self.fullChartData[artist][key][album][chartName][date] = 0
                #print("{0: <40}{1}".format("{0}-{1}".format(chartName,stryear),len(self.fullChartData)))
                
        print("Renamed {0} single artists".format(dbRenameStats))
        print("Renamed {0} multi artists".format(multiRenameStats))

# %%
bsdata = getHTML("chartData/adult__charts__year-end__2019__adult-contemporary-artists.p")

# %%
bsdat = getHTML("chartData/adult__charts__year-end__2020__adult-contemporary-artists.p")

# %%
yearends = []
for ul in bsdata.findAll("ul", {"class": "site-header__subnav-items"}):
    lis = ul.findAll("li", {"class": "site-header__subnav-item"})
    for li in lis:
        refs = li.findAll("a")
        for ref in refs:
            if ref.attrs['href'].find("year-end") != -1:
                yearends.append(ref)

# %%
downloads = {}
baseURL = "https://www.billboard.com"
for ifile in sorted(glob(join(basedir, "data", "billboard", "yearly", "*.p"))):
    year = getBaseFilename(ifile)
    if downloads.get(year) is None:
        downloads[year] = {}
    fdata = getHTML(ifile)
    for iul,ul in enumerate(fdata.findAll("ul")):
        lis = ul.findAll("li", {"class": "chart-group__item"})
        for j,li in enumerate(lis):  
            a = li.find('a')
            if a is not None:
                href = a['href']
                text = a.text
                subdir = getDirname(href)[1:]
                downloads[year][href] = [baseURL, subdir, getBasename(href)]

# %%
downloads.keys()

# %% [markdown]
# # Download Category Data

# %%
baseURL = "https://www.billboard.com"

for year, yearData in downloads.items():   
    for href, hrefData in yearData.items():
        url  = "{0}/{1}".format(baseURL, href)
        year = getBasename(hrefData[1])
        category = hrefData[2]

        savedir  = join(basedir, "data", "billboard", "categories")
        savename = join(savedir, "{0}-{1}.p".format(year, category))

        if isFile(savename):
            continue

        print("  Trying to download and save {0}".format(savename))
        try:

            user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
            headers={'User-Agent':user_agent,} 

            request=urllib.request.Request(url,None,headers) #The assembled request
            response = urllib.request.urlopen(request)
            data = response.read() # The data u need
        except:
            continue

        print("Saving {0}".format(savename))
        saveJoblib(data=data, filename=savename, compress=True)
        sleep(1)

# %% [markdown]
# # Parse Category Data

# %%
data = {}

baseURL = "https://www.billboard.com"
names = [getBaseFilename(x) for x in sorted(glob(join(basedir, "data", "billboard", "categories", "*.p")))]
categories = set([x[5:] for x in names])

albumCategories  = [x for x in categories if x.endswith("albums")]
songCategories   = [x for x in categories if not x.endswith("albums")]


names = [getBaseFilename(x) for x in sorted(glob(join(basedir, "data", "billboard", "categories", "*.p")))]
years = sorted(set([x[:4] for x in names]))

print("There are {0} years".format(len(years)))
print("There are {0} charts".format(len(categories)))
print("There are {0} album charts".format(len(albumCategories)))
print("There are {0} song charts".format(len(songCategories)))

# %%
#categories

# %%
if False:
    catdir = join(basedir, "data", "billboard", "categories")
    files = findPatternExt(catdir, pattern='2019', ext='.p')    
    for ifile in files:
        bsdata = getHTML(ifile)
        name   = bsdata.find("h2", {"class": "simple-page__title"})
        print(ifile,'\t',name)

# %%
def parseBillboardFile(ifile):
    fdata = getHTML(ifile)
    data  = {}
    for i,table in enumerate(fdata.findAll('table')):
        ths = table.findAll("th")
        trs = table.findAll("tr")

        headers = [x.text for x in ths]
        for j,tr in enumerate(trs[1:]):
            tds  = tr.findAll('td')
            vals = [x.text for x in tds]
            #print(headers,vals)

            if len(vals) == 3:
                date,name,artist = vals
                try:
                    date = getDateTime(", ".join([date, year]))
                except:
                    print(vals)
                    print(", ".join([date, year]))

                    1/0
            elif len(vals) == 1:
                date = vals[0]
                try:
                    date = getDateTime(", ".join([date, year]))
                except:
                    print(vals)
                    1/0

            if not isDate(date):
                raise ValueError("Could not form date for {0}".format(date))

            date = printDateTime(date)
            if data.get(date) is not None:
                raise ValueError("Already seen this date!!!")
            data[date] = {"Artist": artist, "Name": name}
            
            #print("{0: <12}{1}".format(date, data[date]))
            continue
            
            
            if data.get(date) is None:
                data[date] = {}
            #print("{0: <20}{1: <20}{2: <20}{3: <20}".format(artist, name, category, date))
            #continue
            if data.get(artist) is None:
                data[artist] = {}
                #print("Artist: {0}".format(artist))
            if data[artist].get(name) is None:
                data[artist][name] = {}
                #print("\tSong: {0} ({1})".format(name, len(data[artist])))
            if data[artist][name].get(category) is None:
                data[artist][name][category] = []
            data[artist][name][category].append([date])

    return data

# %%
catdir = join(basedir, "data", "billboard", "categories")
for year in years:
    data  = {}
    files = findPatternExt(catdir, pattern=year, ext='.p')    
    for ifile in files:
        chart   = getBaseFilename(ifile)
        chart   = "-".join(chart.split('-')[1:])
        results = parseBillboardFile(ifile)
        data[chart] = results
        print("{0: <10}{1: <30}{2}".format(year, chart, len(results)))
        
    savedir = join(basedir, "data", "billboard", "results")
    savename = join(savedir, "{0}.p".format(year))
    print("Saving {0}".format(savename))
    saveJoblib(data=data, filename=savename, compress=True)

# %% [markdown]
# # Aggregrate Charts

# %%
# Out:
# Found 62 files.
#   Getting All Charts
#   Using 200 Charts
#   Using Charts (None): ['adult-contemporary', 'adult-pop-songs', 'ASI', 'ATF', 'alternative-albums', 'alternative-songs', 'MRT', 'ALT', 'BLU', 'BGR', 'FLK', 'christian-airplay', 'hot-christian-songs', 'christian-albums', 'christian-digital-song-sales', 'christian-songs', 'christian-streaming-songs', 'gospel-airplay', 'gospel-albums', 'gospel-digital-song-sales', 'gospel-songs', 'gospel-streaming-songs', 'CRI', 'CRT', 'ICO', 'ILL', 'SLL', 'GOS', 'GSI', 'GSS', 'CHS', 'GDT', 'country-airplay', 'country-albums', 'country-digital-song-sales', 'country-songs', 'country-streaming-songs', 'CSA', 'CSI', 'CST', 'CLP', 'CDT', 'dance-club-play-songs', 'dance-electronic-albums', 'dance-electronic-digital-song-sales', 'dance-electronic-songs', 'dance-electronic-streaming-songs', 'DAN', 'DAS', 'DDT', 'BSI', 'BST', 'DSI', 'ELP', 'hot-100', 'pop-songs', 'radio-songs', 'streaming-songs', 'rhythmic-40', 'heatseekers-albums', 'billboard-200', 'artist-100', 'top-album-sales', 'TLN', 'HSB', 'HSI', 'TLP', 'TSL', 'TFM', 'ATS', 'billboard-200', 'artist-100', 'top-album-sales', 'r-and-b-albums', 'r-and-b-hip-hop-digital-song-sales', 'r-and-b-hip-hop-streaming-songs', 'r-and-b-songs', 'r-b-hip-hop-albums', 'r-b-hip-hop-songs', 'rap-albums', 'rap-song', 'hot-r-and-b-hip-hop-airplay', 'RLP', 'RAP', 'RBL', 'RBM', 'RBS', 'RBT', 'BLP', 'rock-airplay', 'hot-mainstream-rock-tracks', 'rock-albums', 'rock-digital-song-sales', 'rock-songs', 'rock-streaming-songs', 'hard-rock-albums', 'RCK', 'RKA', 'RKT', 'ROS', 'RTT', 'MTL', 'ARK', 'canadian-albums', 'canadian-hot-100', 'CAN', 'CNA', 'latin-airplay', 'latin-albums', 'latin-digital-song-sales', 'latin-pop-albums', 'latin-pop-songs', 'latin-songs', 'latin-streaming-songs', 'HTA', 'HTL', 'LSS', 'LDT', 'LPO', 'LPP', 'LCM', 'regional-mexican-albums', 'regional-mexican-songs', 'LRM', 'LMX', 'china-v-chart', 'japan-hot-100', 'tropical-albums', 'tropical-songs', 'world-albums', 'reggae-albums', 'LSA', 'LTS', 'JPN', 'WLP', 'JAH', 'ARG', 'holiday-albums', 'holiday-season-digital-song-sales', 'holiday-songs', 'holiday-streaming-songs', 'XSS', 'XML', 'XDT', 'ASX', 'classical-albums', 'COA', 'jazz-albums', 'jazz-songs', 'JLS', 'JSI', 'comedy-albums', 'GIG', 'new-age-albums', 'NLP', 'HDS', 'DLP', 'kids-albums', 'KID', 'twitter-emerging-artists', 'twitter-top-tracks', 'social-50', 'STM', 'SOC', 'vinyl-albums', 'catalog-albums', 'tastemaker-albums', 'TAS', 'VNL', 'TLC', 'independent-albums', 'IND', 'soundtracks', 'STX', 'adult', 'alternative', 'folkblue', 'christian', 'countryMusic', 'electronic', 'hot', 'top', 'rnb', 'rock', 'canadian', 'latin', 'mexican', 'world', 'holiday', 'classical', 'jazz', 'comedy', 'newage', 'general', 'kids', 'twitter', 'vinyl', 'rare', 'soundtrack', 'chartNames']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-04506d1c82d2> in <module>
#       5 #bd.setDBRenames(getDBRenames())
#       6 bd.setChartUsage()
# ----> 7 bd.setFullChartData()
#       8 bd.setArtistAlbumData()
#       9
#
# ~/Documents/code/charts/billboardData.py in setFullChartData(self)
#      83
#      84     def setFullChartData(self):
# ---> 85         renameStats  = Counter()
#      86         chartCounter = Counter()
#      87
#
# NameError: name 'Counter' is not defined

# %% [markdown]
# ****

# %% [markdown]
# # Chart Analysis

# %%
chartCounter = getFile("chartCounter.p")
keys = chartCounter.keys()
sorted(keys)
#chartCounter.most_common()
# Out:
# ['ATS',
#  'HSB',
#  'HSI',
#  'TFM',
#  'TLN',
#  'TLP',
#  'TSL',
#  'artist-100',
#  'billboard-200',
#  'heatseekers-albums',
#  'hot-100',
#  'pop-songs',
#  'radio-songs',
#  'rhythmic-40',
#  'streaming-songs',
#  'top-album-sales']

# %%
slimResults = Counter()
for artist, artistData in results.items():
    for key, keyData in artistData.items():
        for album, albumData in keyData.items():
            slimResults[artist] += sum({k: len(v) for k,v in albumData.items()}.values())

# %%
saveFile(idata = slimResults, ifile="billboardCounter.p", debug=True)
saveFile(idata = results,     ifile="billboardResults.p", debug=True)

# %% [markdown]
# # Get Billboard Results

# %%
slimResults = getFile(ifile="billboardCounter.p", debug=True)
fullResults = getFile(ifile="billboardResults.p", debug=True)

# %% [markdown]
# # Get Discogs

# %%
disc = discogs()
discdf = disc.getMasterSlimArtistDiscogsDB()
artistIDToName = discdf["DiscArtist"].to_dict()
from masterdb import getArtistAlbumsDB, discConv
artistAlbumsDB = getArtistAlbumsDB(disc)

artistNameToID = {}
print("Found {0} ID -> Name entries".format(len(artistIDToName)))
for artistID,artistName in artistIDToName.items():
    if artistNameToID.get(artistName) is None:
        artistNameToID[artistName] = []
    artistNameToID[artistName].append(artistID)
print("Found {0} Name -> ID entries".format(len(artistNameToID)))
mulArts  = multiArtist(cutoff=0.9, discdata=artistNameToID, exact=False)

# %% [markdown]
# # Check Renames

# %%
singleRenames = getFile(ifile="singleRenames.p", debug=True)
multiRenames  = getFile(ifile="multiRenames.p", debug=True)
knownArtists  = getFile(ifile="artistMap.p", debug=True)

# %% [markdown]
# # Near Renames Artists

# %%
from searchUtils import findNearest
cutoff = 0.9
artistsToGet = {}
for i, (artist, cnt) in enumerate(slimResults.most_common()):
#for i, (artist, cnt) in enumerate(sorted(slimResults.items(), key=lambda pair: pair[1], reverse=False)):
    if i <= 4500:
        continue
    if i % 250 == 0:
        print("==>",i,len(slimResults))
    if multiRenames.get(artist) is not None:
        artist = multiRenames[artist]
    if singleRenames.get(artist) is not None:
        idx    = str(singleRenames[artist])
        artist = artistIDToName[idx]
    if knownArtists.get(artist) is not None:
        continue
    if manualRenames.get(artist) is not None:
        continue

    matches = mulArts.getArtistNames(artist)
    if len(matches) > 1:
        continue

    mdata = getMusicData("DiscArtist", artist)
    if mdata is None:
        results = findNearest(artist, artistNameToID.keys(), num=1, cutoff=cutoff)      
        if len(results) > 0:
            artistsToGet[artist] = results
            print("manualRenames[\"{0}\"] = \"{1}\"".format(artist, results[0]))

# %%
findNearest

# %%
for k,v in artistsToGet.items():
    print("keep[\"{0}\"] = {1}  #{2}".format(k, v[0], v[1]))

# %% [markdown]
# # Get Multi Results

# %%
from collections import Counter
cutoff = 0.8
multiMatchResult = {}
for i, (artist, cnt) in enumerate(slimResults.most_common()):
    if i > 0 and i % 1000 == 0:
        print("Passed",i,'/',len(slimResults))
    prevArtist = None
    if multiRenames.get(artist) is not None:
        prevArtist = artist
        artist = multiRenames[artist]
    if singleRenames.get(artist) is not None:
        idx    = str(singleRenames[artist])
        artist = artistIDToName[idx]
    if prevArtist is None:
        prevArtist = artist
    if knownArtists.get(prevArtist) is not None:
        continue
    if manualRenames.get(prevArtist) is not None:
        prevArtist = manualRenames[prevArtist]
    mdata = getMusicData("DiscArtist", prevArtist)
    if isinstance(mdata, DataFrame):
        if mdata.shape[0] <= 1:
            continue
        matches = mdata["Name"].index
        artistAlbums = set(list(fullResults[prevArtist]["Songs"].keys()) + list(fullResults[prevArtist]["Albums"].keys()))
        results = getBestArtistIDMatch(artist, artistAlbums, matches, N=3, cutoff=cutoff)
        if results[2] is not None:
            if results[2] >= cutoff:
                print(i,"/",len(slimResults),'  \t',artist,results)
                multiMatchResult[artist] = list(results[:-1])

# %%
len(multiMatchResult)

# %%
print(len(knownArtists))
knownArtists.update(multiMatchResult)
print(len(knownArtists))
saveFile(idata=knownArtists, ifile="artistMap.p", debug=True)

# %% [markdown]
# # Single Results

# %%
knownArtists["The Kingston Trio"]

# %%
cutoff = 0.60
singleResult = {}
#for i, (artist, cnt) in enumerate(slimResults.most_common()):
for i, (artist, cnt) in enumerate(sorted(slimResults.items(), key=lambda pair: pair[1], reverse=False)):
    if i > 0 and i % 100 == 0 or i == 100:
        print("Passed",i,'/',len(slimResults))
    if cnt < 1:
        continue
    prevArtist = None
    if multiRenames.get(artist) is not None:
        prevArtist = artist
        artist = multiRenames[artist]
    if singleRenames.get(artist) is not None:
        idx    = str(singleRenames[artist])
        artist = artistIDToName[idx]        
    if prevArtist is None:
        prevArtist = artist
    if manualRenames.get(prevArtist) is not None:
        prevArtist = manualRenames[prevArtist]
    if knownArtists.get(prevArtist) is not None or knownArtists.get(artist) is not None:
        continue
    artistAlbums = set(list(fullResults[artist]["Songs"].keys()) + list(fullResults[artist]["Albums"].keys()))
    match = mulArts.getArtistNames(artist                                                     )
    if len(match) == 1:
        mdata = getMusicData("DiscArtist", list(match.keys())[0])
        if not isinstance(mdata, DataFrame):
            results = getBestArtistMatch(artist, artistAlbums, N=3, cutoff=cutoff)
            if results[2] is not None:
                if results[2] >= cutoff:
                    print(i,"/",len(slimResults),'  \t',artist,'\t',results)
                    singleResult[artist] = results
                    if len(singleResult) > 1000:
                        break

# %%
del singleResult["Murk vs. Kristine W"]
del singleResult["Chris Cox Vs. Happy Clappers"]
del singleResult["T.M.Revolution × Nana Mizuki"]
del singleResult["Bob Marley Vs. Funkstar De Luxe"]

# %%
singleResults = {k: v[0] for k,v in singleResult.items()}
print("Found {0} single results".format(len(singleResults)))
print("Found {0} all results".format(len(knownArtists)))
knownArtists.update(singleResults)
print("Found {0} all results".format(len(knownArtists)))
saveFile(idata=knownArtists, ifile="artistMap.p", debug=True)

# %% [markdown]
# ## Known Results

# %%
from collections import Counter
cutoff = 0.8
multiMatchResult = {}
for i, (artist, cnt) in enumerate(slimResults.most_common()):
    if i > 0 and i % 1000 == 0:
        print("Passed",i,'/',len(slimResults))
    prevArtist = None
    if multiRenames.get(artist) is not None:
        prevArtist = artist
        artist = multiRenames[artist]
    if singleRenames.get(artist) is not None:
        idx    = str(singleRenames[artist])
        artist = artistIDToName[idx]
    if prevArtist is None:
        prevArtist = artist
    if knownArtists.get(prevArtist) is not None:
        continue
    mdata = getMusicData("DiscArtist", prevArtist)
    if isinstance(mdata, DataFrame):
        if mdata.shape[0] <= 1:
            continue
        matches = mdata["Name"].index
        artistAlbums = set(list(fullResults[prevArtist]["Songs"].keys()) + list(fullResults[prevArtist]["Albums"].keys()))
        results = getBestArtistIDMatch(artist, artistAlbums, matches, N=3, cutoff=cutoff)
        if results[2] is not None:
            if results[2] >= cutoff:
                print(i,"/",len(slimResults),'  \t',artist,results)
                multiMatchResult[artist] = list(results[:-1])

# %%
singleResults = {k: v[0] for k,v in multiMatchResult.items()}
print("Found {0} single results".format(len(singleResults)))
print("Found {0} all results".format(len(knownArtists)))
knownArtists.update(singleResults)
print("Found {0} all results".format(len(knownArtists)))

# %%
saveFile(idata=knownArtists, ifile="singleRenames.p")

# %% [markdown]
# # Check For Misnames

# %%
ma = multiartist(cutoff=0.9, discdata=discdata)

# %%
print(ma.getArtistNames('Lipps, Inc.') == {'Lipps, Inc.': ['159617', '26641', '101850']})
print(ma.getArtistNames('Bob Wills & His Texas Playboys') == {'Bob Wills & His Texas Playboys': ['670000','786114','1134146','804668','804679','1004309','935875','935907']})
print(ma.getArtistNames('Brad Paisley Duet With Carrie Underwood', debug=False) == {'Carrie Underwood': ['1011680'], 'Brad Paisley': ['313755']})
print(ma.getArtistNames('Ray Charles With Willie Nelson', debug=False) == {'Willie Nelson': ['249449'], 'Ray Charles': ['521963', '30552']})

# %% [markdown]
# # Album Data

# %%
savename = join(savedir, "billboard.p")
albumData = getFile(join(savedir, "billboard-album.p"))
#chartdata = getFile(savename, debug=True)

# %%
for artist,artistData in albumData.items():
    print(artist)
    for album in artistData.keys():
        print("\t",album)

# %% [markdown]
# # Show Data

# %%
togets = {}
combos = []

savedir  = join(basedir, "results")
savename = join(savedir, "billboard.p")
chartdata = getFile(savename, debug=True)
chartArtists = sorted(chartdata.keys(), reverse=True)

import json
prevs = json.load(open("prevs.json", "r"))
artPrev = json.load(open("../discogs/prevs.json", "r"))
prevs.update(artPrev)
json.dump(prevs, open("prevs.json", "w"))
print("There are {0} artists previously searched.".format(len(prevs)))

ma = multiartist(cutoff=0.9, discdata=discdata, exact=False)

from random import shuffle
print("There are {0} chart artists".format(len(chartArtists)))
shuffle(chartArtists)
for i,artist in enumerate(chartArtists):
    if prevs.get(artist) is not None:
        continue
    retval = ma.getArtistNames(artist)
    if retval is None:
        togets[artist] = artist
    else:
        for name,value in retval.items():
            if prevs.get(name) is not None:
                continue
            if value is None:
                togets[name.upper()] = artist
                print("{0: <3}{1: <40}{2: <60}{3}".format(len(togets),name,artist,retval))
                print('\t---->',i,'/',len(chartArtists))

    
    if len(togets) > 50:
        print("\n\n\n\n")
        for name,artist in togets.items():
            print("art.searchDiscogForArtist(\"{0}\")  ## {1}".format(name, artist))
        break

# %% [markdown]
# ###### artists = [x.strip() for x in vals.split("\n")]
# artists = [x for x in artists if len(x) > 0]

# %%
Pitbull Featuring Ne-Yo, Afrojack & Nayer
Drake Featuring Kanye West, Lil Wayne & Eminem

# %%
def testName(name, discdata):
    if discdata.get(name) is not None:
        return discdata[name]
    return name

def findName(name, discArtists, threshold):
    retval = findNearest(name, discArtists, 1, threshold)
    if len(retval) == 0:
        return name
    return retval
    

def splitArtist(name):
    names = [name]
    names = [[x.strip() for x in y.split(" Featuring ")]
results = {}
    
for name in artists:
    if " & " in name:
        retvals = [testName(x, discdata) for x in 
        retvals = [findName(x, discArtists, 0.95) if not isinstance(x, list) else x for x in retvals]
        results[name] = retvals

# %%
togets = []
for k,v in results.items():
    for val in v:
        if not isinstance(val, list):
            togets.append("art.searchDiscogForArtist(\"{0}\")".format(val))
            
for toget in set(togets):
    print(toget)

# %%
tmp = [['5070865', '90037', '4135543', '1507065'], ['Katy XXX Perry', ['1201210']]]

# %%
tmp

# %%
nameids = {}
namerefs = {}
for name,nameid in iddata.items():
    artist = name
    if name.endswith(")"):
        artist = None
        for x in [-3,-4,-5]:
            if artist is not None:
                continue
            if abs(x) > len(name):
                continue
            if name[x] == "(":
                try:
                    val = int(name[(x+1):-1])
                    artist = name[:x].strip()
                except:
                    continue
          
        if artist is None:
            artist = name

    ref = refdata[name]
            
    if nameids.get(artist) is None:
        nameids[artist] = {}
    nameids[artist][nameid] = 1
    
    if namerefs.get(artist) is None:
        namerefs[artist] = {}
    namerefs[artist][ref] = 1
    

nameids = {k: list(v.keys()) for k,v in nameids.items()}
namerefs = {k: list(v.keys()) for k,v in namerefs.items()}
